# %%
import numpy as np
from itertools import permutations
from tqdm import tqdm

# %% [markdown]
# # Data Loading

# %%
def load_supertags(path):

    file = open(path, 'r')
    word_to_tag = {}

    for line in file:

        word, tag = line.split(" ")
        if tag[-1] == "\n": tag = tag[:-1]

        word_to_tag[word.lower()] = tag
    
    file.close()
    return word_to_tag

# %%
def load_corpus(path, word_to_tag, num_lines, K):
    file = open(path, "r")

    one_grams = {}
    two_grams = {}
    three_gram = {}

    unitags = {}
    bitags = {}
    tritags = {}

    number_of_words = 0
    number_of_tags = 0
    num_line_iter = 0 
    
    for _, line in enumerate(tqdm(file)):
        
        line = line.lower().split(" ")

        if len(line) < 3: continue

        number_of_words += len(line)
        line_iter = 0

        # Trigrams/tritags
        while line_iter < len(line) - 2:

            word_1 = line[line_iter]
            word_2 = line[line_iter+1]
            word_3 = line[line_iter+2]

            if word_3[-1] == '\n': word_3 = word_3[:-1] 

            #unitags, bitags, trigrams
            tag_1 = None
            tag_2 = None
            tag_3 = None

            if word_1 in word_to_tag.keys():
                tag_1 = word_to_tag[word_1]
                key_1 = tag_1
                number_of_tags += 1

                if key_1 in unitags.keys():
                    unitags[key_1] += 1
                else:
                    unitags[key_1] = 1
    
                if word_2 in word_to_tag.keys():
                    tag_2 = word_to_tag[word_2]
                    key_2 = (tag_1, tag_2)

                    if key_2 in bitags.keys():
                        bitags[key_2] += 1
                    else:
                        bitags[key_2] = 1
        
                    if word_3 in word_to_tag.keys():
                        tag_3 = word_to_tag[word_3]
                        key_3 = (tag_1, tag_2, tag_3)

                        if key_3 in tritags.keys():
                            tritags[key_3] += 1
                        else:
                            tritags[key_3] = 1


            #unisufixes, bisufiexes, trisufixes
            if len(word_1) > K:
                word_1 = word_1[-K:]
            if len(word_2) > K:
                word_2 = word_2[-K:]
            if len(word_3) > K:
                word_3 = word_3[-K:]

            key_1 = word_1
            key_2 = (word_1, word_2)
            key_3 = (word_1, word_2, word_3)

            if key_1 in one_grams.keys():
                one_grams[key_1] += 1
            else:
                one_grams[key_1] = 1

            if key_2 in two_grams.keys():
                two_grams[key_2] += 1
            else:
                two_grams[key_2] = 1

            if key_3 in three_gram.keys():
                three_gram[key_3] += 1
            else:
                three_gram[key_3] = 1

            line_iter += 1


        if tag_2 and tag_3:
                number_of_tags += 2
                key_2 = (tag_2, tag_3)
                if key_2 in bitags.keys():
                    bitags[key_2] += 1
                else:
                    bitags[key_2] = 1

                key_1 = tag_2
                if key_1 in unitags.keys():
                    unitags[key_1] += 1
                else:
                    unitags[key_1] = 1

                key_1 = tag_3
                if key_1 in unitags.keys():
                    unitags[key_1] += 1
                else:
                    unitags[key_1] = 1

        key_2 = (word_2, word_3)
        if key_2 in two_grams.keys():
            two_grams[key_2] += 1
        else:
            two_grams[key_2] = 1

        key_1 = word_2
        if key_1 in one_grams.keys():
             one_grams[key_1] += 1
        else:
            one_grams[key_1] = 1

        key_1 = word_3
        if key_1 in one_grams.keys():
            one_grams[key_1] += 1
        else:
            one_grams[key_1] = 1


        num_line_iter += 1
        if num_line_iter == num_lines: break

    return three_gram, two_grams, one_grams, number_of_words, unitags, bitags, tritags, number_of_tags

# %%
def train_three_grams(path, start_line, num_lines, K):
    file = open(path, "r")

    three_gram = {}
    tritags = {}
    num_line_iter = 0

    for line in tqdm(file):
        if num_line_iter < start_line:
            num_line_iter += 1
            continue
        
        line = line.lower().split(" ")

        if len(line) < 3: continue

        line_iter = 0

        while line_iter < len(line) - 2:

            word_1 = line[line_iter]
            word_2 = line[line_iter+1]
            word_3 = line[line_iter+2]

            if word_3[-1] == '\n': word_3 = word_3[:-1] 

            if word_1 in word_to_tag.keys() and word_2 in word_to_tag.keys() and word_3 in word_to_tag.keys():
                key_3 = (word_to_tag[word_1], word_to_tag[word_2], word_to_tag[word_3])

                if key_3 in tritags.keys():
                    tritags[key_3] += 1
                else:
                    tritags[key_3] = 1

            if len(word_1) > K:
                word_1 = word_1[-K:]
            if len(word_2) > K:
                word_2 = word_2[-K:]
            if len(word_3) > K:
                word_3 = word_3[-K:]

            key_3 = (word_1, word_2, word_3)
            
            if key_3 in three_gram.keys():
                three_gram[key_3] += 1
            else:
                three_gram[key_3] = 1
            
            line_iter += 1

        num_line_iter += 1
        if num_line_iter == start_line + num_lines: break

    return three_gram, tritags

# %%
def load_val(path, start_line=0,end=10000):

    val = []
    file = open(path, 'r')
    for iter, line in enumerate(file):
        if iter < start_line: continue
        val.append(line)
        if iter - start_line == end: break
        
    return val

# %% [markdown]
# #Lambda Training

# %%
def train_lambdas(one_grams, two_grams, three_grams, train_three_grams, number_of_words):

    lambdas = np.array([0, 0, 0])

    for three_gram in train_three_grams.keys():

        p3 = 0
        p2 = 0
        p1 = 0

        if three_gram in three_grams:

            p3 = three_grams[three_gram]/two_grams[three_gram[:2]]

        if three_gram[1:] in two_grams:

            p2 = two_grams[three_gram[1:]]/one_grams[three_gram[1]]

        if three_gram[2] in one_grams:

            p1 = one_grams[three_gram[2]]/number_of_words
        
        results = (p1, p2, p3)
        
        f = lambda i: results[i]
        best = max(range(len(results)), key=f)

        lambdas[best] += train_three_grams[three_gram]

    return lambdas/np.sum(lambdas)

# %% [markdown]
# # Testing Functions

# %%
def test_three_gram(one_grams, two_grams, three_grams, lambdas, three_gram, number_of_one_grams):

    result = 0

    if three_gram in three_grams:

        result += lambdas[2] * three_grams[three_gram]/two_grams[three_gram[:2]]

    if three_gram[1:] in two_grams:

        result += lambdas[1] * two_grams[three_gram[1:]]/one_grams[three_gram[1]]

    if three_gram[2] in one_grams:

        result += lambdas[0] * one_grams[three_gram[2]]/number_of_words

    return result

# %%
def test_sentence(one_grams, two_grams, three_grams, lambdas_words, number_of_words, unitags, bitags, tritags, lambdas_tags, number_of_tags, word_to_tag, sentence, K, gamma):

    sen_iter = 0
    result = 0

    while sen_iter < len(sentence) - 2:
        
        result_tags = 0
        result_words = 0
        word_1 = sentence[sen_iter]
        word_2 = sentence[sen_iter+1]
        word_3 = sentence[sen_iter+2]
        tag_1 = word_1
        tag_2 = word_2
        tag_3 = word_3

        if word_1 in word_to_tag.keys():
            tag_1 = word_to_tag[word_1]
        
        if word_2 in word_to_tag.keys():
            tag_2 = word_to_tag[word_2]
            
        if word_3 in word_to_tag.keys():
            tag_3 = word_to_tag[word_3]
            
        tritag = (tag_1, tag_2, tag_3)

        if len(word_1) > K:
            word_1 = word_1[-K:]
        if len(word_2) > K:
            word_2 = word_2[-K:]
        if len(word_3) > K:
            word_3 = word_3[-K:]

        three_gram = (word_1, word_2, word_3)
 

        result_words = test_three_gram(one_grams, two_grams, three_grams, lambdas_words, three_gram, number_of_words)
        result_tags = test_three_gram(unitags, bitags, tritags, lambdas_tags, tritag, number_of_tags)
        
        result += gamma*result_words + (1-gamma)*result_tags

        sen_iter +=1
    
    return result

# %% [markdown]
# # Train

# %%
path_supertags = '/content/drive/My Drive/Colab Notebooks/NLP/Dane/Copy of supertags.txt'
path_corpus = '/content/polish_corpora.txt'

num_lines = 19000000
num_train_lines = 1000000
num_val_lines = 30000
K = 3 


word_to_tag = load_supertags(path_supertags)
three_grams, two_grams, one_grams, number_of_words, unitags, bitags, tritags, number_of_tags = load_corpus('/content/polish_corpora.txt', word_to_tag, num_lines, K)
train_corpus_sufixes, train_corpus_tags = train_three_grams('/content/polish_corpora.txt', num_lines, num_train_lines, K)
val = load_val(path_corpus, start_line=num_lines+num_train_lines, end=num_val_lines)

# %%
val = load_val(path_corpus, start_line=num_lines+num_train_lines, end=60000)

# %%
lb1 = train_lambdas(one_grams, two_grams, three_grams, train_corpus_sufixes, number_of_words)
lb2 = train_lambdas(unitags, bitags, tritags, train_corpus_tags, number_of_tags)
# Out:
# 19999190it [02:37, 8637.94it/s]

# %%
print("Word Lambdas from Training {}".format(lb1))
print("Tag Lambdas from Training {}".format(lb2))
# Out:
# Word Lambdas from Training [0.14409179 0.23723645 0.61867176]
# Tag Lambdas from Training [0.17975885 0.23110095 0.5891402 ]

# %%
def test_corpus(test_data, verbose, one_grams, two_grams, three_grams, lb1, number_of_words,\
                unitags, bitags, tritags, lb2, number_of_tags, word_to_tag, K, gamma):

    points = 0
    iter = 1
    for line in test_data:

        sentences = line.split(".")

        for sen in sentences:

            sen = sen.lower().split()

            if len(sen) > 6 or len(sen) < 3: continue

            res = []
            res_values = []
            perms = list(permutations(sen))
            for perm in list(perms):
                res.append([perm])
                res_values.append(test_sentence(one_grams, two_grams, three_grams, lb1, number_of_words,\
                                                unitags, bitags, tritags, lb2, number_of_tags, word_to_tag, perm, K, gamma))

            res = np.array(res)
            res_values = np.array(res_values)

            best = np.argsort(res_values)[::-1]
            points += 1/(np.where(best == 0)[0][0]+1)
            if verbose:
                print("------------Sentence {}-------------------- ".format(iter))
                print("1 order: {} | Val: {}".format(" ".join(res[best[0]][0]), res_values[best[0]]))
                print("2 order: {} | Val: {}".format(" ".join(res[best[1]][0]), res_values[best[1]]))
                print("3 order: {} | Val: {}".format(" ".join(res[best[2]][0]), res_values[best[2]]))
                print("4 order: {} | Val: {}".format(" ".join(res[best[3]][0]), res_values[best[3]]))
                print("5 order: {} | Val: {}".format(" ".join(res[best[4]][0]), res_values[best[4]]))
                print("True order: {}".format(" ".join(sen)))
                print("position of true order: {}".format(np.where(best == 0)[0][0]+1))
                print("Points for sentence: {}".format(1/(np.where(best == 0)[0][0]+1)))
                print("\n")
            
            iter +=1
    print("All points: {}, Gamma: {}".format(points/iter, gamma))

# %%
gamma = np.arange(0,1,0.05)
for gamma in gamma:
    test_corpus(val, False, one_grams, two_grams, three_grams, lb1, number_of_words, 
                unitags, bitags, tritags, lb2, number_of_tags, word_to_tag, K, gamma)
# Out:
# All points: 0.17963094976114505, Gamma: 0.0
# All points: 0.23792604693754413, Gamma: 0.05
# All points: 0.25431601719436925, Gamma: 0.1
# All points: 0.2637442430516763, Gamma: 0.15000000000000002
# All points: 0.27202294872180593, Gamma: 0.2
# All points: 0.27870518205354616, Gamma: 0.25
# All points: 0.2847861776136745, Gamma: 0.30000000000000004
# All points: 0.2895599645952951, Gamma: 0.35000000000000003
# All points: 0.29317283737258715, Gamma: 0.4
# All points: 0.29647131801275506, Gamma: 0.45
# All points: 0.2991174511898849, Gamma: 0.5
# All points: 0.3008727054668867, Gamma: 0.55
# All points: 0.303045493332454, Gamma: 0.6000000000000001
# All points: 0.3043362871602421, Gamma: 0.65
# All points: 0.3041599067287659, Gamma: 0.7000000000000001
# All points: 0.30245075022352996, Gamma: 0.75
# All points: 0.3028125830807928, Gamma: 0.8
# All points: 0.3023296151116362, Gamma: 0.8500000000000001
# All points: 0.3004626662723437, Gamma: 0.9
# All points: 0.299969127560412, Gamma: 0.9500000000000001

# %% [markdown]
# # Test

# %%
test_path = '/content/test.txt'
test = load_val(test_path, start_line=-1, end=100000000)
test_corpus(test, True, one_grams, two_grams, three_grams, lb1, number_of_words, 
            unitags, bitags, tritags, lb2, number_of_tags, word_to_tag, K, 0.65)
# Out:
# ------------Sentence 1--------------------
# 1 order: to nasz przedmiot przetwarzanie języka naturalnego | Val: 0.32575546876294287
# 2 order: to przetwarzanie języka naturalnego nasz przedmiot | Val: 0.31409702461025324
# 3 order: przetwarzanie języka naturalnego nasz przedmiot to | Val: 0.3068748782202812
# 4 order: to nasz przedmiot przetwarzanie naturalnego języka | Val: 0.28167462186369485
# 5 order: to języka naturalnego nasz przedmiot przetwarzanie | Val: 0.27366039930018554
# True order: nasz przedmiot to przetwarzanie języka naturalnego
# position of true order: 15
# Points for sentence: 0.06666666666666667
#
#
# ------------Sentence 2--------------------
# 1 order: michaliszyn jakub prowadzi jedną grupę | Val: 0.13990501559806934
# 2 order: jakub prowadzi jedną grupę michaliszyn | Val: 0.13722303324486193
# 3 order: michaliszyn prowadzi jedną grupę jakub | Val: 0.13683168837835816
# 4 order: michaliszyn jakub jedną grupę prowadzi | Val: 0.13679542395172592
# 5 order: jakub jedną grupę prowadzi michaliszyn | Val: 0.1367043051405763
# True order: jedną grupę prowadzi jakub michaliszyn
# position of true order: 30
# Points for sentence: 0.03333333333333333
#
#
# ------------Sentence 3--------------------
# 1 order: wykładowcą jest paweł rychlikowski | Val: 0.17427872883244006
# 2 order: jest paweł rychlikowski wykładowcą | Val: 0.1250096065987439
# 3 order: wykładowcą rychlikowski jest paweł | Val: 0.08384414881807441
# 4 order: paweł wykładowcą rychlikowski jest | Val: 0.08306670647891663
# 5 order: rychlikowski wykładowcą jest paweł | Val: 0.05638299778428463
# True order: wykładowcą jest paweł rychlikowski
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 4--------------------
# 1 order: będą listy ćwiczeniowe i pracowniowe to | Val: 0.19221585229962537
# 2 order: to będą listy ćwiczeniowe i pracowniowe | Val: 0.1922128836944691
# 3 order: będą to listy ćwiczeniowe i pracowniowe | Val: 0.176310232414121
# 4 order: to listy ćwiczeniowe i pracowniowe będą | Val: 0.17474339967284833
# 5 order: to będą ćwiczeniowe i pracowniowe listy | Val: 0.13338748609831547
# True order: będą to listy ćwiczeniowe i pracowniowe
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 5--------------------
# 1 order: będą listy ćwiczeniowe i pracowniowe to | Val: 0.19221585229962537
# 2 order: to będą listy ćwiczeniowe i pracowniowe | Val: 0.1922128836944691
# 3 order: będą to listy ćwiczeniowe i pracowniowe | Val: 0.176310232414121
# 4 order: to listy ćwiczeniowe i pracowniowe będą | Val: 0.17474339967284833
# 5 order: to będą ćwiczeniowe i pracowniowe listy | Val: 0.13338748609831547
# True order: będą to listy pracowniowe i ćwiczeniowe
# position of true order: 20
# Points for sentence: 0.05
#
#
# ------------Sentence 6--------------------
# 1 order: również aktywności dodatkowe mogą pojawiać się | Val: 0.2100266027195737
# 2 order: mogą pojawiać się również aktywności dodatkowe | Val: 0.20038016520862048
# 3 order: również mogą pojawiać się aktywności dodatkowe | Val: 0.19988682799406093
# 4 order: również mogą pojawiać się dodatkowe aktywności | Val: 0.19871197024058307
# 5 order: dodatkowe również mogą pojawiać się aktywności | Val: 0.1945153320746711
# True order: mogą się pojawiać również dodatkowe aktywności
# position of true order: 180
# Points for sentence: 0.005555555555555556
#
#
# ------------Sentence 7--------------------
# 1 order: aktywności te będą premiowane | Val: 0.208062723905455
# 2 order: te będą premiowane aktywności | Val: 0.19822618395391364
# 3 order: te aktywności będą premiowane | Val: 0.14763757182742593
# 4 order: aktywności będą premiowane te | Val: 0.14434559142672104
# 5 order: aktywności te premiowane będą | Val: 0.046427582937480526
# True order: te aktywności będą premiowane
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 8--------------------
# 1 order: przykłąd quizy zdalnej na platformie na | Val: 0.4923470343618816
# 2 order: przykłąd quizy zdalnej na platformie na | Val: 0.4923470343618816
# 3 order: na przykłąd quizy zdalnej na platformie | Val: 0.47420575727424336
# 4 order: na przykłąd quizy zdalnej na platformie | Val: 0.47420575727424336
# 5 order: przykłąd quizy zdalnej na na platformie | Val: 0.4566968976942147
# True order: na przykłąd quizy na platformie zdalnej
# position of true order: 90
# Points for sentence: 0.011111111111111112
#
#
# ------------Sentence 9--------------------
# 1 order: też miniprojekty rozważamy na temat wykładu | Val: 0.08235168427187217
# 2 order: miniprojekty rozważamy na temat wykładu też | Val: 0.08229363006937543
# 3 order: miniprojekty też wykładu rozważamy na temat | Val: 0.07552050964921773
# 4 order: miniprojekty też wykładu temat rozważamy na | Val: 0.07542222341742656
# 5 order: miniprojekty rozważamy też wykładu na temat | Val: 0.07498200191851791
# True order: rozważamy też miniprojekty na temat wykładu
# position of true order: 152
# Points for sentence: 0.006578947368421052
#
#
# ------------Sentence 10--------------------
# 1 order: zajęcia przeznaczone są na konkretne zadania | Val: 0.3052764266921202
# 2 order: zajęcia są przeznaczone na konkretne zadania | Val: 0.29239490046319616
# 3 order: zajęcia przeznaczone są na zadania konkretne | Val: 0.27102234262972463
# 4 order: zajęcia są przeznaczone na zadania konkretne | Val: 0.2597461018251578
# 5 order: zadania są przeznaczone na zajęcia konkretne | Val: 0.2424332266265233
# True order: zadania są przeznaczone na konkretne zajęcia
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 11--------------------
# 1 order: ćwiczenia zaczynają się w sali seminaryjnej | Val: 0.3597496912799316
# 2 order: sali zaczynają się w seminaryjnej ćwiczenia | Val: 0.311918486839137
# 3 order: ćwiczenia sali zaczynają się w seminaryjnej | Val: 0.31001581791183697
# 4 order: ćwiczenia seminaryjnej sali zaczynają się w | Val: 0.3050955385503067
# 5 order: sali zaczynają się w ćwiczenia seminaryjnej | Val: 0.30090765752279813
# True order: ćwiczenia zaczynają się w sali seminaryjnej
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 12--------------------
# 1 order: trybie tylko w tak stacjonarnym jest | Val: 0.21004236634502732
# 2 order: jest trybie tylko w tak stacjonarnym | Val: 0.20513704294104484
# 3 order: trybie jest tylko w tak stacjonarnym | Val: 0.17758719246257082
# 4 order: jest tylko w tak stacjonarnym trybie | Val: 0.17699826502057692
# 5 order: tylko tak jest w trybie stacjonarnym | Val: 0.15266657378814025
# True order: jest tak tylko w trybie stacjonarnym
# position of true order: 23
# Points for sentence: 0.043478260869565216
#
#
# ------------Sentence 13--------------------
# 1 order: pracownia polega na indywidualnych konsutlacjach | Val: 0.5047275258106033
# 2 order: pracownia polega na konsutlacjach indywidualnych | Val: 0.3611678594336496
# 3 order: polega pracownia na indywidualnych konsutlacjach | Val: 0.30849993897669714
# 4 order: polega na indywidualnych konsutlacjach pracownia | Val: 0.29108213177077136
# 5 order: pracownia na indywidualnych konsutlacjach polega | Val: 0.28293606337557803
# True order: pracownia polega na indywidualnych konsutlacjach
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 14--------------------
# 1 order: rozwiązań rozmawiamy na temat tam | Val: 0.06315361111688302
# 2 order: rozmawiamy tam na temat rozwiązań | Val: 0.06117479361808647
# 3 order: tam rozwiązań rozmawiamy na temat | Val: 0.05966699558698395
# 4 order: rozwiązań rozmawiamy tam na temat | Val: 0.05870774938701797
# 5 order: tam rozmawiamy na temat rozwiązań | Val: 0.05680747419686308
# True order: rozmawiamy tam na temat rozwiązań
# position of true order: 2
# Points for sentence: 0.5
#
#
# ------------Sentence 15--------------------
# 1 order: tryb zależy od zajęć sytuacji epidemiologicznej | Val: 0.2945053192485175
# 2 order: zajęć sytuacji epidemiologicznej tryb zależy od | Val: 0.28718847707114453
# 3 order: tryb zajęć sytuacji epidemiologicznej zależy od | Val: 0.26802233701595196
# 4 order: zajęć sytuacji epidemiologicznej zależy od tryb | Val: 0.2632524244190228
# 5 order: zależy tryb zajęć sytuacji epidemiologicznej od | Val: 0.22714924293385477
# True order: tryb zajęć zależy od sytuacji epidemiologicznej
# position of true order: 79
# Points for sentence: 0.012658227848101266
#
#
# ------------Sentence 16--------------------
# 1 order: od też formalnych wymogów zależy | Val: 0.2431238557908406
# 2 order: zależy od też formalnych wymogów | Val: 0.24163834067951095
# 3 order: wymogów zależy od też formalnych | Val: 0.23243275950841116
# 4 order: też zależy od wymogów formalnych | Val: 0.21181601862629312
# 5 order: zależy też od wymogów formalnych | Val: 0.2041819710001297
# True order: zależy też od wymogów formalnych
# position of true order: 5
# Points for sentence: 0.2
#
#
# ------------Sentence 17--------------------
# 1 order: władz od decyzji zależy również | Val: 0.08900208096523851
# 2 order: zależy również władz od decyzji | Val: 0.08540458090490805
# 3 order: również władz od decyzji zależy | Val: 0.08439329836703438
# 4 order: władz od decyzji również zależy | Val: 0.08364147762628424
# 5 order: również zależy władz od decyzji | Val: 0.08049092483839676
# True order: zależy również od decyzji władz
# position of true order: 9
# Points for sentence: 0.1111111111111111
#
#
# ------------Sentence 18--------------------
# 1 order: możliwości studentów prowadzących uwzględnia się i | Val: 0.28534377271020045
# 2 order: i możliwości studentów prowadzących uwzględnia się | Val: 0.28031969892458874
# 3 order: możliwości studentów prowadzących i uwzględnia się | Val: 0.27075789426353414
# 4 order: możliwości uwzględnia się studentów prowadzących i | Val: 0.2485826556771345
# 5 order: i studentów prowadzących możliwości uwzględnia się | Val: 0.24804330104365002
# True order: uwzględnia się możliwości studentów i prowadzących
# position of true order: 311
# Points for sentence: 0.003215434083601286
#
#
# ------------Sentence 19--------------------
# 1 order: prowadzącemu studenci dostarczają przed ćwiczeniami deklaracje | Val: 0.18639657470410623
# 2 order: deklaracje prowadzącemu studenci dostarczają przed ćwiczeniami | Val: 0.18595017510400957
# 3 order: deklaracje studenci dostarczają przed ćwiczeniami prowadzącemu | Val: 0.17701910649998137
# 4 order: prowadzącemu deklaracje studenci dostarczają przed ćwiczeniami | Val: 0.17676670134949923
# 5 order: prowadzącemu studenci dostarczają deklaracje przed ćwiczeniami | Val: 0.16179879023155905
# True order: przed ćwiczeniami studenci dostarczają prowadzącemu deklaracje
# position of true order: 192
# Points for sentence: 0.005208333333333333
#
#
# ------------Sentence 20--------------------
# 1 order: numery ona zawiera zadań | Val: 0.11638099869698236
# 2 order: zadań numery ona zawiera | Val: 0.11595993414843883
# 3 order: zadań ona zawiera numery | Val: 0.01240628575792221
# 4 order: zawiera ona numery zadań | Val: 0.012344148625061802
# 5 order: zadań zawiera ona numery | Val: 0.008180342952732783
# True order: zawiera ona numery zadań
# position of true order: 4
# Points for sentence: 0.25
#
#
# ------------Sentence 21--------------------
# 1 order: tablicy studenci pokazują przy rozwiązania | Val: 0.08002040983806946
# 2 order: przy studenci pokazują rozwiązania tablicy | Val: 0.07107678784160162
# 3 order: studenci tablicy pokazują przy rozwiązania | Val: 0.06865770687769557
# 4 order: tablicy przy studenci pokazują rozwiązania | Val: 0.06775761159618716
# 5 order: rozwiązania tablicy przy studenci pokazują | Val: 0.0651542151682804
# True order: studenci pokazują rozwiązania przy tablicy
# position of true order: 24
# Points for sentence: 0.041666666666666664
#
#
# ------------Sentence 22--------------------
# 1 order: mu coś dodatkowo odejmuje się | Val: 0.24192541219253685
# 2 order: odejmuje coś dodatkowo mu się | Val: 0.24143555771199762
# 3 order: coś mu się dodatkowo odejmuje | Val: 0.23892402916216152
# 4 order: dodatkowo mu się coś odejmuje | Val: 0.2375043397643277
# 5 order: coś dodatkowo odejmuje się mu | Val: 0.23541654644386317
# True order: dodatkowo coś mu się odejmuje
# position of true order: 13
# Points for sentence: 0.07692307692307693
#
#
# ------------Sentence 23--------------------
# 1 order: zadania należy rozwiązywać samodzielnie | Val: 0.08391918633509311
# 2 order: samodzielnie należy rozwiązywać zadania | Val: 0.06501162203467227
# 3 order: zadania należy samodzielnie rozwiązywać | Val: 0.06327993714224185
# 4 order: należy rozwiązywać samodzielnie zadania | Val: 0.06083282728030388
# 5 order: zadania samodzielnie należy rozwiązywać | Val: 0.053787400006070636
# True order: zadania należy rozwiązywać samodzielnie
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 24--------------------
# 1 order: prowadzący ocenia poprawność rozwiązania | Val: 0.1293088080053856
# 2 order: prowadzący poprawność rozwiązania ocenia | Val: 0.12390649493557562
# 3 order: ocenia poprawność rozwiązania prowadzący | Val: 0.11961498408005086
# 4 order: ocenia prowadzący poprawność rozwiązania | Val: 0.11297229351318941
# 5 order: prowadzący poprawność ocenia rozwiązania | Val: 0.09130167471871736
# True order: prowadzący ocenia poprawność rozwiązania
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 25--------------------
# 1 order: liście podany jest na termin każdej | Val: 0.24462442847951132
# 2 order: każdej liście podany jest na termin | Val: 0.24271546064663904
# 3 order: liście podany jest na każdej termin | Val: 0.24128573245636417
# 4 order: termin liście podany jest na każdej | Val: 0.240305013671248
# 5 order: termin podany jest na liście każdej | Val: 0.24027809365602526
# True order: na każdej liście podany jest termin
# position of true order: 16
# Points for sentence: 0.0625
#
#
# ------------Sentence 26--------------------
# 1 order: dużo dostajemy za poprawne rozwiązanie punktów | Val: 0.22014355400882785
# 2 order: dostajemy za poprawne rozwiązanie punktów dużo | Val: 0.21638417787103958
# 3 order: dostajemy za poprawne rozwiązanie dużo punktów | Val: 0.2105298440454629
# 4 order: dostajemy dużo za poprawne rozwiązanie punktów | Val: 0.21006045483272537
# 5 order: dużo za poprawne rozwiązanie punktów dostajemy | Val: 0.20753640551966715
# True order: za poprawne rozwiązanie dostajemy dużo punktów
# position of true order: 15
# Points for sentence: 0.06666666666666667
#
#
# ------------Sentence 27--------------------
# 1 order: spóźnione zadania będą sprawdzane nie | Val: 0.2062823516310902
# 2 order: zadania będą sprawdzane nie spóźnione | Val: 0.20492530719354654
# 3 order: zadania będą sprawdzane spóźnione nie | Val: 0.19350686587508745
# 4 order: nie spóźnione zadania będą sprawdzane | Val: 0.1901558100808444
# 5 order: spóźnione nie zadania będą sprawdzane | Val: 0.18340770252477284
# True order: spóźnione zadania nie będą sprawdzane
# position of true order: 14
# Points for sentence: 0.07142857142857142
#
#
# ------------Sentence 28--------------------
# 1 order: ma dłuższy termin pierwsza lista | Val: 0.35816278081629205
# 2 order: pierwsza dłuższy termin ma lista | Val: 0.24450847018761782
# 3 order: lista pierwsza dłuższy termin ma | Val: 0.24184878628349318
# 4 order: pierwsza dłuższy termin lista ma | Val: 0.24051747093113665
# 5 order: ma pierwsza dłuższy termin lista | Val: 0.23919309878504655
# True order: pierwsza lista ma dłuższy termin
# position of true order: 9
# Points for sentence: 0.1111111111111111
#
#
# ------------Sentence 29--------------------
# 1 order: zgodnie wystawia się z tabelką ocenę | Val: 0.2499577779905353
# 2 order: ocenę zgodnie wystawia się z tabelką | Val: 0.244689622667639
# 3 order: tabelką ocenę zgodnie wystawia się z | Val: 0.2344114777221732
# 4 order: ocenę zgodnie wystawia się tabelką z | Val: 0.2269213889186934
# 5 order: zgodnie wystawia się tabelką z ocenę | Val: 0.22175742410593985
# True order: ocenę wystawia się zgodnie z tabelką
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 30--------------------
# 1 order: 50 daje dostateczną ocenę punktów | Val: 0.1688978832797859
# 2 order: daje dostateczną ocenę punktów 50 | Val: 0.16768021517282708
# 3 order: punktów daje dostateczną ocenę 50 | Val: 0.15910980432737193
# 4 order: 50 punktów daje dostateczną ocenę | Val: 0.15901534822523886
# 5 order: daje dostateczną ocenę 50 punktów | Val: 0.15804209849591938
# True order: 50 punktów daje ocenę dostateczną
# position of true order: 19
# Points for sentence: 0.05263157894736842
#
#
# ------------Sentence 31--------------------
# 1 order: daje 120 punktów ocenę bardzo dobrą | Val: 0.4060124080489884
# 2 order: ocenę bardzo dobrą daje 120 punktów | Val: 0.40379278914505773
# 3 order: 120 punktów daje ocenę bardzo dobrą | Val: 0.30414813308884103
# 4 order: punktów daje ocenę bardzo dobrą 120 | Val: 0.30298731464323025
# 5 order: 120 daje ocenę bardzo dobrą punktów | Val: 0.2979092362064361
# True order: 120 punktów daje ocenę bardzo dobrą
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 32--------------------
# 1 order: zostanie powyższa tabelka przeskalowana | Val: 0.18370939086395083
# 2 order: powyższa tabelka zostanie przeskalowana | Val: 0.18159677348411635
# 3 order: przeskalowana zostanie powyższa tabelka | Val: 0.17709805944114976
# 4 order: tabelka zostanie przeskalowana powyższa | Val: 0.17171371370166183
# 5 order: przeskalowana powyższa tabelka zostanie | Val: 0.15959977628353034
# True order: powyższa tabelka zostanie przeskalowana
# position of true order: 2
# Points for sentence: 0.5
#
#
# ------------Sentence 33--------------------
# 1 order: podamy coś w pierwszym tygodniu zajęć | Val: 0.25845813530774503
# 2 order: zajęć podamy coś w pierwszym tygodniu | Val: 0.25585309821684143
# 3 order: coś zajęć podamy w pierwszym tygodniu | Val: 0.22337348259599427
# 4 order: zajęć podamy w pierwszym tygodniu coś | Val: 0.223251627944799
# 5 order: coś podamy w pierwszym tygodniu zajęć | Val: 0.19803562435282634
# True order: w pierwszym tygodniu zajęć coś podamy
# position of true order: 19
# Points for sentence: 0.05263157894736842
#
#
# ------------Sentence 34--------------------
# 1 order: umożliwiające dodatkowe zwolnienie zasady z egzaminu | Val: 0.223035022952019
# 2 order: zasady z egzaminu umożliwiające dodatkowe zwolnienie | Val: 0.20411577138379405
# 3 order: umożliwiające dodatkowe zwolnienie z egzaminu zasady | Val: 0.178658484107582
# 4 order: zasady umożliwiające dodatkowe zwolnienie z egzaminu | Val: 0.17838585461663461
# 5 order: zasady z egzaminu umożliwiające zwolnienie dodatkowe | Val: 0.16288229422481906
# True order: dodatkowe zasady umożliwiające zwolnienie z egzaminu
# position of true order: 45
# Points for sentence: 0.022222222222222223
#
#
# ------------Sentence 35--------------------
# 1 order: osób dotyczą z dużą liczbą punktów | Val: 0.30003891271563127
# 2 order: dotyczą osób z dużą liczbą punktów | Val: 0.2924094213926134
# 3 order: dotyczą z dużą liczbą punktów osób | Val: 0.27768273903171165
# 4 order: osób z dużą liczbą punktów dotyczą | Val: 0.27664719249481035
# 5 order: z dużą liczbą punktów osób dotyczą | Val: 0.27547656453037944
# True order: dotyczą osób z dużą liczbą punktów
# position of true order: 2
# Points for sentence: 0.5
#
#
# ------------Sentence 36--------------------
# 1 order: też specjalne zadanie można rozwiązać | Val: 0.2879565774812296
# 2 order: można też rozwiązać specjalne zadanie | Val: 0.23086907895434516
# 3 order: też można rozwiązać specjalne zadanie | Val: 0.22751602982218624
# 4 order: specjalne też zadanie można rozwiązać | Val: 0.22493516123736196
# 5 order: specjalne można rozwiązać też zadanie | Val: 0.18424276556182495
# True order: można rozwiązać też zadanie specjalne
# position of true order: 45
# Points for sentence: 0.022222222222222223
#
#
# ------------Sentence 37--------------------
# 1 order: zależy wielu czynników od egzaminu forma | Val: 0.1868808470254448
# 2 order: forma zależy wielu czynników od egzaminu | Val: 0.1854956827000402
# 3 order: forma zależy od egzaminu wielu czynników | Val: 0.16457060940036933
# 4 order: zależy wielu czynników forma od egzaminu | Val: 0.16344995662852618
# 5 order: forma od egzaminu zależy wielu czynników | Val: 0.16136364583613724
# True order: forma egzaminu zależy od wielu czynników
# position of true order: 23
# Points for sentence: 0.043478260869565216
#
#
# ------------Sentence 38--------------------
# 1 order: należy wariantów różnych spodziewać się | Val: 0.28275229629138454
# 2 order: należy się spodziewać wariantów różnych | Val: 0.24606081343722658
# 3 order: należy spodziewać się wariantów różnych | Val: 0.23359325538100706
# 4 order: należy wariantów różnych się spodziewać | Val: 0.22753176873344563
# 5 order: spodziewać należy wariantów różnych się | Val: 0.22549980570644465
# True order: należy się spodziewać różnych wariantów
# position of true order: 13
# Points for sentence: 0.07692307692307693
#
#
# ------------Sentence 39--------------------
# 1 order: nie wykluczamy indywidualnego egzaminu ustnego | Val: 0.21738375488549927
# 2 order: nie wykluczamy ustnego egzaminu indywidualnego | Val: 0.21738375488549927
# 3 order: wykluczamy indywidualnego egzaminu ustnego nie | Val: 0.21017102008620586
# 4 order: wykluczamy ustnego egzaminu indywidualnego nie | Val: 0.21017102008620586
# 5 order: wykluczamy nie indywidualnego egzaminu ustnego | Val: 0.19165581630034148
# True order: nie wykluczamy indywidualnego egzaminu ustnego
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 40--------------------
# 1 order: są jaś i małgosia tutaj też | Val: 0.8600143019946879
# 2 order: tutaj też są jaś i małgosia | Val: 0.8567998121153262
# 3 order: są jaś i małgosia też tutaj | Val: 0.8537990987501294
# 4 order: też tutaj są jaś i małgosia | Val: 0.852307241228978
# 5 order: tutaj są jaś i małgosia też | Val: 0.8503866788384267
# True order: jaś i małgosia też są tutaj
# position of true order: 40
# Points for sentence: 0.025
#
#
# ------------Sentence 41--------------------
# 1 order: puchatek przybędą nie z prosiaczkiem | Val: 0.07531808422550976
# 2 order: przybędą nie z prosiaczkiem puchatek | Val: 0.05693082154250171
# 3 order: puchatek przybędą nie prosiaczkiem z | Val: 0.052354710789561526
# 4 order: przybędą puchatek nie z prosiaczkiem | Val: 0.05198461391303297
# 5 order: puchatek nie z prosiaczkiem przybędą | Val: 0.04709206754118774
# True order: puchatek z prosiaczkiem nie przybędą
# position of true order: 21
# Points for sentence: 0.047619047619047616
#
#
# ------------Sentence 42--------------------
# 1 order: odpoczywał chory raz kotek i był | Val: 0.1697463534792484
# 2 order: był odpoczywał chory raz kotek i | Val: 0.16912817111062312
# 3 order: był kotek i odpoczywał chory raz | Val: 0.1628113824561722
# 4 order: odpoczywał chory raz był kotek i | Val: 0.1618090997080664
# 5 order: odpoczywał chory raz i kotek był | Val: 0.15268064657574484
# True order: raz kotek był chory i odpoczywał
# position of true order: 84
# Points for sentence: 0.011904761904761904
#
#
# ------------Sentence 43--------------------
# 1 order: relacji definicja trudna równoważności jest nie | Val: 0.3840617800751356
# 2 order: trudna równoważności jest nie definicja relacji | Val: 0.37316518994848386
# 3 order: trudna równoważności jest nie relacji definicja | Val: 0.36690851877551384
# 4 order: definicja trudna równoważności jest nie relacji | Val: 0.36684631797853856
# 5 order: relacji trudna równoważności jest nie definicja | Val: 0.36204974537792406
# True order: definicja relacji równoważności nie jest trudna
# position of true order: 315
# Points for sentence: 0.0031746031746031746
#
#
# ------------Sentence 44--------------------
# 1 order: hipoteza continuum jest niezależna od aksjomatów | Val: 0.21687774006849553
# 2 order: aksjomatów hipoteza continuum jest niezależna od | Val: 0.20228438678682586
# 3 order: continuum jest niezależna od aksjomatów hipoteza | Val: 0.1604030215609235
# 4 order: aksjomatów continuum jest niezależna od hipoteza | Val: 0.15061118756157849
# 5 order: continuum jest niezależna od hipoteza aksjomatów | Val: 0.15046138826983535
# True order: hipoteza continuum jest niezależna od aksjomatów
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 45--------------------
# 1 order: radości teoria daje wiele mnogości | Val: 0.11845397624105675
# 2 order: mnogości teoria daje wiele radości | Val: 0.11845397624105675
# 3 order: daje wiele mnogości teoria radości | Val: 0.11224351472785246
# 4 order: daje wiele radości teoria mnogości | Val: 0.11224351472785246
# 5 order: teoria mnogości daje wiele radości | Val: 0.10975291010500259
# True order: teoria mnogości daje wiele radości
# position of true order: 5
# Points for sentence: 0.2
#
#
# ------------Sentence 46--------------------
# 1 order: nie trudne jest programowanie szczególnie | Val: 0.3572220576394148
# 2 order: szczególnie trudne jest programowanie nie | Val: 0.3571085817816506
# 3 order: nie szczególnie trudne jest programowanie | Val: 0.3508771676372145
# 4 order: trudne jest programowanie szczególnie nie | Val: 0.34790006187067746
# 5 order: szczególnie nie trudne jest programowanie | Val: 0.34305641488637695
# True order: programowanie nie jest szczególnie trudne
# position of true order: 30
# Points for sentence: 0.03333333333333333
#
#
# ------------Sentence 47--------------------
# 1 order: życiu przydaje się w rachunek prawdopodobieństwa | Val: 0.40156536395179127
# 2 order: prawdopodobieństwa życiu przydaje się w rachunek | Val: 0.3870985479138078
# 3 order: rachunek życiu przydaje się w prawdopodobieństwa | Val: 0.3775669126166863
# 4 order: życiu przydaje się w prawdopodobieństwa rachunek | Val: 0.3767579800318136
# 5 order: rachunek prawdopodobieństwa życiu przydaje się w | Val: 0.37532497732710624
# True order: rachunek prawdopodobieństwa przydaje się w życiu
# position of true order: 22
# Points for sentence: 0.045454545454545456
#
#
# ------------Sentence 48--------------------
# 1 order: strawił smoka zanim rycerze księżniczkę osaczyli | Val: 0.4387367521005919
# 2 order: strawił osaczyli księżniczkę smoka zanim rycerze | Val: 0.43751630209543624
# 3 order: smoka zanim rycerze księżniczkę osaczyli strawił | Val: 0.43704449973027926
# 4 order: strawił smoka zanim rycerze osaczyli księżniczkę | Val: 0.4358243664440016
# 5 order: smoka zanim rycerze osaczyli księżniczkę strawił | Val: 0.4351081112273777
# True order: rycerze osaczyli smoka zanim strawił księżniczkę
# position of true order: 79
# Points for sentence: 0.012658227848101266
#
#
# ------------Sentence 49--------------------
# 1 order: zdania chyba już przestać wymyślać należy | Val: 0.105240271292291
# 2 order: należy zdania chyba już przestać wymyślać | Val: 0.10481945056698823
# 3 order: już przestać wymyślać zdania chyba należy | Val: 0.09719080280488038
# 4 order: należy chyba już przestać wymyślać zdania | Val: 0.09668773308417096
# 5 order: chyba należy już przestać wymyślać zdania | Val: 0.09480460959947594
# True order: chyba należy już przestać wymyślać zdania
# position of true order: 5
# Points for sentence: 0.2
#
#
# All points: 0.2372836163851478, Gamma: 0.65
