# %%
import numpy as np
from itertools import permutations
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/Colab Notebooks/NLP/Dane/Copy of polish_corpora.zip'
# Out:
# Archive:  /content/drive/My Drive/Colab Notebooks/NLP/Dane/Copy of polish_corpora.zip
#   inflating: polish_corpora.txt

# %% [markdown]
# # Data Loading

# %%
def load_supertags(path):

    file = open(path, 'r')
    word_to_tag = {}

    for line in file:

        word, tag = line.split(" ")
        if tag[-1] == "\n": tag = tag[:-1]

        word_to_tag[word.lower()] = tag
    
    file.close()
    return word_to_tag

# %%
def load_corpus(path, word_to_tag, num_lines, K):
    file = open(path, "r")

    one_grams = {}
    two_grams = {}
    three_gram = {}

    unitags = {}
    bitags = {}
    tritags = {}

    number_of_words = 0
    number_of_tags = 0
    num_line_iter = 0 
    
    for _, line in enumerate(tqdm(file)):
        
        line = line.lower().split(" ")

        if len(line) < 3: continue

        number_of_words += len(line)
        line_iter = 0

        # Trigrams/tritags
        while line_iter < len(line) - 2:

            word_1 = line[line_iter]
            word_2 = line[line_iter+1]
            word_3 = line[line_iter+2]

            if word_3[-1] == '\n': word_3 = word_3[:-1] 

            #unitags, bitags, trigrams
            tag_1 = None
            tag_2 = None
            tag_3 = None

            if word_1 in word_to_tag.keys():
                tag_1 = word_to_tag[word_1]
                key_1 = tag_1
                number_of_tags += 1

                if key_1 in unitags.keys():
                    unitags[key_1] += 1
                else:
                    unitags[key_1] = 1
    
                if word_2 in word_to_tag.keys():
                    tag_2 = word_to_tag[word_2]
                    key_2 = (tag_1, tag_2)

                    if key_2 in bitags.keys():
                        bitags[key_2] += 1
                    else:
                        bitags[key_2] = 1
        
                    if word_3 in word_to_tag.keys():
                        tag_3 = word_to_tag[word_3]
                        key_3 = (tag_1, tag_2, tag_3)

                        if key_3 in tritags.keys():
                            tritags[key_3] += 1
                        else:
                            tritags[key_3] = 1


            #unisufixes, bisufiexes, trisufixes
            if len(word_1) > K:
                word_1 = word_1[-K:]
            if len(word_2) > K:
                word_2 = word_2[-K:]
            if len(word_3) > K:
                word_3 = word_3[-K:]

            key_1 = word_1
            key_2 = (word_1, word_2)
            key_3 = (word_1, word_2, word_3)

            if key_1 in one_grams.keys():
                one_grams[key_1] += 1
            else:
                one_grams[key_1] = 1

            if key_2 in two_grams.keys():
                two_grams[key_2] += 1
            else:
                two_grams[key_2] = 1

            if key_3 in three_gram.keys():
                three_gram[key_3] += 1
            else:
                three_gram[key_3] = 1

            line_iter += 1


        if tag_2 and tag_3:
                number_of_tags += 2
                key_2 = (tag_2, tag_3)
                if key_2 in bitags.keys():
                    bitags[key_2] += 1
                else:
                    bitags[key_2] = 1

                key_1 = tag_2
                if key_1 in unitags.keys():
                    unitags[key_1] += 1
                else:
                    unitags[key_1] = 1

                key_1 = tag_3
                if key_1 in unitags.keys():
                    unitags[key_1] += 1
                else:
                    unitags[key_1] = 1

        key_2 = (word_2, word_3)
        if key_2 in two_grams.keys():
            two_grams[key_2] += 1
        else:
            two_grams[key_2] = 1

        key_1 = word_2
        if key_1 in one_grams.keys():
             one_grams[key_1] += 1
        else:
            one_grams[key_1] = 1

        key_1 = word_3
        if key_1 in one_grams.keys():
            one_grams[key_1] += 1
        else:
            one_grams[key_1] = 1


        num_line_iter += 1
        if num_line_iter == num_lines: break

    return three_gram, two_grams, one_grams, number_of_words, unitags, bitags, tritags, number_of_tags

# %%
def train_three_grams(path, start_line, num_lines, K):
    file = open(path, "r")

    three_gram = {}
    tritags = {}
    num_line_iter = 0

    for line in tqdm(file):
        if num_line_iter < start_line:
            num_line_iter += 1
            continue
        
        line = line.lower().split(" ")

        if len(line) < 3: continue

        line_iter = 0

        while line_iter < len(line) - 2:

            word_1 = line[line_iter]
            word_2 = line[line_iter+1]
            word_3 = line[line_iter+2]

            if word_3[-1] == '\n': word_3 = word_3[:-1] 

            if word_1 in word_to_tag.keys() and word_2 in word_to_tag.keys() and word_3 in word_to_tag.keys():
                key_3 = (word_to_tag[word_1], word_to_tag[word_2], word_to_tag[word_3])

                if key_3 in tritags.keys():
                    tritags[key_3] += 1
                else:
                    tritags[key_3] = 1

            if len(word_1) > K:
                word_1 = word_1[-K:]
            if len(word_2) > K:
                word_2 = word_2[-K:]
            if len(word_3) > K:
                word_3 = word_3[-K:]

            key_3 = (word_1, word_2, word_3)
            
            if key_3 in three_gram.keys():
                three_gram[key_3] += 1
            else:
                three_gram[key_3] = 1
            
            line_iter += 1

        num_line_iter += 1
        if num_line_iter == start_line + num_lines: break

    return three_gram, tritags

# %%
def load_val(path, start_line=0,end=10000):

    val = []
    file = open(path, 'r')
    for iter, line in enumerate(file):
        if iter < start_line: continue
        val.append(line)
        if iter - start_line == end: break
        
    return val

# %% [markdown]
# #Lambda Training

# %%
def train_lambdas(one_grams, two_grams, three_grams, train_three_grams, number_of_words):

    lambdas = np.array([0, 0, 0])

    for three_gram in train_three_grams.keys():

        p3 = 0
        p2 = 0
        p1 = 0

        if three_gram in three_grams:

            p3 = three_grams[three_gram]/two_grams[three_gram[:2]]

        if three_gram[1:] in two_grams:

            p2 = two_grams[three_gram[1:]]/one_grams[three_gram[1]]

        if three_gram[2] in one_grams:

            p1 = one_grams[three_gram[2]]/number_of_words
        
        results = (p1, p2, p3)
        
        f = lambda i: results[i]
        best = max(range(len(results)), key=f)

        lambdas[best] += train_three_grams[three_gram]

    return lambdas/np.sum(lambdas)

# %% [markdown]
# # Testing Functions

# %%
def test_three_gram(one_grams, two_grams, three_grams, lambdas, three_gram, number_of_one_grams):

    result = 0

    if three_gram in three_grams:

        result += lambdas[2] * three_grams[three_gram]/two_grams[three_gram[:2]]

    if three_gram[1:] in two_grams:

        result += lambdas[1] * two_grams[three_gram[1:]]/one_grams[three_gram[1]]

    if three_gram[2] in one_grams:

        result += lambdas[0] * one_grams[three_gram[2]]/number_of_words

    return result

# %%
def test_sentence(one_grams, two_grams, three_grams, lambdas_words, number_of_words, unitags, bitags, tritags, lambdas_tags, number_of_tags, word_to_tag, sentence, K, gamma):

    sen_iter = 0
    result = 0

    while sen_iter < len(sentence) - 2:
        
        result_tags = 0
        result_words = 0
        word_1 = sentence[sen_iter]
        word_2 = sentence[sen_iter+1]
        word_3 = sentence[sen_iter+2]
        tag_1 = word_1
        tag_2 = word_2
        tag_3 = word_3

        if word_1 in word_to_tag.keys():
            tag_1 = word_to_tag[word_1]
        
        if word_2 in word_to_tag.keys():
            tag_2 = word_to_tag[word_2]
            
        if word_3 in word_to_tag.keys():
            tag_3 = word_to_tag[word_3]
            
        tritag = (tag_1, tag_2, tag_3)

        if len(word_1) > K:
            word_1 = word_1[-K:]
        if len(word_2) > K:
            word_2 = word_2[-K:]
        if len(word_3) > K:
            word_3 = word_3[-K:]

        three_gram = (word_1, word_2, word_3)
 

        result_words = test_three_gram(one_grams, two_grams, three_grams, lambdas_words, three_gram, number_of_words)
        result_tags = test_three_gram(unitags, bitags, tritags, lambdas_tags, tritag, number_of_tags)
        
        result += gamma*result_words + (1-gamma)*result_tags

        sen_iter +=1
    
    return result

# %% [markdown]
# # Train

# %%
path_supertags = '/content/drive/My Drive/Colab Notebooks/NLP/Dane/Copy of supertags.txt'
path_corpus = '/content/polish_corpora.txt'

num_lines = 19000000
num_train_lines = 1000000
num_val_lines = 30000
K = 3 


word_to_tag = load_supertags(path_supertags)
three_grams, two_grams, one_grams, number_of_words, unitags, bitags, tritags, number_of_tags = load_corpus('/content/polish_corpora.txt', word_to_tag, num_lines, K)
train_corpus_sufixes, train_corpus_tags = train_three_grams('/content/polish_corpora.txt', num_lines, num_train_lines, K)
val = load_val(path_corpus, start_line=num_lines+num_train_lines, end=num_val_lines)

# %%
lb1 = train_lambdas(one_grams, two_grams, three_grams, train_corpus_sufixes, number_of_words)
lb2 = train_lambdas(unitags, bitags, tritags, train_corpus_tags, number_of_tags)

# %%
print("Word Lambdas from Training {}".format(lb1))
print("Tag Lambdas from Training {}".format(lb2))

# %%
def test_corpus(test_data, verbose, one_grams, two_grams, three_grams, lb1, number_of_words,\
                unitags, bitags, tritags, lb2, number_of_tags, word_to_tag, K, gamma):

    points = 0
    iter = 1
    for line in test_data:

        sentences = line.split(".")

        for sen in sentences:

            sen = sen.lower().split()

            #if len(sen) > 6 or len(sen) < 3: continue

            res = []
            res_values = []
            perms = list(permutations(sen))
            for perm in list(perms):
                res.append([perm])
                res_values.append(test_sentence(one_grams, two_grams, three_grams, lb1, number_of_words,\
                                                unitags, bitags, tritags, lb2, number_of_tags, word_to_tag, perm, K, gamma))

            res = np.array(res)
            res_values = np.array(res_values)

            best = np.argsort(res_values)[::-1]
            points += 1/(np.where(best == 0)[0][0]+1)
            if verbose:
                print("------------Sentence {}-------------------- ".format(iter))
                print("1 order: {} | Val: {}".format(" ".join(res[best[0]][0]), res_values[best[0]]))
                print("2 order: {} | Val: {}".format(" ".join(res[best[1]][0]), res_values[best[1]]))
                print("3 order: {} | Val: {}".format(" ".join(res[best[2]][0]), res_values[best[2]]))
                print("4 order: {} | Val: {}".format(" ".join(res[best[3]][0]), res_values[best[3]]))
                print("5 order: {} | Val: {}".format(" ".join(res[best[4]][0]), res_values[best[4]]))
                print("True order: {}".format(" ".join(sen)))
                print("position of true order: {}".format(np.where(best == 0)[0][0]+1))
                print("Points for sentence: {}".format(1/(np.where(best == 0)[0][0]+1)))
                print("\n")
            
            iter +=1
    print("All points: {}, Gamma: {}".format(points, gamma))

# %%
gamma = np.arange(0,1,0.05)
for gamma in gamma:
    test_corpus(val, False, one_grams, two_grams, three_grams, lb1, number_of_words, 
                unitags, bitags, tritags, lb2, number_of_tags, word_to_tag, K, gamma)
# Out:
# All points: 0.17701912129372996, Gamma: 0.0
# All points: 0.23682702764155072, Gamma: 0.05
# All points: 0.25287389600745946, Gamma: 0.1
# All points: 0.2619882760083669, Gamma: 0.15000000000000002
# All points: 0.26962069371685043, Gamma: 0.2
# All points: 0.2756516587567429, Gamma: 0.25
# All points: 0.28043306874706697, Gamma: 0.30000000000000004
# All points: 0.2852798116312918, Gamma: 0.35000000000000003
# All points: 0.29088500341162477, Gamma: 0.4
# All points: 0.2933406873142839, Gamma: 0.45
# All points: 0.2955588933707904, Gamma: 0.5
# All points: 0.2971220422588652, Gamma: 0.55
# All points: 0.2992117367195587, Gamma: 0.6000000000000001
# All points: 0.3000548942437848, Gamma: 0.65
# All points: 0.3027560188422148, Gamma: 0.7000000000000001
# All points: 0.3015726803568406, Gamma: 0.75
# All points: 0.3015231781448256, Gamma: 0.8
# All points: 0.30147313050133523, Gamma: 0.8500000000000001
# All points: 0.3002353038754604, Gamma: 0.9
# All points: 0.29878695220250945, Gamma: 0.9500000000000001

# %% [markdown]
# # Test

# %%
test_path = '/content/test.txt'
test = load_val(test_path, start_line=-1, end=100000000)
test_corpus(test, True, one_grams, two_grams, three_grams, lb1, number_of_words, 
            unitags, bitags, tritags, lb2, number_of_tags, word_to_tag, K, 0.75)
# Out:
# ------------Sentence 1--------------------
# 1 order: to nasz przedmiot przetwarzanie języka naturalnego | Val: 0.30573414413025096
# 2 order: to przetwarzanie języka naturalnego nasz przedmiot | Val: 0.2722896562714722
# 3 order: przetwarzanie języka naturalnego nasz przedmiot to | Val: 0.2672923826688738
# 4 order: nasz to przedmiot przetwarzanie języka naturalnego | Val: 0.24361447717548834
# 5 order: nasz przedmiot to przetwarzanie języka naturalnego | Val: 0.24103735735543938
# True order: nasz przedmiot to przetwarzanie języka naturalnego
# position of true order: 5
# Points for sentence: 0.2
#
#
# ------------Sentence 2--------------------
# 1 order: michaliszyn jakub prowadzi jedną grupę | Val: 0.10284369326703399
# 2 order: michaliszyn jakub jedną grupę prowadzi | Val: 0.10174163683540058
# 3 order: jakub jedną grupę prowadzi michaliszyn | Val: 0.10167353731549551
# 4 order: jakub prowadzi jedną grupę michaliszyn | Val: 0.10085477148580714
# 5 order: michaliszyn prowadzi jedną grupę jakub | Val: 0.10054695108847128
# True order: jedną grupę prowadzi jakub michaliszyn
# position of true order: 24
# Points for sentence: 0.041666666666666664
#
#
# ------------Sentence 3--------------------
# 1 order: wykładowcą jest paweł rychlikowski | Val: 0.17098817086899523
# 2 order: jest paweł rychlikowski wykładowcą | Val: 0.13570299082547835
# 3 order: wykładowcą rychlikowski jest paweł | Val: 0.09586561029950744
# 4 order: paweł wykładowcą rychlikowski jest | Val: 0.09541688971033103
# 5 order: rychlikowski wykładowcą jest paweł | Val: 0.042631638954449234
# True order: wykładowcą jest paweł rychlikowski
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 4--------------------
# 1 order: pozostałe dwie grupy prowadzi również pan paweł | Val: 0.14155172094962332
# 2 order: pozostałe dwie grupy prowadzi również paweł pan | Val: 0.13900802622628092
# 3 order: pozostałe dwie grupy również pan paweł prowadzi | Val: 0.13700911817995623
# 4 order: również pan paweł prowadzi pozostałe dwie grupy | Val: 0.13597754029509712
# 5 order: pozostałe również pan paweł prowadzi dwie grupy | Val: 0.13543964857332808
# True order: pan paweł prowadzi również dwie pozostałe grupy
# position of true order: 694
# Points for sentence: 0.001440922190201729
#
#
# ------------Sentence 5--------------------
# 1 order: listy będą pojawiać na zadań się stronie wykładu | Val: 0.2808844073118514
# 2 order: listy zadań się stronie wykładu będą pojawiać na | Val: 0.28070496890002267
# 3 order: zadań się stronie wykładu listy będą pojawiać na | Val: 0.280295507421001
# 4 order: listy będą pojawiać się na stronie wykładu zadań | Val: 0.2802935588458216
# 5 order: zadań się stronie będą pojawiać na listy wykładu | Val: 0.27990697001224635
# True order: na stronie wykładu będą pojawiać się listy zadań
# position of true order: 4485
# Points for sentence: 0.0002229654403567447
#
#
# ------------Sentence 6--------------------
# 1 order: będą listy ćwiczeniowe i pracowniowe to | Val: 0.19052436571657064
# 2 order: to będą listy ćwiczeniowe i pracowniowe | Val: 0.19026270816180385
# 3 order: będą to listy ćwiczeniowe i pracowniowe | Val: 0.1763152953276545
# 4 order: to listy ćwiczeniowe i pracowniowe będą | Val: 0.17512836022169914
# 5 order: będą listy to ćwiczeniowe i pracowniowe | Val: 0.14395487065828133
# True order: będą to listy ćwiczeniowe i pracowniowe
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 7--------------------
# 1 order: będą listy ćwiczeniowe i pracowniowe to | Val: 0.19052436571657064
# 2 order: to będą listy ćwiczeniowe i pracowniowe | Val: 0.19026270816180385
# 3 order: będą to listy ćwiczeniowe i pracowniowe | Val: 0.1763152953276545
# 4 order: to listy ćwiczeniowe i pracowniowe będą | Val: 0.17512836022169914
# 5 order: będą listy to ćwiczeniowe i pracowniowe | Val: 0.14395487065828133
# True order: będą to listy pracowniowe i ćwiczeniowe
# position of true order: 13
# Points for sentence: 0.07692307692307693
#
#
# ------------Sentence 8--------------------
# 1 order: również aktywności dodatkowe mogą pojawiać się | Val: 0.21212249781690568
# 2 order: mogą pojawiać się również aktywności dodatkowe | Val: 0.2048902078108068
# 3 order: również mogą pojawiać się aktywności dodatkowe | Val: 0.20371002587756057
# 4 order: również mogą pojawiać się dodatkowe aktywności | Val: 0.20370148814078326
# 5 order: dodatkowe również mogą pojawiać się aktywności | Val: 0.2014917978264723
# True order: mogą się pojawiać również dodatkowe aktywności
# position of true order: 153
# Points for sentence: 0.006535947712418301
#
#
# ------------Sentence 9--------------------
# 1 order: aktywności te będą premiowane | Val: 0.20310209670787907
# 2 order: te będą premiowane aktywności | Val: 0.19272532908990217
# 3 order: te aktywności będą premiowane | Val: 0.14387706727779037
# 4 order: aktywności będą premiowane te | Val: 0.140665993551441
# 5 order: aktywności te premiowane będą | Val: 0.045719618226166436
# True order: te aktywności będą premiowane
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 10--------------------
# 1 order: przykłąd quizy zdalnej na platformie na | Val: 0.5432113965242535
# 2 order: przykłąd quizy zdalnej na platformie na | Val: 0.5432113965242535
# 3 order: na przykłąd quizy zdalnej na platformie | Val: 0.5286050402904289
# 4 order: na przykłąd quizy zdalnej na platformie | Val: 0.5286050402904289
# 5 order: przykłąd quizy zdalnej na na platformie | Val: 0.51508590971876
# True order: na przykłąd quizy na platformie zdalnej
# position of true order: 89
# Points for sentence: 0.011235955056179775
#
#
# ------------Sentence 11--------------------
# 1 order: też miniprojekty rozważamy na temat wykładu | Val: 0.07029304620733487
# 2 order: miniprojekty rozważamy na temat wykładu też | Val: 0.07020777923901503
# 3 order: miniprojekty rozważamy też wykładu na temat | Val: 0.06910737145806434
# 4 order: miniprojekty też wykładu na temat rozważamy | Val: 0.06777840769258352
# 5 order: rozważamy też wykładu na temat miniprojekty | Val: 0.06764806210878366
# True order: rozważamy też miniprojekty na temat wykładu
# position of true order: 122
# Points for sentence: 0.00819672131147541
#
#
# ------------Sentence 12--------------------
# 1 order: je zapowiadamy tygodniowym wyprzedzeniem z co najmniej | Val: 0.7591612510561211
# 2 order: zapowiadamy tygodniowym wyprzedzeniem z co najmniej je | Val: 0.7587896035872876
# 3 order: zapowiadamy tygodniowym wyprzedzeniem je z co najmniej | Val: 0.755384226163143
# 4 order: z co najmniej je zapowiadamy tygodniowym wyprzedzeniem | Val: 0.7524889316993701
# 5 order: je z co najmniej zapowiadamy tygodniowym wyprzedzeniem | Val: 0.7476573666737352
# True order: zapowiadamy je z co najmniej tygodniowym wyprzedzeniem
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 13--------------------
# 1 order: zajęcia przeznaczone są na konkretne zadania | Val: 0.30182045718433115
# 2 order: zajęcia są przeznaczone na konkretne zadania | Val: 0.26928514535339004
# 3 order: zajęcia przeznaczone są na zadania konkretne | Val: 0.2516283018734007
# 4 order: na konkretne zadania zajęcia przeznaczone są | Val: 0.22916554208786827
# 5 order: zajęcia są przeznaczone na zadania konkretne | Val: 0.2210346870372706
# True order: zadania są przeznaczone na konkretne zajęcia
# position of true order: 16
# Points for sentence: 0.0625
#
#
# ------------Sentence 14--------------------
# 1 order: ćwiczenia zaczynają się w sali seminaryjnej | Val: 0.33459301593309493
# 2 order: sali zaczynają się w seminaryjnej ćwiczenia | Val: 0.2961346535655992
# 3 order: ćwiczenia sali zaczynają się w seminaryjnej | Val: 0.2941098596881113
# 4 order: ćwiczenia seminaryjnej sali zaczynają się w | Val: 0.2863084385342715
# 5 order: sali zaczynają się w ćwiczenia seminaryjnej | Val: 0.28539220137132343
# True order: ćwiczenia zaczynają się w sali seminaryjnej
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 15--------------------
# 1 order: trybie tylko w tak stacjonarnym jest | Val: 0.20320671010996522
# 2 order: jest trybie tylko w tak stacjonarnym | Val: 0.1986226123832267
# 3 order: trybie jest tylko w tak stacjonarnym | Val: 0.16986067853743875
# 4 order: jest tylko w tak stacjonarnym trybie | Val: 0.16922689600999435
# 5 order: tylko tak jest w trybie stacjonarnym | Val: 0.1535104873184851
# True order: jest tak tylko w trybie stacjonarnym
# position of true order: 28
# Points for sentence: 0.03571428571428571
#
#
# ------------Sentence 16--------------------
# 1 order: pracowni pozostałe domyślnie zajęcia zaczynają się w | Val: 0.3980775424053349
# 2 order: zajęcia zaczynają się w pracowni pozostałe domyślnie | Val: 0.39546160699741856
# 3 order: pracowni pozostałe zajęcia zaczynają się w domyślnie | Val: 0.3474580272599224
# 4 order: pracowni zajęcia zaczynają się w pozostałe domyślnie | Val: 0.3434559042772089
# 5 order: zajęcia zaczynają się w pozostałe domyślnie pracowni | Val: 0.34338184271631483
# True order: pozostałe zajęcia domyślnie zaczynają się w pracowni
# position of true order: 95
# Points for sentence: 0.010526315789473684
#
#
# ------------Sentence 17--------------------
# 1 order: pracownia polega na indywidualnych konsutlacjach | Val: 0.5590320393910636
# 2 order: pracownia polega na konsutlacjach indywidualnych | Val: 0.39611269985666686
# 3 order: polega pracownia na indywidualnych konsutlacjach | Val: 0.3446390449940471
# 4 order: polega na indywidualnych konsutlacjach pracownia | Val: 0.33234224814146873
# 5 order: pracownia na indywidualnych konsutlacjach polega | Val: 0.3238894264248344
# True order: pracownia polega na indywidualnych konsutlacjach
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 18--------------------
# 1 order: rozwiązań rozmawiamy na temat tam | Val: 0.05802416102291947
# 2 order: tam rozwiązań rozmawiamy na temat | Val: 0.055574066870834375
# 3 order: tam rozmawiamy na temat rozwiązań | Val: 0.04886597250183854
# 4 order: rozwiązań tam rozmawiamy na temat | Val: 0.04620418217960881
# 5 order: rozwiązań tam temat rozmawiamy na | Val: 0.04563148864338128
# True order: rozmawiamy tam na temat rozwiązań
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 19--------------------
# 1 order: studenci zadań przedstawiają podczas ćwiczeń pisemne rozwiązania | Val: 0.4249388203126928
# 2 order: studenci zadań przedstawiają ćwiczeń pisemne rozwiązania podczas | Val: 0.4225186941530206
# 3 order: ćwiczeń pisemne rozwiązania studenci zadań przedstawiają podczas | Val: 0.42216723995292205
# 4 order: ćwiczeń pisemne rozwiązania podczas studenci zadań przedstawiają | Val: 0.4220308260797436
# 5 order: podczas ćwiczeń pisemne rozwiązania studenci zadań przedstawiają | Val: 0.4167013907740149
# True order: podczas ćwiczeń studenci przedstawiają pisemne rozwiązania zadań
# position of true order: 621
# Points for sentence: 0.001610305958132045
#
#
# ------------Sentence 20--------------------
# 1 order: tryb zależy od zajęć sytuacji epidemiologicznej | Val: 0.31166093390874483
# 2 order: zajęć sytuacji epidemiologicznej tryb zależy od | Val: 0.3061329988113682
# 3 order: tryb zajęć sytuacji epidemiologicznej zależy od | Val: 0.2812321261689488
# 4 order: zajęć sytuacji epidemiologicznej zależy od tryb | Val: 0.2774303967164216
# 5 order: zależy tryb zajęć sytuacji epidemiologicznej od | Val: 0.23588746582673548
# True order: tryb zajęć zależy od sytuacji epidemiologicznej
# position of true order: 79
# Points for sentence: 0.012658227848101266
#
#
# ------------Sentence 21--------------------
# 1 order: też zależy od wymogów formalnych | Val: 0.2067436206070173
# 2 order: zależy też od wymogów formalnych | Val: 0.19945295783051709
# 3 order: też wymogów formalnych zależy od | Val: 0.18574190032531496
# 4 order: też od wymogów formalnych zależy | Val: 0.17118733794979288
# 5 order: od wymogów formalnych też zależy | Val: 0.16966247792281633
# True order: zależy też od wymogów formalnych
# position of true order: 2
# Points for sentence: 0.5
#
#
# ------------Sentence 22--------------------
# 1 order: władz od decyzji zależy również | Val: 0.10439557555086858
# 2 order: władz od decyzji również zależy | Val: 0.0983059888439348
# 3 order: zależy również władz od decyzji | Val: 0.09762915305764998
# 4 order: również władz od decyzji zależy | Val: 0.09711997695088076
# 5 order: również zależy władz od decyzji | Val: 0.09401973148322096
# True order: zależy również od decyzji władz
# position of true order: 10
# Points for sentence: 0.1
#
#
# ------------Sentence 23--------------------
# 1 order: możliwości studentów prowadzących i uwzględnia się | Val: 0.28470489486645806
# 2 order: możliwości studentów prowadzących uwzględnia się i | Val: 0.2846179462990399
# 3 order: i możliwości studentów prowadzących uwzględnia się | Val: 0.2781164228979136
# 4 order: możliwości studentów prowadzących się i uwzględnia | Val: 0.2566571100684088
# 5 order: się możliwości i uwzględnia studentów prowadzących | Val: 0.25492173117438205
# True order: uwzględnia się możliwości studentów i prowadzących
# position of true order: 305
# Points for sentence: 0.003278688524590164
#
#
# ------------Sentence 24--------------------
# 1 order: semestru może zmieniać się on w trakcie | Val: 0.3160751010814117
# 2 order: on może zmieniać się w trakcie semestru | Val: 0.308229089783711
# 3 order: on semestru może zmieniać się w trakcie | Val: 0.30651233296945934
# 4 order: semestru może zmieniać się w trakcie on | Val: 0.30605674578759284
# 5 order: semestru on może zmieniać się w trakcie | Val: 0.30145621736412964
# True order: może się on zmieniać w trakcie semestru
# position of true order: 839
# Points for sentence: 0.0011918951132300357
#
#
# ------------Sentence 25--------------------
# 1 order: prowadzącemu studenci dostarczają przed ćwiczeniami deklaracje | Val: 0.20590892222191662
# 2 order: deklaracje prowadzącemu studenci dostarczają przed ćwiczeniami | Val: 0.20547383690045698
# 3 order: deklaracje studenci dostarczają przed ćwiczeniami prowadzącemu | Val: 0.18581074227692068
# 4 order: prowadzącemu deklaracje studenci dostarczają przed ćwiczeniami | Val: 0.18546689804929556
# 5 order: prowadzącemu studenci dostarczają deklaracje przed ćwiczeniami | Val: 0.17282456797665535
# True order: przed ćwiczeniami studenci dostarczają prowadzącemu deklaracje
# position of true order: 194
# Points for sentence: 0.005154639175257732
#
#
# ------------Sentence 26--------------------
# 1 order: numery ona zawiera zadań | Val: 0.08010742023841355
# 2 order: zadań numery ona zawiera | Val: 0.0798890918394441
# 3 order: zadań ona zawiera numery | Val: 0.011108600583837365
# 4 order: zawiera ona numery zadań | Val: 0.00915778600954182
# 5 order: numery zadań ona zawiera | Val: 0.007894602841928985
# True order: zawiera ona numery zadań
# position of true order: 4
# Points for sentence: 0.25
#
#
# ------------Sentence 27--------------------
# 1 order: przy studenci pokazują rozwiązania tablicy | Val: 0.07613874606140461
# 2 order: tablicy przy studenci pokazują rozwiązania | Val: 0.07364901467591134
# 3 order: przy studenci pokazują tablicy rozwiązania | Val: 0.06872428359924648
# 4 order: rozwiązania tablicy przy studenci pokazują | Val: 0.06800617496473058
# 5 order: tablicy rozwiązania przy studenci pokazują | Val: 0.06682183237786213
# True order: studenci pokazują rozwiązania przy tablicy
# position of true order: 18
# Points for sentence: 0.05555555555555555
#
#
# ------------Sentence 28--------------------
# 1 order: umie jeżeli student nie jest źle , | Val: 0.331664285597382
# 2 order: jeżeli student nie jest źle , umie | Val: 0.3246956809587093
# 3 order: jeżeli student nie umie jest źle , | Val: 0.3129256427362322
# 4 order: jest źle , jeżeli student nie umie | Val: 0.30098717183619056
# 5 order: umie jest źle , jeżeli student nie | Val: 0.2934518800412395
# True order: jest źle , jeżeli student nie umie
# position of true order: 4
# Points for sentence: 0.25
#
#
# ------------Sentence 29--------------------
# 1 order: odejmuje coś dodatkowo mu się | Val: 0.25424006332455523
# 2 order: dodatkowo mu się coś odejmuje | Val: 0.2541380390108722
# 3 order: dodatkowo mu się odejmuje coś | Val: 0.24481529059080753
# 4 order: coś dodatkowo mu się odejmuje | Val: 0.24456448108574155
# 5 order: coś odejmuje dodatkowo mu się | Val: 0.24433139893708775
# True order: dodatkowo coś mu się odejmuje
# position of true order: 13
# Points for sentence: 0.07692307692307693
#
#
# ------------Sentence 30--------------------
# 1 order: zajęć pracowni podczas zadania można oddawać na | Val: 0.2706987625979912
# 2 order: pracowni podczas zadania można oddawać na zajęć | Val: 0.2668189216103848
# 3 order: pracowni podczas zadania można oddawać zajęć na | Val: 0.26106954365767904
# 4 order: zajęć można oddawać na pracowni podczas zadania | Val: 0.26095979802221264
# 5 order: pracowni podczas zadania zajęć można oddawać na | Val: 0.2562493526926285
# True order: zadania można oddawać podczas zajęć na pracowni
# position of true order: 170
# Points for sentence: 0.0058823529411764705
#
#
# ------------Sentence 31--------------------
# 1 order: zadania należy rozwiązywać samodzielnie | Val: 0.08775295508117728
# 2 order: samodzielnie należy rozwiązywać zadania | Val: 0.0688692637975816
# 3 order: należy rozwiązywać samodzielnie zadania | Val: 0.06295107508455358
# 4 order: zadania należy samodzielnie rozwiązywać | Val: 0.06279895249656607
# 5 order: zadania samodzielnie należy rozwiązywać | Val: 0.057515147626317854
# True order: zadania należy rozwiązywać samodzielnie
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 32--------------------
# 1 order: prowadzący poprawność rozwiązania ocenia | Val: 0.126007597035625
# 2 order: prowadzący ocenia poprawność rozwiązania | Val: 0.11914545985365135
# 3 order: ocenia prowadzący poprawność rozwiązania | Val: 0.11320283714445095
# 4 order: ocenia poprawność rozwiązania prowadzący | Val: 0.11177534885210352
# 5 order: prowadzący poprawność ocenia rozwiązania | Val: 0.10269514973245744
# True order: prowadzący ocenia poprawność rozwiązania
# position of true order: 2
# Points for sentence: 0.5
#
#
# ------------Sentence 33--------------------
# 1 order: czasem mogą pojawić się informacje o regułach | Val: 0.3611025323808311
# 2 order: mogą pojawić się informacje o regułach czasem | Val: 0.34487583022263035
# 3 order: czasem informacje o regułach mogą pojawić się | Val: 0.319773301132529
# 4 order: czasem regułach informacje o pojawić się mogą | Val: 0.3049728641201715
# 5 order: regułach informacje o pojawić się czasem mogą | Val: 0.3048416418007325
# True order: czasem mogą pojawić się informacje o regułach
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 34--------------------
# 1 order: termin podany jest na liście każdej | Val: 0.22214729048653425
# 2 order: termin podany jest na każdej liście | Val: 0.22082678028591882
# 3 order: każdej termin podany jest na liście | Val: 0.20494448482950678
# 4 order: liście podany jest na termin każdej | Val: 0.19930435846147965
# 5 order: każdej liście podany jest na termin | Val: 0.1982317194250154
# True order: na każdej liście podany jest termin
# position of true order: 16
# Points for sentence: 0.0625
#
#
# ------------Sentence 35--------------------
# 1 order: dużo dostajemy za poprawne rozwiązanie punktów | Val: 0.21457922074692512
# 2 order: dostajemy za poprawne rozwiązanie punktów dużo | Val: 0.21136651406251722
# 3 order: dostajemy za poprawne rozwiązanie dużo punktów | Val: 0.20855418398576656
# 4 order: dostajemy dużo za poprawne rozwiązanie punktów | Val: 0.20622049431551906
# 5 order: dużo za poprawne rozwiązanie punktów dostajemy | Val: 0.2042877486059414
# True order: za poprawne rozwiązanie dostajemy dużo punktów
# position of true order: 15
# Points for sentence: 0.06666666666666667
#
#
# ------------Sentence 36--------------------
# 1 order: spóźnione zadania będą sprawdzane nie | Val: 0.20753993646758062
# 2 order: zadania będą sprawdzane nie spóźnione | Val: 0.20622872690106647
# 3 order: zadania będą sprawdzane spóźnione nie | Val: 0.19340432791788897
# 4 order: nie spóźnione zadania będą sprawdzane | Val: 0.18665922808091506
# 5 order: spóźnione nie zadania będą sprawdzane | Val: 0.18188902069288718
# True order: spóźnione zadania nie będą sprawdzane
# position of true order: 12
# Points for sentence: 0.08333333333333333
#
#
# ------------Sentence 37--------------------
# 1 order: ma dłuższy termin pierwsza lista | Val: 0.25567676295783914
# 2 order: pierwsza dłuższy termin ma lista | Val: 0.17597481689521077
# 3 order: lista pierwsza dłuższy termin ma | Val: 0.17408758055660897
# 4 order: pierwsza dłuższy termin lista ma | Val: 0.17207158420707375
# 5 order: ma pierwsza dłuższy termin lista | Val: 0.17103610759842292
# True order: pierwsza lista ma dłuższy termin
# position of true order: 9
# Points for sentence: 0.1111111111111111
#
#
# ------------Sentence 38--------------------
# 1 order: semestru musi być zmodyfikowana pod koniec zasada | Val: 0.48128468103467154
# 2 order: zasada semestru musi być zmodyfikowana pod koniec | Val: 0.471232850047025
# 3 order: semestru musi być zmodyfikowana zasada pod koniec | Val: 0.4146134370624519
# 4 order: semestru musi być zasada zmodyfikowana pod koniec | Val: 0.41205948262696884
# 5 order: koniec zasada semestru musi być zmodyfikowana pod | Val: 0.4082762679115958
# True order: zasada musi być zmodyfikowana pod koniec semestru
# position of true order: 14
# Points for sentence: 0.07142857142857142
#
#
# ------------Sentence 39--------------------
# 1 order: obowiązują inne zasady studenta w przypadku choroby | Val: 0.14734816429293907
# 2 order: choroby obowiązują inne zasady studenta w przypadku | Val: 0.14574907048151264
# 3 order: choroby przypadku w obowiązują inne zasady studenta | Val: 0.14567274975406103
# 4 order: studenta choroby przypadku w obowiązują inne zasady | Val: 0.14534273787444213
# 5 order: studenta obowiązują inne zasady choroby przypadku w | Val: 0.14367106762919113
# True order: w przypadku choroby studenta obowiązują inne zasady
# position of true order: 442
# Points for sentence: 0.0022624434389140274
#
#
# ------------Sentence 40--------------------
# 1 order: kwarantanny studenta w przypadku obowiązują inne zasady | Val: 0.18306385605810055
# 2 order: obowiązują inne zasady kwarantanny studenta w przypadku | Val: 0.17930568647123984
# 3 order: przypadku kwarantanny studenta w obowiązują inne zasady | Val: 0.15761960135446795
# 4 order: kwarantanny studenta w obowiązują inne zasady przypadku | Val: 0.15738024041721332
# 5 order: zasady obowiązują inne kwarantanny studenta w przypadku | Val: 0.1524108089432739
# True order: w przypadku kwarantanny studenta obowiązują inne zasady
# position of true order: 589
# Points for sentence: 0.001697792869269949
#
#
# ------------Sentence 41--------------------
# 1 order: obowiązują inne zasady studenta w przypadku izolacji | Val: 0.1604520131372423
# 2 order: studenta izolacji w przypadku obowiązują inne zasady | Val: 0.15922275371898548
# 3 order: studenta obowiązują inne zasady w przypadku izolacji | Val: 0.15640308296451144
# 4 order: studenta obowiązują inne zasady izolacji w przypadku | Val: 0.15604583205299047
# 5 order: obowiązują inne zasady studenta izolacji w przypadku | Val: 0.1559699955986436
# True order: w przypadku izolacji studenta obowiązują inne zasady
# position of true order: 177
# Points for sentence: 0.005649717514124294
#
#
# ------------Sentence 42--------------------
# 1 order: bez straty punktowej możliwe jest oddawanie zadań zaległych | Val: 0.9429721825045894
# 2 order: bez zadań zaległych straty punktowej możliwe jest oddawanie | Val: 0.9193141358298061
# 3 order: punktowej możliwe jest oddawanie zadań zaległych bez straty | Val: 0.9175611729413768
# 4 order: straty bez punktowej możliwe jest oddawanie zadań zaległych | Val: 0.9115647280959063
# 5 order: punktowej możliwe jest oddawanie zadań zaległych straty bez | Val: 0.9051340241668617
# True order: możliwe jest oddawanie zaległych zadań bez straty punktowej
# position of true order: 825
# Points for sentence: 0.0012121212121212121
#
#
# ------------Sentence 43--------------------
# 1 order: zgodnie wystawia się z tabelką ocenę | Val: 0.23187711851230974
# 2 order: tabelką ocenę zgodnie wystawia się z | Val: 0.2247588530020779
# 3 order: ocenę zgodnie wystawia się z tabelką | Val: 0.22385508001114693
# 4 order: ocenę zgodnie wystawia się tabelką z | Val: 0.22054401128525938
# 5 order: zgodnie wystawia się tabelką z ocenę | Val: 0.21670893136335684
# True order: ocenę wystawia się zgodnie z tabelką
# position of true order: 13
# Points for sentence: 0.07692307692307693
#
#
# ------------Sentence 44--------------------
# 1 order: daje 50 punktów ocenę dostateczną | Val: 0.15030800980649373
# 2 order: 50 punktów ocenę dostateczną daje | Val: 0.13079897370745522
# 3 order: punktów ocenę dostateczną daje 50 | Val: 0.13030768548676003
# 4 order: 50 daje punktów ocenę dostateczną | Val: 0.1294879459469855
# 5 order: daje punktów ocenę dostateczną 50 | Val: 0.12817090810905568
# True order: 50 punktów daje ocenę dostateczną
# position of true order: 20
# Points for sentence: 0.05
#
#
# ------------Sentence 45--------------------
# 1 order: daje 120 punktów ocenę bardzo dobrą | Val: 0.4952316615773185
# 2 order: ocenę bardzo dobrą daje 120 punktów | Val: 0.4934882509829161
# 3 order: 120 punktów daje ocenę bardzo dobrą | Val: 0.34532152010399975
# 4 order: punktów daje ocenę bardzo dobrą 120 | Val: 0.34441662568166176
# 5 order: daje ocenę bardzo dobrą 120 punktów | Val: 0.3415122522389845
# True order: 120 punktów daje ocenę bardzo dobrą
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 46--------------------
# 1 order: zostanie powyższa tabelka przeskalowana | Val: 0.13617801040679645
# 2 order: powyższa tabelka zostanie przeskalowana | Val: 0.1343778438511596
# 3 order: przeskalowana zostanie powyższa tabelka | Val: 0.1298916711097056
# 4 order: tabelka zostanie przeskalowana powyższa | Val: 0.1244473512713174
# 5 order: przeskalowana powyższa tabelka zostanie | Val: 0.11813305639831696
# True order: powyższa tabelka zostanie przeskalowana
# position of true order: 2
# Points for sentence: 0.5
#
#
# ------------Sentence 47--------------------
# 1 order: też może zostać przeskalowana z powodów innych | Val: 0.4326001062586695
# 2 order: przeskalowana może też zostać z powodów innych | Val: 0.42529766262070356
# 3 order: też z powodów innych może zostać przeskalowana | Val: 0.42443807609442186
# 4 order: może też zostać z powodów innych przeskalowana | Val: 0.42331183677170175
# 5 order: z powodów innych może zostać przeskalowana też | Val: 0.41716406497100433
# True order: może też zostać przeskalowana z innych powodów
# position of true order: 610
# Points for sentence: 0.001639344262295082
#
#
# ------------Sentence 48--------------------
# 1 order: podamy coś w pierwszym tygodniu zajęć | Val: 0.23802690770471457
# 2 order: zajęć podamy coś w pierwszym tygodniu | Val: 0.23615981607295788
# 3 order: coś zajęć podamy w pierwszym tygodniu | Val: 0.20452920190402318
# 4 order: zajęć podamy w pierwszym tygodniu coś | Val: 0.20437994734904372
# 5 order: coś podamy w pierwszym tygodniu zajęć | Val: 0.19065112051351624
# True order: w pierwszym tygodniu zajęć coś podamy
# position of true order: 19
# Points for sentence: 0.05263157894736842
#
#
# ------------Sentence 49--------------------
# 1 order: umożliwiające dodatkowe zwolnienie zasady z egzaminu | Val: 0.19189575492700292
# 2 order: zasady z egzaminu umożliwiające dodatkowe zwolnienie | Val: 0.17525981123313233
# 3 order: zasady umożliwiające dodatkowe zwolnienie z egzaminu | Val: 0.16394323543052639
# 4 order: umożliwiające dodatkowe zwolnienie z egzaminu zasady | Val: 0.16339154139955847
# 5 order: umożliwiające dodatkowe zwolnienie z zasady egzaminu | Val: 0.1501905004784095
# True order: dodatkowe zasady umożliwiające zwolnienie z egzaminu
# position of true order: 37
# Points for sentence: 0.02702702702702703
#
#
# ------------Sentence 50--------------------
# 1 order: osób dotyczą z dużą liczbą punktów | Val: 0.25376642240315117
# 2 order: dotyczą osób z dużą liczbą punktów | Val: 0.2446724264341598
# 3 order: dotyczą z dużą liczbą punktów osób | Val: 0.22863642009174387
# 4 order: osób z dużą liczbą punktów dotyczą | Val: 0.22802411119489246
# 5 order: z dużą liczbą punktów osób dotyczą | Val: 0.22702822779990936
# True order: dotyczą osób z dużą liczbą punktów
# position of true order: 2
# Points for sentence: 0.5
#
#
# ------------Sentence 51--------------------
# 1 order: też specjalne zadanie można rozwiązać | Val: 0.26221233984845127
# 2 order: można też rozwiązać specjalne zadanie | Val: 0.20193163453510118
# 3 order: specjalne też zadanie można rozwiązać | Val: 0.1998695995209851
# 4 order: też można rozwiązać specjalne zadanie | Val: 0.1974139144775564
# 5 order: rozwiązać można też specjalne zadanie | Val: 0.17310599844410185
# True order: można rozwiązać też zadanie specjalne
# position of true order: 45
# Points for sentence: 0.022222222222222223
#
#
# ------------Sentence 52--------------------
# 1 order: zależy wielu czynników od egzaminu forma | Val: 0.17799657236161856
# 2 order: forma zależy wielu czynników od egzaminu | Val: 0.17705045838573802
# 3 order: zależy wielu czynników forma od egzaminu | Val: 0.16110233338392033
# 4 order: forma od egzaminu zależy wielu czynników | Val: 0.1594759235633798
# 5 order: zależy wielu czynników od forma egzaminu | Val: 0.15107024807976116
# True order: forma egzaminu zależy od wielu czynników
# position of true order: 28
# Points for sentence: 0.03571428571428571
#
#
# ------------Sentence 53--------------------
# 1 order: należy wariantów różnych spodziewać się | Val: 0.29664116710198074
# 2 order: należy się spodziewać wariantów różnych | Val: 0.2563896598812163
# 3 order: należy wariantów różnych się spodziewać | Val: 0.24328742945507112
# 4 order: spodziewać należy wariantów różnych się | Val: 0.2412373292163078
# 5 order: się spodziewać należy wariantów różnych | Val: 0.23345374040675237
# True order: należy się spodziewać różnych wariantów
# position of true order: 13
# Points for sentence: 0.07692307692307693
#
#
# ------------Sentence 54--------------------
# 1 order: nie wykluczamy indywidualnego egzaminu ustnego | Val: 0.1977824285540397
# 2 order: nie wykluczamy ustnego egzaminu indywidualnego | Val: 0.1977824285540397
# 3 order: wykluczamy indywidualnego egzaminu ustnego nie | Val: 0.19006927840397092
# 4 order: wykluczamy ustnego egzaminu indywidualnego nie | Val: 0.19006927840397092
# 5 order: wykluczamy nie indywidualnego egzaminu ustnego | Val: 0.1774529041609753
# True order: nie wykluczamy indywidualnego egzaminu ustnego
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 55--------------------
# 1 order: są jaś i małgosia tutaj też | Val: 0.9402517999088472
# 2 order: tutaj też są jaś i małgosia | Val: 0.9399566575709017
# 3 order: są jaś i małgosia też tutaj | Val: 0.9361185443904729
# 4 order: też tutaj są jaś i małgosia | Val: 0.9354378431337564
# 5 order: tutaj są jaś i małgosia też | Val: 0.9336056947417811
# True order: jaś i małgosia też są tutaj
# position of true order: 41
# Points for sentence: 0.024390243902439025
#
#
# ------------Sentence 56--------------------
# 1 order: puchatek przybędą nie z prosiaczkiem | Val: 0.08490095464250633
# 2 order: przybędą nie z prosiaczkiem puchatek | Val: 0.06244494774207429
# 3 order: przybędą puchatek nie z prosiaczkiem | Val: 0.05912962948393931
# 4 order: puchatek przybędą nie prosiaczkiem z | Val: 0.055916335826279806
# 5 order: puchatek nie z prosiaczkiem przybędą | Val: 0.053679728553075005
# True order: puchatek z prosiaczkiem nie przybędą
# position of true order: 20
# Points for sentence: 0.05
#
#
# ------------Sentence 57--------------------
# 1 order: odpoczywał chory raz kotek i był | Val: 0.12641888638392795
# 2 order: był odpoczywał chory raz kotek i | Val: 0.12575165485775017
# 3 order: był kotek i odpoczywał chory raz | Val: 0.12357692900311265
# 4 order: odpoczywał chory raz był kotek i | Val: 0.12221813553905839
# 5 order: kotek był i odpoczywał chory raz | Val: 0.11295451336510683
# True order: raz kotek był chory i odpoczywał
# position of true order: 44
# Points for sentence: 0.022727272727272728
#
#
# ------------Sentence 58--------------------
# 1 order: był leżał w chory raz kotek i łóżeczku | Val: 0.24048097403400584
# 2 order: łóżeczku był leżał w chory raz kotek i | Val: 0.23941646946777315
# 3 order: łóżeczku chory raz leżał w kotek i był | Val: 0.23644125846684186
# 4 order: był łóżeczku chory raz leżał w kotek i | Val: 0.235390883338437
# 5 order: łóżeczku kotek i był leżał w chory raz | Val: 0.23475868989379062
# True order: raz kotek był chory i leżał w łóżeczku
# position of true order: 457
# Points for sentence: 0.002188183807439825
#
#
# ------------Sentence 59--------------------
# 1 order: relacji definicja trudna równoważności jest nie | Val: 0.4194256459176676
# 2 order: trudna równoważności jest nie definicja relacji | Val: 0.41516195990036686
# 3 order: definicja trudna równoważności jest nie relacji | Val: 0.4111345468665198
# 4 order: trudna równoważności jest nie relacji definicja | Val: 0.41094578850150026
# 5 order: relacji trudna równoważności jest nie definicja | Val: 0.4046042284627875
# True order: definicja relacji równoważności nie jest trudna
# position of true order: 327
# Points for sentence: 0.0030581039755351682
#
#
# ------------Sentence 60--------------------
# 1 order: hipoteza continuum jest niezależna od aksjomatów | Val: 0.23415651137872995
# 2 order: aksjomatów hipoteza continuum jest niezależna od | Val: 0.22171122687643385
# 3 order: continuum jest niezależna od aksjomatów hipoteza | Val: 0.1706294646937208
# 4 order: aksjomatów continuum jest niezależna od hipoteza | Val: 0.16292201992573027
# 5 order: hipoteza aksjomatów continuum jest niezależna od | Val: 0.16243239442731686
# True order: hipoteza continuum jest niezależna od aksjomatów
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 61--------------------
# 1 order: mnogości teoria daje wiele radości | Val: 0.12033740434263979
# 2 order: radości teoria daje wiele mnogości | Val: 0.12033740434263979
# 3 order: daje wiele mnogości teoria radości | Val: 0.11800217876571158
# 4 order: daje wiele radości teoria mnogości | Val: 0.11800217876571158
# 5 order: teoria radości daje wiele mnogości | Val: 0.11257063956729947
# True order: teoria mnogości daje wiele radości
# position of true order: 6
# Points for sentence: 0.16666666666666666
#
#
# ------------Sentence 62--------------------
# 1 order: nie trudne jest programowanie szczególnie | Val: 0.37561036875898884
# 2 order: szczególnie trudne jest programowanie nie | Val: 0.3754959759135849
# 3 order: nie szczególnie trudne jest programowanie | Val: 0.36583456231413336
# 4 order: trudne jest programowanie szczególnie nie | Val: 0.36369158849744115
# 5 order: szczególnie nie trudne jest programowanie | Val: 0.3602656717390365
# True order: programowanie nie jest szczególnie trudne
# position of true order: 39
# Points for sentence: 0.02564102564102564
#
#
# ------------Sentence 63--------------------
# 1 order: życiu przydaje się w rachunek prawdopodobieństwa | Val: 0.3859312892294793
# 2 order: prawdopodobieństwa życiu przydaje się w rachunek | Val: 0.37386600907341727
# 3 order: rachunek życiu przydaje się w prawdopodobieństwa | Val: 0.36726308029062993
# 4 order: życiu przydaje się w prawdopodobieństwa rachunek | Val: 0.3666005566110708
# 5 order: rachunek prawdopodobieństwa życiu przydaje się w | Val: 0.3654350324112609
# True order: rachunek prawdopodobieństwa przydaje się w życiu
# position of true order: 26
# Points for sentence: 0.038461538461538464
#
#
# ------------Sentence 64--------------------
# 1 order: strawił smoka zanim rycerze księżniczkę osaczyli | Val: 0.4895490653803775
# 2 order: strawił osaczyli księżniczkę smoka zanim rycerze | Val: 0.48856478419712857
# 3 order: smoka zanim rycerze księżniczkę osaczyli strawił | Val: 0.48828847826124455
# 4 order: strawił smoka zanim rycerze osaczyli księżniczkę | Val: 0.48798623457727525
# 5 order: smoka zanim rycerze osaczyli księżniczkę strawił | Val: 0.48745878632128564
# True order: rycerze osaczyli smoka zanim strawił księżniczkę
# position of true order: 85
# Points for sentence: 0.011764705882352941
#
#
# ------------Sentence 65--------------------
# 1 order: zdania chyba już przestać wymyślać należy | Val: 0.08147979219276817
# 2 order: należy zdania chyba już przestać wymyślać | Val: 0.08112600361406683
# 3 order: należy chyba już przestać wymyślać zdania | Val: 0.07304522690034661
# 4 order: już przestać wymyślać zdania chyba należy | Val: 0.07278059608497543
# 5 order: chyba należy już przestać wymyślać zdania | Val: 0.07110089271333699
# True order: chyba należy już przestać wymyślać zdania
# position of true order: 5
# Points for sentence: 0.2
#
#
# All points: 12.796771995215277, Gamma: 0.75
