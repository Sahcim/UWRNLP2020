# %%
import numpy as np
from itertools import permutations
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def load_corpus(path, num_lines, K):
    file = open(path, "r")

    one_grams = {}
    two_grams = {}
    three_gram = {}
    number_of_words = 0
    num_line_iter = 0 
    
    for _, line in enumerate(tqdm(file)):
        
        line = line.lower().split(" ")

        if len(line) < 3: continue

        number_of_words += len(line)
        line_iter = 0

        while line_iter < len(line) - 2:

            word_1 = line[line_iter]
            word_2 = line[line_iter+1]
            word_3 = line[line_iter+2]

            if word_3[-1] == '\n': word_3 = word_3[:-1] 

            if len(word_1) > K:
                word_1 = word_1[-K:]
            if len(word_2) > K:
                word_2 = word_2[-K:]
            if len(word_3) > K:
                word_3 = word_3[-K:]

            key_1 = word_1
            key_2 = (word_1, word_2)
            key_3 = (word_1, word_2, word_3)

            if key_1 in one_grams.keys():
                one_grams[key_1] += 1
            else:
                one_grams[key_1] = 1

            if key_2 in two_grams.keys():
                two_grams[key_2] += 1
            else:
                two_grams[key_2] = 1

            if key_3 in three_gram.keys():
                three_gram[key_3] += 1
            else:
                three_gram[key_3] = 1

            line_iter += 1

        key_2 = (word_2, word_3)
        if key_2 in two_grams.keys():
            two_grams[key_2] += 1
        else:
            two_grams[key_2] = 1


        key_1 = word_2
        if key_1 in one_grams.keys():
             one_grams[key_1] += 1
        else:
            one_grams[key_1] = 1

        key_1 = word_3
        if key_1 in one_grams.keys():
            one_grams[key_1] += 1
        else:
            one_grams[key_1] = 1


        num_line_iter += 1
        if num_line_iter == num_lines: break

    return three_gram, two_grams, one_grams,  number_of_words

# %%
def train_three_grams(path, start_line, num_lines, K):
    file = open(path, "r")

    three_gram = {}
    num_line_iter = 0

    for line in file:
        if num_line_iter < start_line:
            num_line_iter += 1
            continue
        
        line = line.lower().split(" ")

        
        if len(line) < 3: continue

        line_iter = 0

        while line_iter < len(line) - 2:

            word_1 = line[line_iter]
            word_2 = line[line_iter+1]
            word_3 = line[line_iter+2]

            if word_3[-1] == '\n': word_3 = word_3[:-1] 

            if len(word_1) > K:
                word_1 = word_1[-K:]
            if len(word_2) > K:
                word_2 = word_2[-K:]
            if len(word_3) > K:
                word_3 = word_3[-K:]

            key_3 = (word_1, word_2, word_3)
            
            if key_3 in three_gram.keys():
                three_gram[key_3] += 1
            else:
                three_gram[key_3] = 1
            
            line_iter += 1

        num_line_iter += 1
        if num_line_iter == start_line + num_lines: break

    return three_gram

# %%
def train(one_grams, two_grams, three_grams, train_three_grams, number_of_words):

    lambdas = np.array([0, 0, 0])

    for three_gram in train_three_grams.keys():

        p3 = 0
        p2 = 0
        p1 = 0

        if three_gram in three_grams:

            p3 = three_grams[three_gram]/two_grams[three_gram[:2]]

        if three_gram[1:] in two_grams:

            p2 = two_grams[three_gram[1:]]/one_grams[three_gram[1]]

        if three_gram[2] in one_grams:

            p1 = one_grams[three_gram[2]]/number_of_words
        
        results = (p1, p2, p3)
        
        f = lambda i: results[i]
        best = max(range(len(results)), key=f)

        lambdas[best] += train_three_grams[three_gram]


    #lambdas = (lambdas-np.mean(lambdas)) / np.std(lambdas)
    #e_x = np.exp(lambdas - np.max(lambdas))
    #lambdas = e_x / e_x.sum()

    return lambdas/np.sum(lambdas)

# %%
def test_three_gram(one_grams, two_grams, three_grams, lambdas, three_gram):


    result = 0

    if three_gram in three_grams:

        result += lambdas[2] * three_grams[three_gram]/two_grams[three_gram[:2]]

    if three_gram[1:] in two_grams:

        result += lambdas[1] * two_grams[three_gram[1:]]/one_grams[three_gram[1]]

    if three_gram[2] in one_grams:

        result += lambdas[0] * one_grams[three_gram[2]]/number_of_words

    return result

# %%
def test_sentence(one_grams, two_grams, three_grams, lambdas, sentence, K):

    sen_iter = 0
    result = 0

    while sen_iter < len(sentence) - 2:

        word_1 = sentence[sen_iter]
        word_2 = sentence[sen_iter+1]
        word_3 = sentence[sen_iter+2]

        if len(word_1) > K:
            word_1 = word_1[-K:]
        if len(word_2) > K:
            word_2 = word_2[-K:]
        if len(word_3) > K:
            word_3 = word_3[-K:]

        three_gram = (word_1, word_2, word_3)

        result += test_three_gram(one_grams, two_grams, three_grams, lambdas, three_gram)
        sen_iter +=1
    
    return result

# %% [markdown]
# # Deleted Interpolation on words

# %%
num_lines = 4000000
K = 0 

three_grams, two_grams, one_grams, number_of_words = load_corpus('/content/polish_corpora.txt', num_lines, K)

train_corpus = train_three_grams('/content/polish_corpora.txt', num_lines, 100000, K)

lb = train(one_grams, two_grams, three_grams, train_corpus, number_of_words)

print("Lambdas from Training {}".format(lb))

f = open('/content/test.txt', 'r')

points = 0
iter = 1
for line in f:
    
    line = line.split()

    res = []
    res_values = []
    perms = list(permutations(line))
    for perm in list(perms):
        res.append([perm])
        res_values.append(test_sentence(one_grams, two_grams, three_grams, lb, perm, K))

    res = np.array(res)
    res_values = np.array(res_values)

    best = np.argsort(res_values)[::-1]
    points += 1/(np.where(best == 0)[0][0]+1)

    print("------------Sentence {}-------------------- ".format(iter))
    print("1 order: {} | Prob: {}".format(" ".join(res[best[0]][0]), res_values[best[0]]))
    print("2 order: {} | Prob: {}".format(" ".join(res[best[1]][0]), res_values[best[1]]))
    print("3 order: {} | Prob: {}".format(" ".join(res[best[2]][0]), res_values[best[2]]))
    print("4 order: {} | Prob: {}".format(" ".join(res[best[3]][0]), res_values[best[3]]))
    print("5 order: {} | Prob: {}".format(" ".join(res[best[4]][0]), res_values[best[4]]))
    print("True order: {}".format(" ".join(line)))
    print("position of true order: {}".format(np.where(best == 0)[0][0]+1))
    print("Points for sentence: {}".format(1/(np.where(best == 0)[0][0]+1)))
    print("\n")
    iter +=1

print("All points: {}".format(points))
# Out:
# 3999773it [04:58, 13142.54it/s]
# Lambdas from Training [0.23251272 0.337896   0.42959128]
# ------------Sentence 1--------------------
# 1 order: przedmiot przetwarzanie to nasz języka naturalnego | Prob: 0.004011405040972545
# 2 order: przedmiot języka naturalnego przetwarzanie to nasz | Prob: 0.003993060214902989
# 3 order: przedmiot przetwarzanie to języka naturalnego nasz | Prob: 0.003912950303675258
# 4 order: nasz przetwarzanie to przedmiot języka naturalnego | Prob: 0.003911177720165311
# 5 order: nasz przetwarzanie to języka naturalnego przedmiot | Prob: 0.0038973940569436913
# True order: nasz przedmiot to przetwarzanie języka naturalnego
# position of true order: 123
# Points for sentence: 0.008130081300813009
#
#
# ------------Sentence 2--------------------
# 1 order: michaliszyn prowadzi jakub jedną grupę | Prob: 0.0009641778918192047
# 2 order: michaliszyn jakub prowadzi jedną grupę | Prob: 0.0009576852892832296
# 3 order: jakub michaliszyn prowadzi jedną grupę | Prob: 0.0009576852892832296
# 4 order: michaliszyn jedną grupę prowadzi jakub | Prob: 0.0009552733836995945
# 5 order: michaliszyn prowadzi jedną grupę jakub | Prob: 0.0009310605731835705
# True order: jedną grupę prowadzi jakub michaliszyn
# position of true order: 58
# Points for sentence: 0.017241379310344827
#
#
# ------------Sentence 3--------------------
# 1 order: rychlikowski wykładowcą jest paweł | Prob: 0.0027005277040236843
# 2 order: paweł rychlikowski wykładowcą jest | Prob: 0.0026831107094843713
# 3 order: rychlikowski paweł wykładowcą jest | Prob: 0.0026831107094843713
# 4 order: paweł wykładowcą jest rychlikowski | Prob: 0.002681094762001175
# 5 order: rychlikowski paweł jest wykładowcą | Prob: 0.002288789399719153
# True order: wykładowcą jest paweł rychlikowski
# position of true order: 16
# Points for sentence: 0.0625
#
#
# ------------Sentence 4--------------------
# 1 order: pozostałe dwie grupy prowadzi również pan paweł | Prob: 0.05070098110784063
# 2 order: prowadzi pozostałe dwie grupy również pan paweł | Prob: 0.049313195726454664
# 3 order: prowadzi również pan paweł pozostałe dwie grupy | Prob: 0.04895820920601883
# 4 order: również pan paweł pozostałe dwie grupy prowadzi | Prob: 0.04813237910427594
# 5 order: również pan paweł prowadzi pozostałe dwie grupy | Prob: 0.04813237910427594
# True order: pan paweł prowadzi również dwie pozostałe grupy
# position of true order: 151
# Points for sentence: 0.006622516556291391
#
#
# ------------Sentence 5--------------------
# 1 order: zadań wykładu będą pojawiać się na stronie listy | Prob: 0.7190439205822934
# 2 order: listy wykładu będą pojawiać się na stronie zadań | Prob: 0.7189778508044109
# 3 order: listy zadań wykładu będą pojawiać się na stronie | Prob: 0.7189269607116302
# 4 order: zadań listy wykładu będą pojawiać się na stronie | Prob: 0.7189269607116302
# 5 order: wykładu listy zadań będą pojawiać się na stronie | Prob: 0.7181787416693276
# True order: na stronie wykładu będą pojawiać się listy zadań
# position of true order: 516
# Points for sentence: 0.001937984496124031
#
#
# ------------Sentence 6--------------------
# 1 order: pracowniowe ćwiczeniowe będą i to listy | Prob: 0.06049999193042394
# 2 order: pracowniowe listy ćwiczeniowe będą i to | Prob: 0.06047665964953408
# 3 order: listy pracowniowe ćwiczeniowe będą i to | Prob: 0.06047665964953408
# 4 order: listy ćwiczeniowe będą i to pracowniowe | Prob: 0.06047662412623041
# 5 order: pracowniowe ćwiczeniowe będą to listy i | Prob: 0.04285626428806065
# True order: będą to listy ćwiczeniowe i pracowniowe
# position of true order: 562
# Points for sentence: 0.0017793594306049821
#
#
# ------------Sentence 7--------------------
# 1 order: pracowniowe ćwiczeniowe będą i to listy | Prob: 0.06049999193042394
# 2 order: listy pracowniowe ćwiczeniowe będą i to | Prob: 0.06047665964953408
# 3 order: pracowniowe listy ćwiczeniowe będą i to | Prob: 0.06047665964953408
# 4 order: listy ćwiczeniowe będą i to pracowniowe | Prob: 0.06047662412623041
# 5 order: pracowniowe ćwiczeniowe będą to listy i | Prob: 0.04285626428806065
# True order: będą to listy pracowniowe i ćwiczeniowe
# position of true order: 559
# Points for sentence: 0.0017889087656529517
#
#
# ------------Sentence 8--------------------
# 1 order: aktywności mogą pojawiać się również dodatkowe | Prob: 0.6577293301918853
# 2 order: dodatkowe aktywności mogą pojawiać się również | Prob: 0.6575509753679755
# 3 order: aktywności dodatkowe mogą pojawiać się również | Prob: 0.6574570284722995
# 4 order: mogą pojawiać się również dodatkowe aktywności | Prob: 0.6572814237278214
# 5 order: dodatkowe mogą pojawiać się również aktywności | Prob: 0.6572797797169332
# True order: mogą się pojawiać również dodatkowe aktywności
# position of true order: 153
# Points for sentence: 0.006535947712418301
#
#
# ------------Sentence 9--------------------
# 1 order: aktywności premiowane będą te | Prob: 0.022992902320669553
# 2 order: te premiowane będą aktywności | Prob: 0.021946154323402203
# 3 order: te aktywności premiowane będą | Prob: 0.0219355446967065
# 4 order: aktywności te premiowane będą | Prob: 0.0219355446967065
# 5 order: premiowane aktywności te będą | Prob: 0.0031680810995619317
# True order: te aktywności będą premiowane
# position of true order: 12
# Points for sentence: 0.08333333333333333
#
#
# ------------Sentence 10--------------------
# 1 order: quizy przykłąd na platformie na zdalnej | Prob: 0.07179342717084745
# 2 order: quizy przykłąd na platformie na zdalnej | Prob: 0.07179342717084745
# 3 order: zdalnej przykłąd na platformie na quizy | Prob: 0.07179313347499065
# 4 order: zdalnej przykłąd na platformie na quizy | Prob: 0.07179313347499065
# 5 order: quizy zdalnej przykłąd na platformie na | Prob: 0.07179307130920923
# True order: na przykłąd quizy na platformie zdalnej
# position of true order: 499
# Points for sentence: 0.002004008016032064
#
#
# ------------Sentence 11--------------------
# 1 order: miniprojekty rozważamy wykładu na temat też | Prob: 0.4476238620190987
# 2 order: rozważamy miniprojekty wykładu na temat też | Prob: 0.4476238620190987
# 3 order: miniprojekty wykładu na temat też rozważamy | Prob: 0.4476236370381754
# 4 order: rozważamy wykładu na temat też miniprojekty | Prob: 0.4476233706133979
# 5 order: miniprojekty rozważamy też wykładu na temat | Prob: 0.4474321557446397
# True order: rozważamy też miniprojekty na temat wykładu
# position of true order: 225
# Points for sentence: 0.0044444444444444444
#
#
# ------------Sentence 12--------------------
# 1 order: zapowiadamy je z co najmniej tygodniowym wyprzedzeniem | Prob: 0.8387541906135909
# 2 order: je zapowiadamy z co najmniej tygodniowym wyprzedzeniem | Prob: 0.8299639577683295
# 3 order: zapowiadamy z co najmniej tygodniowym wyprzedzeniem je | Prob: 0.8264418370109585
# 4 order: je z co najmniej tygodniowym wyprzedzeniem zapowiadamy | Prob: 0.8263689816754094
# 5 order: z co najmniej tygodniowym wyprzedzeniem zapowiadamy je | Prob: 0.8259475348636927
# True order: zapowiadamy je z co najmniej tygodniowym wyprzedzeniem
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 13--------------------
# 1 order: zajęcia przeznaczone są na konkretne zadania | Prob: 0.3617602763535903
# 2 order: zajęcia są przeznaczone na konkretne zadania | Prob: 0.3520051408582258
# 3 order: są przeznaczone na konkretne zadania zajęcia | Prob: 0.3514818308860351
# 4 order: konkretne zajęcia przeznaczone są na zadania | Prob: 0.31704700518470547
# 5 order: zadania zajęcia przeznaczone są na konkretne | Prob: 0.3166831218999053
# True order: zadania są przeznaczone na konkretne zajęcia
# position of true order: 24
# Points for sentence: 0.041666666666666664
#
#
# ------------Sentence 14--------------------
# 1 order: zaczynają ćwiczenia się w sali seminaryjnej | Prob: 0.4750677099198043
# 2 order: seminaryjnej ćwiczenia się w sali zaczynają | Prob: 0.4750203691585444
# 3 order: seminaryjnej zaczynają ćwiczenia się w sali | Prob: 0.4750202566680828
# 4 order: zaczynają seminaryjnej ćwiczenia się w sali | Prob: 0.4750202566680828
# 5 order: zaczynają sali seminaryjnej ćwiczenia się w | Prob: 0.47429706294873325
# True order: ćwiczenia zaczynają się w sali seminaryjnej
# position of true order: 25
# Points for sentence: 0.04
#
#
# ------------Sentence 15--------------------
# 1 order: stacjonarnym trybie tylko w jest tak | Prob: 0.1997323462522621
# 2 order: trybie tylko w jest tak stacjonarnym | Prob: 0.19929208656318798
# 3 order: stacjonarnym trybie tylko w tak jest | Prob: 0.18617477708743416
# 4 order: trybie tylko w tak jest stacjonarnym | Prob: 0.1857351097120429
# 5 order: stacjonarnym tak jest trybie tylko w | Prob: 0.18529536968053037
# True order: jest tak tylko w trybie stacjonarnym
# position of true order: 84
# Points for sentence: 0.011904761904761904
#
#
# ------------Sentence 16--------------------
# 1 order: domyślnie pozostałe zajęcia zaczynają się w pracowni | Prob: 0.5932633789618286
# 2 order: domyślnie zajęcia zaczynają się w pracowni pozostałe | Prob: 0.5931502604396486
# 3 order: pozostałe domyślnie zajęcia zaczynają się w pracowni | Prob: 0.5931456246485198
# 4 order: pracowni domyślnie pozostałe zajęcia zaczynają się w | Prob: 0.5931348120409773
# 5 order: domyślnie pracowni pozostałe zajęcia zaczynają się w | Prob: 0.5931348120409773
# True order: pozostałe zajęcia domyślnie zaczynają się w pracowni
# position of true order: 139
# Points for sentence: 0.007194244604316547
#
#
# ------------Sentence 17--------------------
# 1 order: konsutlacjach pracownia indywidualnych polega na | Prob: 0.23547900966242938
# 2 order: konsutlacjach polega na pracownia indywidualnych | Prob: 0.23546440725294776
# 3 order: konsutlacjach pracownia polega na indywidualnych | Prob: 0.23464452724565604
# 4 order: pracownia konsutlacjach polega na indywidualnych | Prob: 0.23464452724565604
# 5 order: pracownia konsutlacjach indywidualnych polega na | Prob: 0.23463002473268219
# True order: pracownia polega na indywidualnych konsutlacjach
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 18--------------------
# 1 order: tam rozmawiamy na temat rozwiązań | Prob: 0.2619641649421661
# 2 order: rozwiązań rozmawiamy na temat tam | Prob: 0.26163091377794945
# 3 order: rozwiązań tam rozmawiamy na temat | Prob: 0.261538884242063
# 4 order: tam rozwiązań rozmawiamy na temat | Prob: 0.2615278882447302
# 5 order: rozmawiamy na temat rozwiązań tam | Prob: 0.24996107670333897
# True order: rozmawiamy tam na temat rozwiązań
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 19--------------------
# 1 order: pisemne przedstawiają rozwiązania zadań studenci podczas ćwiczeń | Prob: 0.0014222454491472742
# 2 order: pisemne studenci podczas ćwiczeń przedstawiają rozwiązania zadań | Prob: 0.0014212093527902717
# 3 order: pisemne przedstawiają rozwiązania zadań podczas ćwiczeń studenci | Prob: 0.00127129680176841
# 4 order: pisemne studenci przedstawiają rozwiązania zadań podczas ćwiczeń | Prob: 0.0012702607054114073
# 5 order: studenci pisemne przedstawiają rozwiązania zadań podczas ćwiczeń | Prob: 0.0012702607054114073
# True order: podczas ćwiczeń studenci przedstawiają pisemne rozwiązania zadań
# position of true order: 2589
# Points for sentence: 0.0003862495171881035
#
#
# ------------Sentence 20--------------------
# 1 order: epidemiologicznej tryb zajęć sytuacji zależy od | Prob: 0.563216116419513
# 2 order: epidemiologicznej tryb sytuacji zależy od zajęć | Prob: 0.5632107483778879
# 3 order: tryb epidemiologicznej sytuacji zależy od zajęć | Prob: 0.5632107483778879
# 4 order: epidemiologicznej sytuacji zależy od tryb zajęć | Prob: 0.5631366478289308
# 5 order: epidemiologicznej sytuacji zależy od zajęć tryb | Prob: 0.5631312797873058
# True order: tryb zajęć zależy od sytuacji epidemiologicznej
# position of true order: 25
# Points for sentence: 0.04
#
#
# ------------Sentence 21--------------------
# 1 order: też zależy od wymogów formalnych | Prob: 0.3440108258859119
# 2 order: też zależy od formalnych wymogów | Prob: 0.33327766187416585
# 3 order: wymogów formalnych też zależy od | Prob: 0.33064483001101336
# 4 order: formalnych wymogów też zależy od | Prob: 0.33064483001101336
# 5 order: formalnych też zależy od wymogów | Prob: 0.33061715105792605
# True order: zależy też od wymogów formalnych
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 22--------------------
# 1 order: zależy również od decyzji władz | Prob: 0.3769315955021649
# 2 order: władz zależy również od decyzji | Prob: 0.3731566733788771
# 3 order: decyzji zależy również od władz | Prob: 0.3706291983057449
# 4 order: władz decyzji zależy również od | Prob: 0.3694914135945017
# 5 order: decyzji władz zależy również od | Prob: 0.3693533438954605
# True order: zależy również od decyzji władz
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 23--------------------
# 1 order: prowadzących uwzględnia się studentów i możliwości | Prob: 0.1326116630504333
# 2 order: możliwości uwzględnia się studentów i prowadzących | Prob: 0.13232554619025494
# 3 order: możliwości prowadzących uwzględnia się studentów i | Prob: 0.13230994407624172
# 4 order: prowadzących możliwości uwzględnia się studentów i | Prob: 0.13230994407624172
# 5 order: prowadzących studentów i możliwości uwzględnia się | Prob: 0.10395979679688575
# True order: uwzględnia się możliwości studentów i prowadzących
# position of true order: 162
# Points for sentence: 0.006172839506172839
#
#
# ------------Sentence 24--------------------
# 1 order: semestru on może zmieniać się w trakcie | Prob: 0.40905767041825075
# 2 order: on semestru może zmieniać się w trakcie | Prob: 0.4079561761387911
# 3 order: semestru może zmieniać się w trakcie on | Prob: 0.4077573699698095
# 4 order: on może zmieniać się w trakcie semestru | Prob: 0.40775680452311963
# 5 order: może zmieniać się w trakcie semestru on | Prob: 0.4077075622087785
# True order: może się on zmieniać w trakcie semestru
# position of true order: 1022
# Points for sentence: 0.0009784735812133072
#
#
# ------------Sentence 25--------------------
# 1 order: prowadzącemu deklaracje przed ćwiczeniami studenci dostarczają | Prob: 0.0014522452541187538
# 2 order: prowadzącemu studenci dostarczają deklaracje przed ćwiczeniami | Prob: 0.0014505282944414352
# 3 order: ćwiczeniami prowadzącemu deklaracje przed studenci dostarczają | Prob: 0.00142966186721859
# 4 order: prowadzącemu ćwiczeniami studenci dostarczają deklaracje przed | Prob: 0.00142966186721859
# 5 order: ćwiczeniami prowadzącemu studenci dostarczają deklaracje przed | Prob: 0.00142966186721859
# True order: przed ćwiczeniami studenci dostarczają prowadzącemu deklaracje
# position of true order: 239
# Points for sentence: 0.0041841004184100415
#
#
# ------------Sentence 26--------------------
# 1 order: numery zawiera ona zadań | Prob: 0.005710934315111919
# 2 order: zadań numery zawiera ona | Prob: 0.005687240271564924
# 3 order: numery zadań zawiera ona | Prob: 0.005687240271564924
# 4 order: zadań zawiera ona numery | Prob: 0.005662054249263845
# 5 order: numery zadań ona zawiera | Prob: 0.00017379363975100754
# True order: zawiera ona numery zadań
# position of true order: 21
# Points for sentence: 0.047619047619047616
#
#
# ------------Sentence 27--------------------
# 1 order: studenci tablicy przy pokazują rozwiązania | Prob: 0.0032613366992801747
# 2 order: studenci pokazują rozwiązania tablicy przy | Prob: 0.0032595220505177674
# 3 order: studenci tablicy przy rozwiązania pokazują | Prob: 0.00303502528549497
# 4 order: pokazują tablicy przy studenci rozwiązania | Prob: 0.003013310409527894
# 5 order: pokazują tablicy przy rozwiązania studenci | Prob: 0.003013310409527894
# True order: studenci pokazują rozwiązania przy tablicy
# position of true order: 21
# Points for sentence: 0.047619047619047616
#
#
# ------------Sentence 28--------------------
# 1 order: umie jeżeli student nie jest źle , | Prob: 0.4061120692553704
# 2 order: jeżeli student nie jest źle , umie | Prob: 0.40607236473963954
# 3 order: umie student nie jest źle , jeżeli | Prob: 0.3247952482652718
# 4 order: jeżeli umie student nie jest źle , | Prob: 0.32015305402019
# 5 order: student nie jest źle , jeżeli umie | Prob: 0.3150723513986543
# True order: jest źle , jeżeli student nie umie
# position of true order: 8
# Points for sentence: 0.125
#
#
# ------------Sentence 29--------------------
# 1 order: odejmuje coś mu się dodatkowo | Prob: 0.1759856753741523
# 2 order: odejmuje dodatkowo coś mu się | Prob: 0.17597499113444676
# 3 order: dodatkowo odejmuje coś mu się | Prob: 0.17594475435574075
# 4 order: dodatkowo coś mu się odejmuje | Prob: 0.17590355028376042
# 5 order: coś mu się dodatkowo odejmuje | Prob: 0.17545756407250604
# True order: dodatkowo coś mu się odejmuje
# position of true order: 4
# Points for sentence: 0.25
#
#
# ------------Sentence 30--------------------
# 1 order: zadania oddawać można pracowni podczas zajęć na | Prob: 0.020017915409313785
# 2 order: zadania pracowni podczas zajęć na oddawać można | Prob: 0.020015411016405145
# 3 order: pracowni oddawać można podczas zajęć na zadania | Prob: 0.019655162942411958
# 4 order: pracowni podczas zajęć na zadania oddawać można | Prob: 0.019496868097754114
# 5 order: pracowni oddawać można zadania podczas zajęć na | Prob: 0.019484348948561235
# True order: zadania można oddawać podczas zajęć na pracowni
# position of true order: 93
# Points for sentence: 0.010752688172043012
#
#
# ------------Sentence 31--------------------
# 1 order: samodzielnie rozwiązywać zadania należy | Prob: 0.00643727265722103
# 2 order: należy samodzielnie rozwiązywać zadania | Prob: 0.0062399981795915665
# 3 order: należy rozwiązywać zadania samodzielnie | Prob: 0.006209825855810169
# 4 order: samodzielnie należy rozwiązywać zadania | Prob: 0.006126176560022444
# 5 order: rozwiązywać samodzielnie zadania należy | Prob: 0.00037247262061684437
# True order: zadania należy rozwiązywać samodzielnie
# position of true order: 23
# Points for sentence: 0.043478260869565216
#
#
# ------------Sentence 32--------------------
# 1 order: prowadzący ocenia poprawność rozwiązania | Prob: 0.00308003526574261
# 2 order: prowadzący poprawność rozwiązania ocenia | Prob: 0.0029036771129540635
# 3 order: ocenia poprawność rozwiązania prowadzący | Prob: 0.0029032301113829
# 4 order: ocenia prowadzący poprawność rozwiązania | Prob: 0.0028988577847563492
# 5 order: prowadzący poprawność ocenia rozwiązania | Prob: 0.0002334115387557164
# True order: prowadzący ocenia poprawność rozwiązania
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 33--------------------
# 1 order: regułach czasem informacje o mogą pojawić się | Prob: 0.9390656405129232
# 2 order: regułach mogą pojawić się czasem informacje o | Prob: 0.9390634266937625
# 3 order: czasem informacje o regułach mogą pojawić się | Prob: 0.9389510749626145
# 4 order: czasem informacje o mogą pojawić się regułach | Prob: 0.9389460753916736
# 5 order: mogą pojawić się czasem informacje o regułach | Prob: 0.9375173134003794
# True order: czasem mogą pojawić się informacje o regułach
# position of true order: 10
# Points for sentence: 0.1
#
#
# ------------Sentence 34--------------------
# 1 order: każdej podany termin jest na liście | Prob: 0.11185895951839085
# 2 order: liście podany termin jest na każdej | Prob: 0.11002885612793666
# 3 order: liście każdej podany termin jest na | Prob: 0.10982099522777503
# 4 order: każdej liście podany termin jest na | Prob: 0.10982099522777503
# 5 order: podany termin jest na liście każdej | Prob: 0.10801983611865122
# True order: na każdej liście podany jest termin
# position of true order: 59
# Points for sentence: 0.01694915254237288
#
#
# ------------Sentence 35--------------------
# 1 order: punktów dostajemy za dużo poprawne rozwiązanie | Prob: 0.013702084928375201
# 2 order: punktów poprawne rozwiązanie dostajemy za dużo | Prob: 0.013701667529557095
# 3 order: punktów dostajemy za poprawne rozwiązanie dużo | Prob: 0.01239811524847927
# 4 order: punktów poprawne rozwiązanie dużo dostajemy za | Prob: 0.012370713661668881
# 5 order: dużo dostajemy za poprawne rozwiązanie punktów | Prob: 0.0122549343652283
# True order: za poprawne rozwiązanie dostajemy dużo punktów
# position of true order: 284
# Points for sentence: 0.0035211267605633804
#
#
# ------------Sentence 36--------------------
# 1 order: spóźnione zadania nie będą sprawdzane | Prob: 0.0442800458371198
# 2 order: spóźnione sprawdzane zadania nie będą | Prob: 0.04424762802001048
# 3 order: sprawdzane spóźnione zadania nie będą | Prob: 0.04424762802001048
# 4 order: sprawdzane zadania nie będą spóźnione | Prob: 0.04420603023141448
# 5 order: zadania nie będą sprawdzane spóźnione | Prob: 0.04077832305912833
# True order: spóźnione zadania nie będą sprawdzane
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 37--------------------
# 1 order: lista dłuższy termin ma pierwsza | Prob: 0.00304045809195576
# 2 order: pierwsza dłuższy termin ma lista | Prob: 0.00301838634236943
# 3 order: lista pierwsza dłuższy termin ma | Prob: 0.0030124865136851274
# 4 order: pierwsza lista dłuższy termin ma | Prob: 0.0030124865136851274
# 5 order: lista dłuższy termin pierwsza ma | Prob: 0.002867232810150614
# True order: pierwsza lista ma dłuższy termin
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 38--------------------
# 1 order: zmodyfikowana zasada musi być pod koniec semestru | Prob: 0.5666913255148194
# 2 order: zmodyfikowana semestru zasada musi być pod koniec | Prob: 0.5665382891753827
# 3 order: semestru zmodyfikowana zasada musi być pod koniec | Prob: 0.5665382891753827
# 4 order: semestru zasada musi być pod koniec zmodyfikowana | Prob: 0.5665296126084616
# 5 order: zasada musi być pod koniec semestru zmodyfikowana | Prob: 0.5665259176820978
# True order: zasada musi być zmodyfikowana pod koniec semestru
# position of true order: 9
# Points for sentence: 0.1111111111111111
#
#
# ------------Sentence 39--------------------
# 1 order: studenta inne zasady obowiązują w przypadku choroby | Prob: 0.22889278044411812
# 2 order: choroby studenta inne zasady obowiązują w przypadku | Prob: 0.22838739346797146
# 3 order: studenta choroby inne zasady obowiązują w przypadku | Prob: 0.22838739346797146
# 4 order: choroby inne zasady obowiązują w przypadku studenta | Prob: 0.22836645492769547
# 5 order: inne zasady obowiązują w przypadku choroby studenta | Prob: 0.22799170698026464
# True order: w przypadku choroby studenta obowiązują inne zasady
# position of true order: 203
# Points for sentence: 0.0049261083743842365
#
#
# ------------Sentence 40--------------------
# 1 order: kwarantanny studenta inne zasady obowiązują w przypadku | Prob: 0.22838739346797146
# 2 order: studenta kwarantanny inne zasady obowiązują w przypadku | Prob: 0.22838739346797146
# 3 order: kwarantanny inne zasady obowiązują w przypadku studenta | Prob: 0.22836645492769547
# 4 order: studenta inne zasady obowiązują w przypadku kwarantanny | Prob: 0.22831751912965523
# 5 order: inne zasady obowiązują w przypadku studenta kwarantanny | Prob: 0.2274643394469344
# True order: w przypadku kwarantanny studenta obowiązują inne zasady
# position of true order: 236
# Points for sentence: 0.00423728813559322
#
#
# ------------Sentence 41--------------------
# 1 order: izolacji studenta inne zasady obowiązują w przypadku | Prob: 0.22838739346797146
# 2 order: studenta izolacji inne zasady obowiązują w przypadku | Prob: 0.22838739346797146
# 3 order: izolacji inne zasady obowiązują w przypadku studenta | Prob: 0.22836645492769547
# 4 order: studenta inne zasady obowiązują w przypadku izolacji | Prob: 0.2283191028769438
# 5 order: inne zasady obowiązują w przypadku studenta izolacji | Prob: 0.22746592319422296
# True order: w przypadku izolacji studenta obowiązują inne zasady
# position of true order: 237
# Points for sentence: 0.004219409282700422
#
#
# ------------Sentence 42--------------------
# 1 order: zaległych oddawanie zadań możliwe jest bez punktowej straty | Prob: 0.27854068982560465
# 2 order: oddawanie zaległych zadań możliwe jest bez punktowej straty | Prob: 0.27854068982560465
# 3 order: oddawanie punktowej straty zadań możliwe jest bez zaległych | Prob: 0.27853389785474664
# 4 order: oddawanie punktowej straty zaległych zadań możliwe jest bez | Prob: 0.27853389785474664
# 5 order: zaległych punktowej straty zadań możliwe jest bez oddawanie | Prob: 0.2785333117202361
# True order: możliwe jest oddawanie zaległych zadań bez straty punktowej
# position of true order: 33438
# Points for sentence: 2.9906094862132904e-05
#
#
# ------------Sentence 43--------------------
# 1 order: tabelką ocenę wystawia się zgodnie z | Prob: 0.7605526405477756
# 2 order: tabelką wystawia się zgodnie z ocenę | Prob: 0.7604114500953428
# 3 order: ocenę tabelką wystawia się zgodnie z | Prob: 0.7604054732995007
# 4 order: ocenę wystawia się zgodnie z tabelką | Prob: 0.7604046533032409
# 5 order: tabelką ocenę wystawia zgodnie z się | Prob: 0.7503297430986695
# True order: ocenę wystawia się zgodnie z tabelką
# position of true order: 4
# Points for sentence: 0.25
#
#
# ------------Sentence 44--------------------
# 1 order: daje ocenę dostateczną 50 punktów | Prob: 0.0013823303062425623
# 2 order: daje 50 punktów ocenę dostateczną | Prob: 0.0013522509488611261
# 3 order: dostateczną ocenę daje 50 punktów | Prob: 0.0010896553228813056
# 4 order: ocenę dostateczną daje 50 punktów | Prob: 0.000942488074606316
# 5 order: dostateczną 50 punktów ocenę daje | Prob: 0.000934552777769464
# True order: 50 punktów daje ocenę dostateczną
# position of true order: 21
# Points for sentence: 0.047619047619047616
#
#
# ------------Sentence 45--------------------
# 1 order: daje ocenę bardzo dobrą 120 punktów | Prob: 0.3865970693536282
# 2 order: daje 120 punktów ocenę bardzo dobrą | Prob: 0.3865970427111505
# 3 order: ocenę bardzo dobrą 120 punktów daje | Prob: 0.38509752109630313
# 4 order: ocenę bardzo dobrą daje 120 punktów | Prob: 0.3850565702319028
# 5 order: 120 punktów daje ocenę bardzo dobrą | Prob: 0.3848154280548473
# True order: 120 punktów daje ocenę bardzo dobrą
# position of true order: 5
# Points for sentence: 0.2
#
#
# ------------Sentence 46--------------------
# 1 order: przeskalowana tabelka powyższa zostanie | Prob: 0.00044839598152865613
# 2 order: tabelka przeskalowana powyższa zostanie | Prob: 0.00044839598152865613
# 3 order: przeskalowana powyższa zostanie tabelka | Prob: 0.0004460218407334675
# 4 order: przeskalowana powyższa tabelka zostanie | Prob: 0.0004460218407334675
# 5 order: tabelka powyższa zostanie przeskalowana | Prob: 0.0004459004694459329
# True order: powyższa tabelka zostanie przeskalowana
# position of true order: 15
# Points for sentence: 0.06666666666666667
#
#
# ------------Sentence 47--------------------
# 1 order: przeskalowana innych też może zostać z powodów | Prob: 0.10029102652613034
# 2 order: innych też może zostać z powodów przeskalowana | Prob: 0.10000012618797714
# 3 order: przeskalowana zostać z powodów innych też może | Prob: 0.09176620754794568
# 4 order: przeskalowana powodów innych też może zostać z | Prob: 0.09013951578623673
# 5 order: powodów przeskalowana innych też może zostać z | Prob: 0.08966825218506606
# True order: może też zostać przeskalowana z innych powodów
# position of true order: 280
# Points for sentence: 0.0035714285714285713
#
#
# ------------Sentence 48--------------------
# 1 order: zajęć podamy w pierwszym tygodniu coś | Prob: 0.054311143735734424
# 2 order: coś podamy w pierwszym tygodniu zajęć | Prob: 0.05428004012309721
# 3 order: zajęć coś podamy w pierwszym tygodniu | Prob: 0.054151391333392154
# 4 order: coś zajęć podamy w pierwszym tygodniu | Prob: 0.054151391333392154
# 5 order: podamy zajęć coś pierwszym tygodniu w | Prob: 0.050763395851423344
# True order: w pierwszym tygodniu zajęć coś podamy
# position of true order: 491
# Points for sentence: 0.002036659877800407
#
#
# ------------Sentence 49--------------------
# 1 order: zasady dodatkowe umożliwiające zwolnienie z egzaminu | Prob: 0.3132452249798453
# 2 order: dodatkowe umożliwiające zwolnienie z egzaminu zasady | Prob: 0.3132411409457761
# 3 order: dodatkowe zasady umożliwiające zwolnienie z egzaminu | Prob: 0.3132225852537061
# 4 order: zasady umożliwiające zwolnienie z egzaminu dodatkowe | Prob: 0.31321851556161445
# 5 order: umożliwiające dodatkowe zwolnienie z egzaminu zasady | Prob: 0.3128377041745054
# True order: dodatkowe zasady umożliwiające zwolnienie z egzaminu
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 50--------------------
# 1 order: dotyczą dużą liczbą punktów z osób | Prob: 0.08524138669388566
# 2 order: dotyczą osób dużą liczbą punktów z | Prob: 0.08499665521234119
# 3 order: osób dotyczą dużą liczbą punktów z | Prob: 0.08499665521234119
# 4 order: osób dużą liczbą punktów z dotyczą | Prob: 0.08499355876437142
# 5 order: dużą liczbą punktów z dotyczą osób | Prob: 0.08200205090249252
# True order: dotyczą osób z dużą liczbą punktów
# position of true order: 31
# Points for sentence: 0.03225806451612903
#
#
# ------------Sentence 51--------------------
# 1 order: specjalne zadanie można rozwiązać też | Prob: 0.10866193677253456
# 2 order: też specjalne zadanie można rozwiązać | Prob: 0.10850067161660606
# 3 order: zadanie można rozwiązać też specjalne | Prob: 0.1083532736981236
# 4 order: specjalne też zadanie można rozwiązać | Prob: 0.10827247338858362
# 5 order: też zadanie można rozwiązać specjalne | Prob: 0.10825712059460031
# True order: można rozwiązać też zadanie specjalne
# position of true order: 89
# Points for sentence: 0.011235955056179775
#
#
# ------------Sentence 52--------------------
# 1 order: forma egzaminu zależy od wielu czynników | Prob: 0.17068224233104326
# 2 order: egzaminu forma zależy od wielu czynników | Prob: 0.1705418617734864
# 3 order: egzaminu zależy od wielu czynników forma | Prob: 0.1705328714173829
# 4 order: forma zależy od wielu czynników egzaminu | Prob: 0.1705317287511149
# 5 order: czynników forma egzaminu zależy od wielu | Prob: 0.14692558168730363
# True order: forma egzaminu zależy od wielu czynników
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 53--------------------
# 1 order: różnych wariantów należy spodziewać się | Prob: 0.5663707212768432
# 2 order: wariantów różnych należy spodziewać się | Prob: 0.5657094766544569
# 3 order: wariantów należy spodziewać się różnych | Prob: 0.5656397939084249
# 4 order: różnych należy spodziewać się wariantów | Prob: 0.5655476857678982
# 5 order: należy spodziewać się różnych wariantów | Prob: 0.5651606251981508
# True order: należy się spodziewać różnych wariantów
# position of true order: 23
# Points for sentence: 0.043478260869565216
#
#
# ------------Sentence 54--------------------
# 1 order: indywidualnego ustnego egzaminu nie wykluczamy | Prob: 0.02076132034965314
# 2 order: wykluczamy ustnego egzaminu nie indywidualnego | Prob: 0.02074823024359884
# 3 order: indywidualnego wykluczamy ustnego egzaminu nie | Prob: 0.02074407581636955
# 4 order: wykluczamy indywidualnego ustnego egzaminu nie | Prob: 0.02074407581636955
# 5 order: wykluczamy ustnego egzaminu indywidualnego nie | Prob: 0.017096756759407014
# True order: nie wykluczamy indywidualnego egzaminu ustnego
# position of true order: 59
# Points for sentence: 0.01694915254237288
#
#
# ------------Sentence 55--------------------
# 1 order: są tutaj też jaś i małgosia | Prob: 0.39483937073608155
# 2 order: tutaj też są jaś i małgosia | Prob: 0.39455020177988465
# 3 order: są jaś i małgosia tutaj też | Prob: 0.39206644255999223
# 4 order: tutaj jaś i małgosia są też | Prob: 0.39156688570120546
# 5 order: tutaj jaś i małgosia też są | Prob: 0.3911419637206525
# True order: jaś i małgosia też są tutaj
# position of true order: 21
# Points for sentence: 0.047619047619047616
#
#
# ------------Sentence 56--------------------
# 1 order: prosiaczkiem przybędą z nie puchatek | Prob: 0.024837372519303527
# 2 order: puchatek prosiaczkiem przybędą z nie | Prob: 0.024837351797376388
# 3 order: prosiaczkiem puchatek przybędą z nie | Prob: 0.024837351797376388
# 4 order: puchatek przybędą z nie prosiaczkiem | Prob: 0.024837251148015993
# 5 order: puchatek przybędą z prosiaczkiem nie | Prob: 0.024804141410366236
# True order: puchatek z prosiaczkiem nie przybędą
# position of true order: 82
# Points for sentence: 0.012195121951219513
#
#
# ------------Sentence 57--------------------
# 1 order: odpoczywał chory kotek i raz był | Prob: 0.44821057829671906
# 2 order: chory kotek i raz był odpoczywał | Prob: 0.44762487524548406
# 3 order: odpoczywał raz był chory kotek i | Prob: 0.4460273134532788
# 4 order: odpoczywał chory kotek i był raz | Prob: 0.44600843986694877
# 5 order: raz odpoczywał chory kotek i był | Prob: 0.4459097309020269
# True order: raz kotek był chory i odpoczywał
# position of true order: 26
# Points for sentence: 0.038461538461538464
# 3999773it [05:16, 13142.54it/s]
# ------------Sentence 58--------------------
# 1 order: raz kotek był chory leżał w łóżeczku i | Prob: 0.5551646409511231
# 2 order: raz łóżeczku i kotek był chory leżał w | Prob: 0.5551640953429847
# 3 order: raz łóżeczku i chory leżał w kotek był | Prob: 0.5550939739993016
# 4 order: raz kotek był łóżeczku i chory leżał w | Prob: 0.555093870389666
# 5 order: raz chory leżał w łóżeczku i kotek był | Prob: 0.5550932224706512
# True order: raz kotek był chory i leżał w łóżeczku
# position of true order: 2166
# Points for sentence: 0.0004616805170821791
#
#
# ------------Sentence 59--------------------
# 1 order: równoważności definicja nie jest trudna relacji | Prob: 0.05771995985774024
# 2 order: równoważności relacji definicja nie jest trudna | Prob: 0.057710785964567815
# 3 order: relacji równoważności definicja nie jest trudna | Prob: 0.057710785964567815
# 4 order: relacji definicja nie jest trudna równoważności | Prob: 0.0577084503073516
# 5 order: trudna definicja nie jest relacji równoważności | Prob: 0.05770063211456707
# True order: definicja relacji równoważności nie jest trudna
# position of true order: 45
# Points for sentence: 0.022222222222222223
#
#
# ------------Sentence 60--------------------
# 1 order: hipoteza continuum jest niezależna od aksjomatów | Prob: 0.41056918498590167
# 2 order: aksjomatów continuum jest niezależna od hipoteza | Prob: 0.41056751267361086
# 3 order: aksjomatów hipoteza continuum jest niezależna od | Prob: 0.4105667903664363
# 4 order: hipoteza aksjomatów continuum jest niezależna od | Prob: 0.4105667903664363
# 5 order: continuum hipoteza jest niezależna od aksjomatów | Prob: 0.38647056102813737
# True order: hipoteza continuum jest niezależna od aksjomatów
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 61--------------------
# 1 order: teoria mnogości daje wiele radości | Prob: 0.017504101470154507
# 2 order: mnogości teoria daje wiele radości | Prob: 0.017504101470154507
# 3 order: mnogości daje wiele radości teoria | Prob: 0.017482772686576782
# 4 order: teoria daje wiele radości mnogości | Prob: 0.0174804015060569
# 5 order: daje wiele radości teoria mnogości | Prob: 0.016587443628981367
# True order: teoria mnogości daje wiele radości
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 62--------------------
# 1 order: programowanie szczególnie nie jest trudne | Prob: 0.06628248644253233
# 2 order: programowanie trudne szczególnie nie jest | Prob: 0.06592306474853137
# 3 order: trudne programowanie szczególnie nie jest | Prob: 0.06592306474853137
# 4 order: trudne szczególnie nie jest programowanie | Prob: 0.0658745237057985
# 5 order: szczególnie nie jest trudne programowanie | Prob: 0.0635842467983275
# True order: programowanie nie jest szczególnie trudne
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 63--------------------
# 1 order: prawdopodobieństwa przydaje się w życiu rachunek | Prob: 0.3132257581363887
# 2 order: rachunek przydaje się w życiu prawdopodobieństwa | Prob: 0.3132223390184106
# 3 order: rachunek prawdopodobieństwa przydaje się w życiu | Prob: 0.3132218890565641
# 4 order: prawdopodobieństwa rachunek przydaje się w życiu | Prob: 0.3132218890565641
# 5 order: życiu przydaje się w rachunek prawdopodobieństwa | Prob: 0.31277683597469647
# True order: rachunek prawdopodobieństwa przydaje się w życiu
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 64--------------------
# 1 order: strawił osaczyli księżniczkę zanim rycerze smoka | Prob: 1.3981380268922615e-05
# 2 order: osaczyli strawił księżniczkę smoka zanim rycerze | Prob: 1.3981380268922615e-05
# 3 order: strawił osaczyli księżniczkę zanim smoka rycerze | Prob: 1.3981380268922615e-05
# 4 order: osaczyli strawił smoka zanim rycerze księżniczkę | Prob: 1.3981380268922615e-05
# 5 order: osaczyli strawił smoka rycerze zanim księżniczkę | Prob: 1.3981380268922615e-05
# True order: rycerze osaczyli smoka zanim strawił księżniczkę
# position of true order: 184
# Points for sentence: 0.005434782608695652
#
#
# ------------Sentence 65--------------------
# 1 order: wymyślać zdania należy chyba już przestać | Prob: 0.0036749581527245074
# 2 order: przestać wymyślać zdania należy chyba już | Prob: 0.003670799373851467
# 3 order: wymyślać przestać zdania należy chyba już | Prob: 0.003670799373851467
# 4 order: przestać zdania należy chyba już wymyślać | Prob: 0.0036635644610042836
# 5 order: wymyślać zdania należy przestać chyba już | Prob: 0.0035967883276910705
# True order: chyba należy już przestać wymyślać zdania
# position of true order: 294
# Points for sentence: 0.003401360544217687
#
#
# All points: 10.302831816741671

# %% [markdown]
# # Deleted Interpolation on suffixes

# %%
num_lines = 20000000
K = 3 

three_grams, two_grams, one_grams, number_of_words = load_corpus('/content/polish_corpora.txt', num_lines, K)

train_corpus = train_three_grams('/content/polish_corpora.txt', num_lines, 1000000, K)

lb = train(one_grams, two_grams, three_grams, train_corpus, number_of_words)

print("Lambdas from Training {}".format(lb))

f = open('/content/test.txt', 'r')

points = 0
iter = 1
for line in f:
    
    line = line.split()

    res = []
    res_values = []
    perms = list(permutations(line))
    for perm in list(perms):
        res.append([perm])
        res_values.append(test_sentence(one_grams, two_grams, three_grams, lb, perm, K))

    res = np.array(res)
    res_values = np.array(res_values)

    best = np.argsort(res_values)[::-1]
    points += 1/(np.where(best == 0)[0][0]+1)

    print("------------Sentence {}-------------------- ".format(iter))
    print("1 order: {} | Prob: {}".format(" ".join(res[best[0]][0]), res_values[best[0]]))
    print("2 order: {} | Prob: {}".format(" ".join(res[best[1]][0]), res_values[best[1]]))
    print("3 order: {} | Prob: {}".format(" ".join(res[best[2]][0]), res_values[best[2]]))
    print("4 order: {} | Prob: {}".format(" ".join(res[best[3]][0]), res_values[best[3]]))
    print("5 order: {} | Prob: {}".format(" ".join(res[best[4]][0]), res_values[best[4]]))
    print("True order: {}".format(" ".join(line)))
    print("position of true order: {}".format(np.where(best == 0)[0][0]+1))
    print("Points for sentence: {}".format(1/(np.where(best == 0)[0][0]+1)))
    print("\n")
    iter +=1

print("All points: {}".format(points))
# Out:
# 19999537it [27:33, 11464.33it/s]
# Lambdas from Training [0.14376183 0.23653802 0.61970015]
# ------------Sentence 1--------------------
# 1 order: nasz przedmiot przetwarzanie języka naturalnego to | Prob: 0.2514948284603231
# 2 order: to nasz przedmiot przetwarzanie języka naturalnego | Prob: 0.2490397261541058
# 3 order: nasz przedmiot to przetwarzanie języka naturalnego | Prob: 0.24778991721239146
# 4 order: przedmiot to przetwarzanie języka naturalnego nasz | Prob: 0.24663884932370272
# 5 order: przedmiot nasz to przetwarzanie języka naturalnego | Prob: 0.23411120517466466
# True order: nasz przedmiot to przetwarzanie języka naturalnego
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 2--------------------
# 1 order: jakub michaliszyn jedną grupę prowadzi | Prob: 0.012743941888986166
# 2 order: michaliszyn jakub jedną grupę prowadzi | Prob: 0.01272924803326748
# 3 order: jakub jedną grupę prowadzi michaliszyn | Prob: 0.012718920765462292
# 4 order: michaliszyn jedną grupę prowadzi jakub | Prob: 0.012695283441071169
# 5 order: jedną grupę prowadzi jakub michaliszyn | Prob: 0.012362251157584535
# True order: jedną grupę prowadzi jakub michaliszyn
# position of true order: 5
# Points for sentence: 0.2
#
#
# ------------Sentence 3--------------------
# 1 order: wykładowcą jest paweł rychlikowski | Prob: 0.19684752528781238
# 2 order: jest paweł rychlikowski wykładowcą | Prob: 0.19684372250970975
# 3 order: paweł wykładowcą rychlikowski jest | Prob: 0.10663049000681735
# 4 order: wykładowcą rychlikowski jest paweł | Prob: 0.10625839265059137
# 5 order: wykładowcą paweł rychlikowski jest | Prob: 0.04792198405797781
# True order: wykładowcą jest paweł rychlikowski
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 4--------------------
# 1 order: paweł również grupy pozostałe dwie pan prowadzi | Prob: 0.038368783787267546
# 2 order: również grupy pozostałe dwie pan prowadzi paweł | Prob: 0.038299460787727134
# 3 order: również grupy pozostałe dwie prowadzi pan paweł | Prob: 0.03809555503502094
# 4 order: paweł również grupy pozostałe dwie prowadzi pan | Prob: 0.03711635792343334
# 5 order: paweł prowadzi również grupy pozostałe dwie pan | Prob: 0.036952166701421374
# True order: pan paweł prowadzi również dwie pozostałe grupy
# position of true order: 764
# Points for sentence: 0.0013089005235602095
#
#
# ------------Sentence 5--------------------
# 1 order: wykładu pojawiać na listy zadań się stronie będą | Prob: 0.5018364445219735
# 2 order: wykładu pojawiać na zadań się stronie będą listy | Prob: 0.5016443055922295
# 3 order: listy wykładu pojawiać na zadań się stronie będą | Prob: 0.5015628195782117
# 4 order: listy zadań się stronie będą wykładu pojawiać na | Prob: 0.5015483647703259
# 5 order: wykładu pojawiać na zadań się stronie listy będą | Prob: 0.5012810505411677
# True order: na stronie wykładu będą pojawiać się listy zadań
# position of true order: 4731
# Points for sentence: 0.0002113718030014796
#
#
# ------------Sentence 6--------------------
# 1 order: będą listy ćwiczeniowe i pracowniowe to | Prob: 0.18449407729246525
# 2 order: będą listy pracowniowe i ćwiczeniowe to | Prob: 0.18449407729246525
# 3 order: to będą listy ćwiczeniowe i pracowniowe | Prob: 0.183247969584037
# 4 order: to będą listy pracowniowe i ćwiczeniowe | Prob: 0.183247969584037
# 5 order: to listy ćwiczeniowe i pracowniowe będą | Prob: 0.17308303625408583
# True order: będą to listy ćwiczeniowe i pracowniowe
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 7--------------------
# 1 order: będą listy pracowniowe i ćwiczeniowe to | Prob: 0.18449407729246525
# 2 order: będą listy ćwiczeniowe i pracowniowe to | Prob: 0.18449407729246525
# 3 order: to będą listy pracowniowe i ćwiczeniowe | Prob: 0.183247969584037
# 4 order: to będą listy ćwiczeniowe i pracowniowe | Prob: 0.183247969584037
# 5 order: to listy pracowniowe i ćwiczeniowe będą | Prob: 0.17308303625408583
# True order: będą to listy pracowniowe i ćwiczeniowe
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 8--------------------
# 1 order: również mogą pojawiać się dodatkowe aktywności | Prob: 0.21503119994528438
# 2 order: również aktywności dodatkowe mogą pojawiać się | Prob: 0.21442348032539327
# 3 order: mogą pojawiać się również aktywności dodatkowe | Prob: 0.21296552575866912
# 4 order: dodatkowe również mogą pojawiać się aktywności | Prob: 0.212953836338085
# 5 order: również dodatkowe aktywności mogą pojawiać się | Prob: 0.2120598040889304
# True order: mogą się pojawiać również dodatkowe aktywności
# position of true order: 119
# Points for sentence: 0.008403361344537815
#
#
# ------------Sentence 9--------------------
# 1 order: aktywności te będą premiowane | Prob: 0.19071092867135284
# 2 order: te będą premiowane aktywności | Prob: 0.1794952660074051
# 3 order: te aktywności będą premiowane | Prob: 0.12973077115271694
# 4 order: aktywności będą premiowane te | Prob: 0.1267578294693512
# 5 order: aktywności te premiowane będą | Prob: 0.04482280313386769
# True order: te aktywności będą premiowane
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 10--------------------
# 1 order: przykłąd quizy zdalnej na platformie na | Prob: 0.6754159726450366
# 2 order: przykłąd quizy zdalnej na platformie na | Prob: 0.6754159726450366
# 3 order: na przykłąd quizy zdalnej na platformie | Prob: 0.6695836355087091
# 4 order: na przykłąd quizy zdalnej na platformie | Prob: 0.6695836355087091
# 5 order: przykłąd quizy zdalnej na na platformie | Prob: 0.6649094316534475
# True order: na przykłąd quizy na platformie zdalnej
# position of true order: 84
# Points for sentence: 0.011904761904761904
#
#
# ------------Sentence 11--------------------
# 1 order: też miniprojekty rozważamy na temat wykładu | Prob: 0.06303847044101261
# 2 order: miniprojekty rozważamy na temat wykładu też | Prob: 0.06288516832883871
# 3 order: wykładu miniprojekty rozważamy na temat też | Prob: 0.06196099115393308
# 4 order: wykładu też miniprojekty rozważamy na temat | Prob: 0.061907465759452926
# 5 order: też wykładu miniprojekty rozważamy na temat | Prob: 0.061730281327730424
# True order: rozważamy też miniprojekty na temat wykładu
# position of true order: 69
# Points for sentence: 0.014492753623188406
#
#
# ------------Sentence 12--------------------
# 1 order: je zapowiadamy tygodniowym wyprzedzeniem z co najmniej | Prob: 0.8281493528271417
# 2 order: zapowiadamy tygodniowym wyprzedzeniem z co najmniej je | Prob: 0.8280709574521865
# 3 order: zapowiadamy tygodniowym wyprzedzeniem je z co najmniej | Prob: 0.82513312952716
# 4 order: z co najmniej je zapowiadamy tygodniowym wyprzedzeniem | Prob: 0.8234116008437875
# 5 order: je z co najmniej zapowiadamy tygodniowym wyprzedzeniem | Prob: 0.8177710323917147
# True order: zapowiadamy je z co najmniej tygodniowym wyprzedzeniem
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 13--------------------
# 1 order: zajęcia przeznaczone są na konkretne zadania | Prob: 0.30121352653094974
# 2 order: na konkretne zadania zajęcia przeznaczone są | Prob: 0.2495775684905113
# 3 order: zajęcia przeznaczone są konkretne na zadania | Prob: 0.22195690369755647
# 4 order: zajęcia przeznaczone są na zadania konkretne | Prob: 0.2117133697735069
# 5 order: zajęcia są przeznaczone na konkretne zadania | Prob: 0.20988984769912028
# True order: zadania są przeznaczone na konkretne zajęcia
# position of true order: 76
# Points for sentence: 0.013157894736842105
#
#
# ------------Sentence 14--------------------
# 1 order: ćwiczenia zaczynają się w sali seminaryjnej | Prob: 0.27344349596021894
# 2 order: sali zaczynają się w seminaryjnej ćwiczenia | Prob: 0.25362530339438244
# 3 order: ćwiczenia sali zaczynają się w seminaryjnej | Prob: 0.2513198094659056
# 4 order: sali zaczynają się w ćwiczenia seminaryjnej | Prob: 0.24332344580156764
# 5 order: seminaryjnej sali zaczynają się w ćwiczenia | Prob: 0.2388428936009975
# True order: ćwiczenia zaczynają się w sali seminaryjnej
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 15--------------------
# 1 order: trybie tylko w tak stacjonarnym jest | Prob: 0.19169660855968443
# 2 order: jest trybie tylko w tak stacjonarnym | Prob: 0.1879957295431809
# 3 order: tylko tak jest w trybie stacjonarnym | Prob: 0.15797239624326764
# 4 order: trybie jest tylko w tak stacjonarnym | Prob: 0.15611835194333448
# 5 order: jest tylko w tak stacjonarnym trybie | Prob: 0.15539790755745098
# True order: jest tak tylko w trybie stacjonarnym
# position of true order: 33
# Points for sentence: 0.030303030303030304
#
#
# ------------Sentence 16--------------------
# 1 order: pracowni pozostałe domyślnie zajęcia zaczynają się w | Prob: 0.4259312440768718
# 2 order: zajęcia zaczynają się w pracowni pozostałe domyślnie | Prob: 0.42219628617213656
# 3 order: pracowni pozostałe domyślnie w zajęcia zaczynają się | Prob: 0.3722302055864549
# 4 order: zajęcia zaczynają się pracowni pozostałe domyślnie w | Prob: 0.37048212504356404
# 5 order: pracowni zajęcia zaczynają się w pozostałe domyślnie | Prob: 0.33821584096986096
# True order: pozostałe zajęcia domyślnie zaczynają się w pracowni
# position of true order: 159
# Points for sentence: 0.006289308176100629
#
#
# ------------Sentence 17--------------------
# 1 order: pracownia polega na indywidualnych konsutlacjach | Prob: 0.6890830790432133
# 2 order: pracownia polega na konsutlacjach indywidualnych | Prob: 0.4743740255720491
# 3 order: polega na indywidualnych konsutlacjach pracownia | Prob: 0.43926164533205225
# 4 order: polega pracownia na indywidualnych konsutlacjach | Prob: 0.43801777400846953
# 5 order: pracownia na indywidualnych konsutlacjach polega | Prob: 0.42990850527119123
# True order: pracownia polega na indywidualnych konsutlacjach
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 18--------------------
# 1 order: tam rozwiązań rozmawiamy na temat | Prob: 0.040341932845748246
# 2 order: rozwiązań rozmawiamy na temat tam | Prob: 0.040207895612633264
# 3 order: tam temat rozwiązań rozmawiamy na | Prob: 0.03429238199627046
# 4 order: temat rozwiązań rozmawiamy na tam | Prob: 0.0341711547400554
# 5 order: temat tam rozwiązań rozmawiamy na | Prob: 0.03415105922190558
# True order: rozmawiamy tam na temat rozwiązań
# position of true order: 19
# Points for sentence: 0.05263157894736842
#
#
# ------------Sentence 19--------------------
# 1 order: studenci zadań przedstawiają ćwiczeń pisemne rozwiązania podczas | Prob: 0.5305566925035132
# 2 order: ćwiczeń pisemne rozwiązania podczas studenci zadań przedstawiają | Prob: 0.5303836689364433
# 3 order: studenci zadań przedstawiają podczas ćwiczeń pisemne rozwiązania | Prob: 0.5299023885504259
# 4 order: ćwiczeń pisemne rozwiązania studenci zadań przedstawiają podczas | Prob: 0.5292741999376342
# 5 order: podczas studenci zadań przedstawiają ćwiczeń pisemne rozwiązania | Prob: 0.5290900017432314
# True order: podczas ćwiczeń studenci przedstawiają pisemne rozwiązania zadań
# position of true order: 663
# Points for sentence: 0.0015082956259426848
#
#
# ------------Sentence 20--------------------
# 1 order: tryb zależy od zajęć sytuacji epidemiologicznej | Prob: 0.3282242237114677
# 2 order: zajęć sytuacji epidemiologicznej tryb zależy od | Prob: 0.32683865776122345
# 3 order: tryb zajęć sytuacji epidemiologicznej zależy od | Prob: 0.293666257416794
# 4 order: zajęć sytuacji epidemiologicznej zależy od tryb | Prob: 0.2920870963622311
# 5 order: tryb zajęć sytuacji epidemiologicznej od zależy | Prob: 0.2359386565275181
# True order: tryb zajęć zależy od sytuacji epidemiologicznej
# position of true order: 67
# Points for sentence: 0.014925373134328358
#
#
# ------------Sentence 21--------------------
# 1 order: wymogów zależy od też formalnych | Prob: 0.3131809990712271
# 2 order: od też formalnych wymogów zależy | Prob: 0.2588349555059181
# 3 order: zależy od też formalnych wymogów | Prob: 0.25797856103139355
# 4 order: zależy wymogów od też formalnych | Prob: 0.2544545802876498
# 5 order: wymogów od też formalnych zależy | Prob: 0.2538727748316954
# True order: zależy też od wymogów formalnych
# position of true order: 9
# Points for sentence: 0.1111111111111111
#
#
# ------------Sentence 22--------------------
# 1 order: władz od decyzji zależy również | Prob: 0.10259361785206912
# 2 order: władz od decyzji również zależy | Prob: 0.09505212592881554
# 3 order: również władz od decyzji zależy | Prob: 0.09063754338373174
# 4 order: zależy władz od decyzji również | Prob: 0.09025408444570023
# 5 order: zależy również władz od decyzji | Prob: 0.08991332233843659
# True order: zależy również od decyzji władz
# position of true order: 11
# Points for sentence: 0.09090909090909091
#
#
# ------------Sentence 23--------------------
# 1 order: się możliwości uwzględnia studentów prowadzących i | Prob: 0.32449425827100664
# 2 order: możliwości studentów prowadzących i uwzględnia się | Prob: 0.321727266421843
# 3 order: się możliwości i uwzględnia studentów prowadzących | Prob: 0.31584020439539306
# 4 order: się możliwości studentów prowadzących i uwzględnia | Prob: 0.3085276445212051
# 5 order: się uwzględnia możliwości studentów prowadzących i | Prob: 0.3013582733639679
# True order: uwzględnia się możliwości studentów i prowadzących
# position of true order: 259
# Points for sentence: 0.003861003861003861
#
#
# ------------Sentence 24--------------------
# 1 order: semestru może zmieniać się on w trakcie | Prob: 0.27714066969670015
# 2 order: może zmieniać się on w trakcie semestru | Prob: 0.2759349846651116
# 3 order: semestru on może zmieniać się w trakcie | Prob: 0.26223588004022613
# 4 order: on może zmieniać się w trakcie semestru | Prob: 0.26135745620938095
# 5 order: on semestru może zmieniać się w trakcie | Prob: 0.2607123617313343
# True order: może się on zmieniać w trakcie semestru
# position of true order: 1074
# Points for sentence: 0.000931098696461825
#
#
# ------------Sentence 25--------------------
# 1 order: prowadzącemu studenci dostarczają przed ćwiczeniami deklaracje | Prob: 0.24329993086247265
# 2 order: deklaracje prowadzącemu studenci dostarczają przed ćwiczeniami | Prob: 0.24290506931067324
# 3 order: deklaracje studenci dostarczają przed ćwiczeniami prowadzącemu | Prob: 0.21247912540579125
# 4 order: prowadzącemu deklaracje studenci dostarczają przed ćwiczeniami | Prob: 0.21195670926079335
# 5 order: prowadzącemu studenci dostarczają deklaracje przed ćwiczeniami | Prob: 0.1855564274071786
# True order: przed ćwiczeniami studenci dostarczają prowadzącemu deklaracje
# position of true order: 182
# Points for sentence: 0.005494505494505495
#
#
# ------------Sentence 26--------------------
# 1 order: numery zadań ona zawiera | Prob: 0.00768676429553913
# 2 order: zadań ona zawiera numery | Prob: 0.007552773242511582
# 3 order: zadań zawiera ona numery | Prob: 0.0019519604088273352
# 4 order: zadań numery zawiera ona | Prob: 0.0018573836174351278
# 5 order: numery zadań zawiera ona | Prob: 0.0017549451269762558
# True order: zawiera ona numery zadań
# position of true order: 10
# Points for sentence: 0.1
#
#
# ------------Sentence 27--------------------
# 1 order: przy studenci pokazują rozwiązania tablicy | Prob: 0.08650534697578943
# 2 order: tablicy przy studenci pokazują rozwiązania | Prob: 0.0862153548018855
# 3 order: przy studenci pokazują tablicy rozwiązania | Prob: 0.08031901211693479
# 4 order: rozwiązania tablicy przy studenci pokazują | Prob: 0.07338046666151625
# 5 order: tablicy rozwiązania przy studenci pokazują | Prob: 0.07209121896740354
# True order: studenci pokazują rozwiązania przy tablicy
# position of true order: 14
# Points for sentence: 0.07142857142857142
#
#
# ------------Sentence 28--------------------
# 1 order: jeżeli student nie jest źle , umie | Prob: 0.3769011923043689
# 2 order: umie jeżeli student nie jest źle , | Prob: 0.37646717308039734
# 3 order: jest źle , jeżeli student nie umie | Prob: 0.34439593527384343
# 4 order: umie jest źle , jeżeli student nie | Prob: 0.34200091956297485
# 5 order: jeżeli student nie umie jest źle , | Prob: 0.34014248554562954
# True order: jest źle , jeżeli student nie umie
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 29--------------------
# 1 order: dodatkowo mu się coś odejmuje | Prob: 0.2694893624081802
# 2 order: odejmuje dodatkowo mu się coś | Prob: 0.2625762295307204
# 3 order: dodatkowo mu się odejmuje coś | Prob: 0.2624972572388413
# 4 order: coś dodatkowo mu się odejmuje | Prob: 0.2621978502350149
# 5 order: coś odejmuje dodatkowo mu się | Prob: 0.2605167291546804
# True order: dodatkowo coś mu się odejmuje
# position of true order: 11
# Points for sentence: 0.09090909090909091
#
#
# ------------Sentence 30--------------------
# 1 order: zajęć można oddawać na pracowni podczas zadania | Prob: 0.25090298448921927
# 2 order: pracowni podczas zadania zajęć można oddawać na | Prob: 0.2506934550963319
# 3 order: pracowni podczas zadania na zajęć można oddawać | Prob: 0.24997196480508144
# 4 order: zajęć można oddawać pracowni podczas zadania na | Prob: 0.24993368474220512
# 5 order: zajęć pracowni podczas zadania można oddawać na | Prob: 0.24433037337381688
# True order: zadania można oddawać podczas zajęć na pracowni
# position of true order: 350
# Points for sentence: 0.002857142857142857
#
#
# ------------Sentence 31--------------------
# 1 order: zadania należy rozwiązywać samodzielnie | Prob: 0.09647917610332811
# 2 order: samodzielnie należy rozwiązywać zadania | Prob: 0.0790311847524513
# 3 order: należy rozwiązywać samodzielnie zadania | Prob: 0.06960507624916962
# 4 order: zadania samodzielnie należy rozwiązywać | Prob: 0.06714337246817008
# 5 order: zadania należy samodzielnie rozwiązywać | Prob: 0.06477151237591074
# True order: zadania należy rozwiązywać samodzielnie
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 32--------------------
# 1 order: prowadzący poprawność ocenia rozwiązania | Prob: 0.12961149735135255
# 2 order: prowadzący poprawność rozwiązania ocenia | Prob: 0.12961149735135255
# 3 order: rozwiązania prowadzący poprawność ocenia | Prob: 0.11225689123961646
# 4 order: ocenia prowadzący poprawność rozwiązania | Prob: 0.11225689123961646
# 5 order: prowadzący ocenia poprawność rozwiązania | Prob: 0.09343973135865197
# True order: prowadzący ocenia poprawność rozwiązania
# position of true order: 5
# Points for sentence: 0.2
#
#
# ------------Sentence 33--------------------
# 1 order: czasem mogą pojawić się informacje o regułach | Prob: 0.4099332498923591
# 2 order: mogą pojawić się informacje o regułach czasem | Prob: 0.39172368348333436
# 3 order: czasem regułach informacje o pojawić się mogą | Prob: 0.3916754905904931
# 4 order: regułach informacje o pojawić się mogą czasem | Prob: 0.3915183754838916
# 5 order: mogą czasem regułach informacje o pojawić się | Prob: 0.39150341672431543
# True order: czasem mogą pojawić się informacje o regułach
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 34--------------------
# 1 order: termin podany jest na każdej liście | Prob: 0.19419531925429687
# 2 order: każdej termin podany jest na liście | Prob: 0.17910160553645793
# 3 order: termin podany jest na liście każdej | Prob: 0.17771285943481424
# 4 order: liście termin podany jest na każdej | Prob: 0.1578432098770141
# 5 order: każdej liście termin podany jest na | Prob: 0.15777340769833054
# True order: na każdej liście podany jest termin
# position of true order: 44
# Points for sentence: 0.022727272727272728
#
#
# ------------Sentence 35--------------------
# 1 order: dostajemy za poprawne rozwiązanie dużo punktów | Prob: 0.20573253734292501
# 2 order: dużo dostajemy za poprawne rozwiązanie punktów | Prob: 0.20442402720723515
# 3 order: za poprawne rozwiązanie dużo punktów dostajemy | Prob: 0.20340002710362784
# 4 order: dostajemy za poprawne rozwiązanie punktów dużo | Prob: 0.20262130496685254
# 5 order: dostajemy dużo punktów za poprawne rozwiązanie | Prob: 0.201835988117991
# True order: za poprawne rozwiązanie dostajemy dużo punktów
# position of true order: 13
# Points for sentence: 0.07692307692307693
#
#
# ------------Sentence 36--------------------
# 1 order: spóźnione zadania będą sprawdzane nie | Prob: 0.21046271420858936
# 2 order: zadania będą sprawdzane nie spóźnione | Prob: 0.2089849360472379
# 3 order: zadania będą sprawdzane spóźnione nie | Prob: 0.1920169587754404
# 4 order: nie spóźnione zadania będą sprawdzane | Prob: 0.1771458453092966
# 5 order: spóźnione nie zadania będą sprawdzane | Prob: 0.17700802070002522
# True order: spóźnione zadania nie będą sprawdzane
# position of true order: 13
# Points for sentence: 0.07692307692307693
#
#
# ------------Sentence 37--------------------
# 1 order: pierwsza lista ma dłuższy termin | Prob: 0.009045003352488595
# 2 order: dłuższy termin ma pierwsza lista | Prob: 0.007478797011825445
# 3 order: lista dłuższy termin ma pierwsza | Prob: 0.007374590434398966
# 4 order: termin pierwsza lista ma dłuższy | Prob: 0.006814243257666061
# 5 order: lista ma dłuższy termin pierwsza | Prob: 0.00504198235373875
# True order: pierwsza lista ma dłuższy termin
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 38--------------------
# 1 order: semestru musi być zmodyfikowana pod koniec zasada | Prob: 0.41761428223922414
# 2 order: zasada semestru musi być zmodyfikowana pod koniec | Prob: 0.40594647678472895
# 3 order: semestru zmodyfikowana musi być pod koniec zasada | Prob: 0.37912566673135184
# 4 order: zmodyfikowana musi być pod koniec zasada semestru | Prob: 0.379074396144397
# 5 order: semestru zasada zmodyfikowana musi być pod koniec | Prob: 0.3682559988286026
# True order: zasada musi być zmodyfikowana pod koniec semestru
# position of true order: 151
# Points for sentence: 0.006622516556291391
#
#
# ------------Sentence 39--------------------
# 1 order: studenta choroby przypadku w obowiązują inne zasady | Prob: 0.130819995054032
# 2 order: choroby przypadku w obowiązują inne zasady studenta | Prob: 0.1307824162469154
# 3 order: studenta obowiązują inne zasady choroby przypadku w | Prob: 0.11962498810611988
# 4 order: choroby przypadku w studenta obowiązują inne zasady | Prob: 0.11928606527932917
# 5 order: obowiązują inne zasady choroby przypadku w studenta | Prob: 0.11350609843291053
# True order: w przypadku choroby studenta obowiązują inne zasady
# position of true order: 699
# Points for sentence: 0.001430615164520744
#
#
# ------------Sentence 40--------------------
# 1 order: kwarantanny studenta w obowiązują inne zasady przypadku | Prob: 0.1520115921477442
# 2 order: przypadku kwarantanny studenta w obowiązują inne zasady | Prob: 0.15109959882163282
# 3 order: kwarantanny studenta w przypadku obowiązują inne zasady | Prob: 0.14559363995903482
# 4 order: obowiązują inne zasady kwarantanny studenta w przypadku | Prob: 0.14512040309779478
# 5 order: przypadku obowiązują inne zasady kwarantanny studenta w | Prob: 0.1343388932768129
# True order: w przypadku kwarantanny studenta obowiązują inne zasady
# position of true order: 1016
# Points for sentence: 0.000984251968503937
#
#
# ------------Sentence 41--------------------
# 1 order: przypadku studenta izolacji w obowiązują inne zasady | Prob: 0.12465907817796776
# 2 order: studenta izolacji w obowiązują inne zasady przypadku | Prob: 0.1229064061216973
# 3 order: obowiązują inne zasady studenta izolacji w przypadku | Prob: 0.11568139283983342
# 4 order: studenta izolacji w przypadku obowiązują inne zasady | Prob: 0.11402585442207294
# 5 order: obowiązują inne zasady studenta w przypadku izolacji | Prob: 0.11383812578098329
# True order: w przypadku izolacji studenta obowiązują inne zasady
# position of true order: 294
# Points for sentence: 0.003401360544217687
#
#
# ------------Sentence 42--------------------
# 1 order: bez straty punktowej możliwe jest oddawanie zadań zaległych | Prob: 1.1342448015510036
# 2 order: punktowej możliwe jest oddawanie zadań zaległych bez straty | Prob: 1.1252249965826098
# 3 order: straty bez punktowej możliwe jest oddawanie zadań zaległych | Prob: 1.1248842292311463
# 4 order: punktowej możliwe jest oddawanie zadań zaległych straty bez | Prob: 1.116817457217489
# 5 order: straty punktowej możliwe jest oddawanie zadań zaległych bez | Prob: 1.1162173178828034
# True order: możliwe jest oddawanie zaległych zadań bez straty punktowej
# position of true order: 1932
# Points for sentence: 0.0005175983436853002
#
#
# ------------Sentence 43--------------------
# 1 order: ocenę zgodnie wystawia się tabelką z | Prob: 0.20819163087975048
# 2 order: zgodnie wystawia się tabelką z ocenę | Prob: 0.20769848676858943
# 3 order: tabelką ocenę zgodnie wystawia się z | Prob: 0.19888766866571006
# 4 order: z tabelką ocenę zgodnie wystawia się | Prob: 0.19270310920693595
# 5 order: tabelką wystawia z ocenę się zgodnie | Prob: 0.19209363406100533
# True order: ocenę wystawia się zgodnie z tabelką
# position of true order: 50
# Points for sentence: 0.02
#
#
# ------------Sentence 44--------------------
# 1 order: daje 50 punktów ocenę dostateczną | Prob: 0.18625816709819276
# 2 order: punktów ocenę dostateczną daje 50 | Prob: 0.16042285023505773
# 3 order: 50 punktów ocenę dostateczną daje | Prob: 0.16039580560615396
# 4 order: 50 daje punktów ocenę dostateczną | Prob: 0.1601749664920406
# 5 order: punktów ocenę dostateczną 50 daje | Prob: 0.15936456052015233
# True order: 50 punktów daje ocenę dostateczną
# position of true order: 29
# Points for sentence: 0.034482758620689655
#
#
# ------------Sentence 45--------------------
# 1 order: daje 120 punktów ocenę bardzo dobrą | Prob: 0.5906855983754247
# 2 order: ocenę bardzo dobrą daje 120 punktów | Prob: 0.5902363757496769
# 3 order: daje ocenę bardzo dobrą 120 punktów | Prob: 0.4357511768146622
# 4 order: ocenę bardzo dobrą 120 punktów daje | Prob: 0.4354437296588271
# 5 order: 120 ocenę bardzo dobrą daje punktów | Prob: 0.4323281670051139
# True order: 120 punktów daje ocenę bardzo dobrą
# position of true order: 13
# Points for sentence: 0.07692307692307693
#
#
# ------------Sentence 46--------------------
# 1 order: powyższa tabelka przeskalowana zostanie | Prob: 0.03301736542597359
# 2 order: tabelka przeskalowana zostanie powyższa | Prob: 0.027253734308336733
# 3 order: powyższa tabelka zostanie przeskalowana | Prob: 0.02144371616918122
# 4 order: tabelka powyższa przeskalowana zostanie | Prob: 0.01994880900035446
# 5 order: przeskalowana powyższa tabelka zostanie | Prob: 0.0188112495228931
# True order: powyższa tabelka zostanie przeskalowana
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 47--------------------
# 1 order: przeskalowana może też zostać z powodów innych | Prob: 0.4329408002937798
# 2 order: może też zostać z powodów innych przeskalowana | Prob: 0.43085983546493417
# 3 order: też przeskalowana może zostać z powodów innych | Prob: 0.4297586567319073
# 4 order: przeskalowana może zostać z powodów innych też | Prob: 0.4296778376313648
# 5 order: przeskalowana może zostać z innych też powodów | Prob: 0.423755895560169
# True order: może też zostać przeskalowana z innych powodów
# position of true order: 1004
# Points for sentence: 0.00099601593625498
#
#
# ------------Sentence 48--------------------
# 1 order: podamy coś w pierwszym tygodniu zajęć | Prob: 0.18227877586744806
# 2 order: zajęć podamy coś w pierwszym tygodniu | Prob: 0.18225538896671117
# 3 order: coś zajęć podamy w pierwszym tygodniu | Prob: 0.17700833760534462
# 4 order: zajęć podamy w pierwszym tygodniu coś | Prob: 0.17675063008149247
# 5 order: zajęć coś podamy w pierwszym tygodniu | Prob: 0.16861518464566072
# True order: w pierwszym tygodniu zajęć coś podamy
# position of true order: 21
# Points for sentence: 0.047619047619047616
#
#
# ------------Sentence 49--------------------
# 1 order: egzaminu zasady umożliwiające dodatkowe zwolnienie z | Prob: 0.1249650223836365
# 2 order: zasady umożliwiające dodatkowe zwolnienie z egzaminu | Prob: 0.12300145696363991
# 3 order: egzaminu umożliwiające dodatkowe zwolnienie z zasady | Prob: 0.12142636879112698
# 4 order: zasady egzaminu umożliwiające dodatkowe zwolnienie z | Prob: 0.12122605229698126
# 5 order: umożliwiające dodatkowe zwolnienie z egzaminu zasady | Prob: 0.12053470173478799
# True order: dodatkowe zasady umożliwiające zwolnienie z egzaminu
# position of true order: 35
# Points for sentence: 0.02857142857142857
#
#
# ------------Sentence 50--------------------
# 1 order: dotyczą dużą liczbą punktów z osób | Prob: 0.16370442997944373
# 2 order: osób dotyczą dużą liczbą punktów z | Prob: 0.1634786365843533
# 3 order: dotyczą dużą liczbą punktów osób z | Prob: 0.15897397768296886
# 4 order: osób dotyczą z dużą liczbą punktów | Prob: 0.14252504704343394
# 5 order: z dotyczą dużą liczbą punktów osób | Prob: 0.13633422920262941
# True order: dotyczą osób z dużą liczbą punktów
# position of true order: 8
# Points for sentence: 0.125
#
#
# ------------Sentence 51--------------------
# 1 order: też specjalne zadanie można rozwiązać | Prob: 0.2003606687083909
# 2 order: rozwiązać można też specjalne zadanie | Prob: 0.19125692336702166
# 3 order: rozwiązać też specjalne zadanie można | Prob: 0.18324412362753828
# 4 order: można rozwiązać też specjalne zadanie | Prob: 0.18307638962956624
# 5 order: też specjalne zadanie rozwiązać można | Prob: 0.18237339823296078
# True order: można rozwiązać też zadanie specjalne
# position of true order: 28
# Points for sentence: 0.03571428571428571
#
#
# ------------Sentence 52--------------------
# 1 order: forma egzaminu zależy od wielu czynników | Prob: 0.13889380262614545
# 2 order: egzaminu zależy od wielu czynników forma | Prob: 0.13858318794972257
# 3 order: egzaminu forma zależy od wielu czynników | Prob: 0.1311511367268876
# 4 order: forma zależy od wielu czynników egzaminu | Prob: 0.13092404256297255
# 5 order: egzaminu forma od wielu czynników zależy | Prob: 0.11812275520204933
# True order: forma egzaminu zależy od wielu czynników
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 53--------------------
# 1 order: należy wariantów różnych spodziewać się | Prob: 0.2979435830402649
# 2 order: należy się spodziewać wariantów różnych | Prob: 0.28511803396792273
# 3 order: należy wariantów różnych się spodziewać | Prob: 0.24871240056425664
# 4 order: spodziewać należy wariantów różnych się | Prob: 0.24640083055416792
# 5 order: się spodziewać należy wariantów różnych | Prob: 0.2362401835666982
# True order: należy się spodziewać różnych wariantów
# position of true order: 12
# Points for sentence: 0.08333333333333333
#
#
# ------------Sentence 54--------------------
# 1 order: nie wykluczamy indywidualnego egzaminu ustnego | Prob: 0.1524460075765951
# 2 order: nie wykluczamy ustnego egzaminu indywidualnego | Prob: 0.1524460075765951
# 3 order: indywidualnego egzaminu ustnego wykluczamy nie | Prob: 0.1510979727811957
# 4 order: ustnego egzaminu indywidualnego wykluczamy nie | Prob: 0.1510979727811957
# 5 order: indywidualnego egzaminu ustnego nie wykluczamy | Prob: 0.1466334039309139
# True order: nie wykluczamy indywidualnego egzaminu ustnego
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 55--------------------
# 1 order: tutaj też są jaś i małgosia | Prob: 1.1794771127103063
# 2 order: też tutaj są jaś i małgosia | Prob: 1.173512701793237
# 3 order: są jaś i małgosia też tutaj | Prob: 1.172434766839281
# 4 order: tutaj są jaś i małgosia też | Prob: 1.172147170856999
# 5 order: są jaś i małgosia tutaj też | Prob: 1.1718733464563906
# True order: jaś i małgosia też są tutaj
# position of true order: 41
# Points for sentence: 0.024390243902439025
#
#
# ------------Sentence 56--------------------
# 1 order: puchatek przybędą nie z prosiaczkiem | Prob: 0.09980162551558794
# 2 order: przybędą puchatek nie z prosiaczkiem | Prob: 0.07577448495472741
# 3 order: przybędą nie z prosiaczkiem puchatek | Prob: 0.07396184903187876
# 4 order: puchatek nie z prosiaczkiem przybędą | Prob: 0.06903031894826371
# 5 order: puchatek przybędą z prosiaczkiem nie | Prob: 0.05804976277700684
# True order: puchatek z prosiaczkiem nie przybędą
# position of true order: 16
# Points for sentence: 0.0625
#
#
# ------------Sentence 57--------------------
# 1 order: był chory i odpoczywał kotek raz | Prob: 0.08615350236311362
# 2 order: kotek odpoczywał raz był chory i | Prob: 0.08524867754617613
# 3 order: był chory i kotek raz odpoczywał | Prob: 0.08518349330659687
# 4 order: odpoczywał był chory i kotek raz | Prob: 0.08459178015049981
# 5 order: był chory i kotek odpoczywał raz | Prob: 0.08299442786177877
# True order: raz kotek był chory i odpoczywał
# position of true order: 9
# Points for sentence: 0.1111111111111111
#
#
# ------------Sentence 58--------------------
# 1 order: leżał chory w kotek i łóżeczku raz był | Prob: 0.2272612433600223
# 2 order: leżał chory w łóżeczku raz był kotek i | Prob: 0.22542921118266473
# 3 order: łóżeczku leżał chory w kotek i raz był | Prob: 0.22530631142982105
# 4 order: leżał chory w kotek i raz był łóżeczku | Prob: 0.2252875329864499
# 5 order: łóżeczku raz był leżał chory w kotek i | Prob: 0.22475097172591396
# True order: raz kotek był chory i leżał w łóżeczku
# position of true order: 1860
# Points for sentence: 0.0005376344086021505
#
#
# ------------Sentence 59--------------------
# 1 order: definicja trudna równoważności jest nie relacji | Prob: 0.5311820728754303
# 2 order: trudna równoważności jest nie definicja relacji | Prob: 0.5306040971854558
# 3 order: trudna równoważności jest nie relacji definicja | Prob: 0.5303292673855714
# 4 order: relacji trudna równoważności jest nie definicja | Prob: 0.51966235969722
# 5 order: definicja relacji trudna równoważności jest nie | Prob: 0.5181585334296684
# True order: definicja relacji równoważności nie jest trudna
# position of true order: 310
# Points for sentence: 0.0032258064516129032
#
#
# ------------Sentence 60--------------------
# 1 order: hipoteza continuum jest niezależna od aksjomatów | Prob: 0.26260506764310226
# 2 order: aksjomatów hipoteza continuum jest niezależna od | Prob: 0.25687617743492175
# 3 order: continuum jest niezależna od aksjomatów hipoteza | Prob: 0.19698745938187398
# 4 order: aksjomatów continuum jest niezależna od hipoteza | Prob: 0.1947697017731633
# 5 order: hipoteza aksjomatów continuum jest niezależna od | Prob: 0.19475834988902946
# True order: hipoteza continuum jest niezależna od aksjomatów
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 61--------------------
# 1 order: daje wiele radości teoria mnogości | Prob: 0.14201880600281935
# 2 order: daje wiele mnogości teoria radości | Prob: 0.14201880600281935
# 3 order: teoria daje wiele mnogości radości | Prob: 0.1357959147977645
# 4 order: teoria daje wiele radości mnogości | Prob: 0.1357959147977645
# 5 order: mnogości teoria daje wiele radości | Prob: 0.1357843012862412
# True order: teoria mnogości daje wiele radości
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 62--------------------
# 1 order: szczególnie trudne jest nie programowanie | Prob: 0.4237481362858127
# 2 order: nie trudne jest szczególnie programowanie | Prob: 0.4237481362858127
# 3 order: nie trudne jest programowanie szczególnie | Prob: 0.4237481362858127
# 4 order: programowanie trudne jest szczególnie nie | Prob: 0.4237481362858127
# 5 order: programowanie trudne jest nie szczególnie | Prob: 0.4237481362858127
# True order: programowanie nie jest szczególnie trudne
# position of true order: 83
# Points for sentence: 0.012048192771084338
#
#
# ------------Sentence 63--------------------
# 1 order: rachunek przydaje się prawdopodobieństwa w życiu | Prob: 0.37884220455437045
# 2 order: życiu rachunek przydaje się prawdopodobieństwa w | Prob: 0.3732033245614136
# 3 order: rachunek przydaje się życiu prawdopodobieństwa w | Prob: 0.35871442144860904
# 4 order: rachunek przydaje się w życiu prawdopodobieństwa | Prob: 0.355878252860667
# 5 order: życiu rachunek przydaje się w prawdopodobieństwa | Prob: 0.35551346504174297
# True order: rachunek prawdopodobieństwa przydaje się w życiu
# position of true order: 40
# Points for sentence: 0.025
#
#
# ------------Sentence 64--------------------
# 1 order: smoka zanim rycerze osaczyli księżniczkę strawił | Prob: 0.6233465983613015
# 2 order: smoka zanim rycerze osaczyli strawił księżniczkę | Prob: 0.6233019226841319
# 3 order: księżniczkę smoka zanim rycerze osaczyli strawił | Prob: 0.6232964829562568
# 4 order: strawił smoka zanim rycerze osaczyli księżniczkę | Prob: 0.6232927972703578
# 5 order: strawił księżniczkę smoka zanim rycerze osaczyli | Prob: 0.6232884405141998
# True order: rycerze osaczyli smoka zanim strawił księżniczkę
# position of true order: 639
# Points for sentence: 0.001564945226917058
#
#
# ------------Sentence 65--------------------
# 1 order: przestać już należy chyba wymyślać zdania | Prob: 0.07653488606433254
# 2 order: już należy chyba wymyślać zdania przestać | Prob: 0.07639528624615283
# 3 order: należy chyba wymyślać zdania już przestać | Prob: 0.07341081297699256
# 4 order: już przestać należy chyba wymyślać zdania | Prob: 0.07332792933655927
# 5 order: należy chyba wymyślać zdania przestać już | Prob: 0.07317418404522408
# True order: chyba należy już przestać wymyślać zdania
# position of true order: 360
# Points for sentence: 0.002777777777777778
#
#
# All points: 12.822725577669852
