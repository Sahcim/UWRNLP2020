# %%
import numpy as np
from itertools import permutations
from tqdm import tqdm

# %%
def load_corpus(path, num_lines, K):
    file = open(path, "r")

    one_grams = {}
    two_grams = {}
    three_gram = {}
    number_of_words = 0
    num_line_iter = 0 
    
    for _, line in enumerate(tqdm(file)):
        
        line = line.lower().split(" ")

        if len(line) < 3: continue

        number_of_words += len(line)
        line_iter = 0

        while line_iter < len(line) - 2:

            word_1 = line[line_iter]
            word_2 = line[line_iter+1]
            word_3 = line[line_iter+2]

            if word_3[-1] == '\n': word_3 = word_3[:-1] 

            if len(word_1) > K:
                word_1 = word_1[-K:]
            if len(word_2) > K:
                word_2 = word_2[-K:]
            if len(word_3) > K:
                word_3 = word_3[-K:]

            key_1 = word_1
            key_2 = (word_1, word_2)
            key_3 = (word_1, word_2, word_3)

            if key_1 in one_grams.keys():
                one_grams[key_1] += 1
            else:
                one_grams[key_1] = 1

            if key_2 in two_grams.keys():
                two_grams[key_2] += 1
            else:
                two_grams[key_2] = 1

            if key_3 in three_gram.keys():
                three_gram[key_3] += 1
            else:
                three_gram[key_3] = 1

            line_iter += 1

        key_2 = (word_2, word_3)
        if key_2 in two_grams.keys():
            two_grams[key_2] += 1
        else:
            two_grams[key_2] = 1


        key_1 = word_2
        if key_1 in one_grams.keys():
             one_grams[key_1] += 1
        else:
            one_grams[key_1] = 1

        key_1 = word_3
        if key_1 in one_grams.keys():
            one_grams[key_1] += 1
        else:
            one_grams[key_1] = 1


        num_line_iter += 1
        if num_line_iter == num_lines: break

    return three_gram, two_grams, one_grams,  number_of_words

# %%
num_lines = 22000000

three_grams, two_grams, one_grams, number_of_words = load_corpus('/content/polish_corpora.txt', num_lines, 3)
# Out:
# 21999686it [30:05, 11892.81it/s]

# %%
len(three_grams.keys())
# Out:
# 64225985

# %%
def train_three_grams(path, start_line, num_lines, K):
    file = open(path, "r")

    three_gram = {}
    num_line_iter = 0

    for line in file:
        if num_line_iter < start_line:
            num_line_iter += 1
            continue
        
        line = line.lower().split(" ")

        
        if len(line) < 3: continue

        line_iter = 0

        while line_iter < len(line) - 2:

            word_1 = line[line_iter]
            word_2 = line[line_iter+1]
            word_3 = line[line_iter+2]

            if word_3[-1] == '\n': word_3 = word_3[:-1] 

            if len(word_1) > K:
                word_1 = word_1[-K:]
            if len(word_2) > K:
                word_2 = word_2[-K:]
            if len(word_3) > K:
                word_3 = word_3[-K:]

            key_3 = (word_1, word_2, word_3)
            
            if key_3 in three_gram.keys():
                three_gram[key_3] += 1
            else:
                three_gram[key_3] = 1
            
            line_iter += 1

        num_line_iter += 1
        if num_line_iter == start_line + num_lines: break

    return three_gram

# %%
train_corpus = train_three_grams('/content/polish_corpora.txt', num_lines, 1000000, 3)

# %%
len(train_corpus.keys())
# Out:
# 6990430

# %%
def train(one_grams, two_grams, three_grams, train_three_grams, number_of_words):

    lambdas = np.array([0, 0, 0])

    for three_gram in train_three_grams.keys():

        p3 = 0
        p2 = 0
        p1 = 0

        if three_gram in three_grams:

            p3 = three_grams[three_gram]/two_grams[three_gram[:2]]

        if three_gram[1:] in two_grams:

            p2 = two_grams[three_gram[1:]]/one_grams[three_gram[1]]

        if three_gram[2] in one_grams:

            p1 = one_grams[three_gram[2]]/number_of_words
        
        results = (p1, p2, p3)
        
        f = lambda i: results[i]
        best = max(range(len(results)), key=f)

        lambdas[best] += train_three_grams[three_gram]


    #lambdas = (lambdas-np.mean(lambdas)) / np.std(lambdas)
    #e_x = np.exp(lambdas - np.max(lambdas))
    #lambdas = e_x / e_x.sum()

    return lambdas/np.sum(lambdas)

# %%
lb = train(one_grams, two_grams, three_grams, train_corpus, number_of_words)
#del train_corpus

# %%
lb
# Out:
# array([0.14280524, 0.23494617, 0.62224859])

# %%
def test_three_gram(one_grams, two_grams, three_grams, lambdas, three_gram):


    result = 0

    if three_gram in three_grams:

        result += lambdas[2] * three_grams[three_gram]/two_grams[three_gram[:2]]

    if three_gram[1:] in two_grams:

        result += lambdas[1] * two_grams[three_gram[1:]]/one_grams[three_gram[1]]

    if three_gram[2] in one_grams:

        result += lambdas[0] * one_grams[three_gram[2]]/number_of_words

    return result

# %%
def test_sentence(one_grams, two_grams, three_grams, lambdas, sentence, K):

    sen_iter = 0
    result = 0

    while sen_iter < len(sentence) - 2:

        word_1 = sentence[sen_iter]
        word_2 = sentence[sen_iter+1]
        word_3 = sentence[sen_iter+2]

        if len(word_1) > K:
            word_1 = word_1[-K:]
        if len(word_2) > K:
            word_2 = word_2[-K:]
        if len(word_3) > K:
            word_3 = word_3[-K:]

        three_gram = (word_1, word_2, word_3)

        result += test_three_gram(one_grams, two_grams, three_grams, lambdas, three_gram)
        sen_iter +=1
    
    return result

# %%
f = open('/content/test.txt', 'r')

points = 0
iter = 1
for line in f:
    
    line = line.split()

    res = []
    res_values = []
    perms = list(permutations(line))
    for perm in list(perms):
        res.append([perm])
        res_values.append(test_sentence(one_grams, two_grams, three_grams, lb, perm, 3))

    res = np.array(res)
    res_values = np.array(res_values)

    best = np.argsort(res_values)[::-1]
    points += 1/(np.where(best == 0)[0][0]+1)

    print("------------Sentence {}-------------------- ".format(iter))
    print("1 order: {} | Prob: {}".format(" ".join(res[best[0]][0]), res_values[best[0]]))
    print("2 order: {} | Prob: {}".format(" ".join(res[best[1]][0]), res_values[best[1]]))
    print("3 order: {} | Prob: {}".format(" ".join(res[best[2]][0]), res_values[best[2]]))
    print("4 order: {} | Prob: {}".format(" ".join(res[best[3]][0]), res_values[best[3]]))
    print("5 order: {} | Prob: {}".format(" ".join(res[best[4]][0]), res_values[best[4]]))
    print("True order: {}".format(" ".join(line)))
    print("position of true order: {}".format(np.where(best == 0)[0][0]+1))
    print("Points for sentence: {}".format(1/(np.where(best == 0)[0][0]+1)))
    print("\n")
    iter +=1

print("All points: {}".format(points))
# Out:
# ------------Sentence 1--------------------
# 1 order: nasz przedmiot to przetwarzanie języka naturalnego | Prob: 0.2582991096208979
# 2 order: przedmiot to przetwarzanie języka naturalnego nasz | Prob: 0.25715014968977196
# 3 order: nasz przedmiot przetwarzanie języka naturalnego to | Prob: 0.24398467969531987
# 4 order: to nasz przedmiot przetwarzanie języka naturalnego | Prob: 0.2417361165167084
# 5 order: przedmiot nasz to przetwarzanie języka naturalnego | Prob: 0.23346941796187362
# True order: nasz przedmiot to przetwarzanie języka naturalnego
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 2--------------------
# 1 order: jakub michaliszyn jedną grupę prowadzi | Prob: 0.011878245239992978
# 2 order: michaliszyn jakub jedną grupę prowadzi | Prob: 0.011864978191215915
# 3 order: jakub jedną grupę prowadzi michaliszyn | Prob: 0.011854605541330379
# 4 order: michaliszyn jedną grupę prowadzi jakub | Prob: 0.011831059412606046
# 5 order: jedną grupę prowadzi jakub michaliszyn | Prob: 0.0114797456372587
# True order: jedną grupę prowadzi jakub michaliszyn
# position of true order: 5
# Points for sentence: 0.2
#
#
# ------------Sentence 3--------------------
# 1 order: wykładowcą jest paweł rychlikowski | Prob: 0.20238746474993818
# 2 order: jest paweł rychlikowski wykładowcą | Prob: 0.20238329193219062
# 3 order: paweł wykładowcą rychlikowski jest | Prob: 0.1070294686936393
# 4 order: wykładowcą rychlikowski jest paweł | Prob: 0.10666469849991242
# 5 order: wykładowcą paweł rychlikowski jest | Prob: 0.0473726479733192
# True order: wykładowcą jest paweł rychlikowski
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 4--------------------
# 1 order: paweł pan również dwie pozostałe grupy prowadzi | Prob: 0.03615697857690614
# 2 order: paweł również grupy pozostałe dwie pan prowadzi | Prob: 0.03567267982562821
# 3 order: również grupy pozostałe dwie pan prowadzi paweł | Prob: 0.03560137262054056
# 4 order: pan również dwie pozostałe grupy prowadzi paweł | Prob: 0.03549687229134434
# 5 order: paweł grupy pozostałe dwie pan również prowadzi | Prob: 0.03532889138875534
# True order: pan paweł prowadzi również dwie pozostałe grupy
# position of true order: 780
# Points for sentence: 0.001282051282051282
#
#
# ------------Sentence 5--------------------
# 1 order: wykładu pojawiać na listy zadań się stronie będą | Prob: 0.518277268549627
# 2 order: wykładu pojawiać na zadań się stronie będą listy | Prob: 0.5180903854930613
# 3 order: listy wykładu pojawiać na zadań się stronie będą | Prob: 0.5180124103923142
# 4 order: listy zadań się stronie będą wykładu pojawiać na | Prob: 0.5179977719131668
# 5 order: wykładu pojawiać na zadań się stronie listy będą | Prob: 0.5177329237322069
# True order: na stronie wykładu będą pojawiać się listy zadań
# position of true order: 4766
# Points for sentence: 0.000209819555182543
#
#
# ------------Sentence 6--------------------
# 1 order: będą listy ćwiczeniowe i pracowniowe to | Prob: 0.18319623974381705
# 2 order: będą listy pracowniowe i ćwiczeniowe to | Prob: 0.18319623974381705
# 3 order: to będą listy ćwiczeniowe i pracowniowe | Prob: 0.18189028481478678
# 4 order: to będą listy pracowniowe i ćwiczeniowe | Prob: 0.18189028481478678
# 5 order: to listy ćwiczeniowe i pracowniowe będą | Prob: 0.17305293797425397
# True order: będą to listy ćwiczeniowe i pracowniowe
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 7--------------------
# 1 order: będą listy pracowniowe i ćwiczeniowe to | Prob: 0.18319623974381705
# 2 order: będą listy ćwiczeniowe i pracowniowe to | Prob: 0.18319623974381705
# 3 order: to będą listy pracowniowe i ćwiczeniowe | Prob: 0.18189028481478678
# 4 order: to będą listy ćwiczeniowe i pracowniowe | Prob: 0.18189028481478678
# 5 order: to listy pracowniowe i ćwiczeniowe będą | Prob: 0.17305293797425397
# True order: będą to listy pracowniowe i ćwiczeniowe
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 8--------------------
# 1 order: również aktywności dodatkowe mogą pojawiać się | Prob: 0.21417507199910935
# 2 order: również mogą pojawiać się dodatkowe aktywności | Prob: 0.2139010067126935
# 3 order: mogą pojawiać się również aktywności dodatkowe | Prob: 0.21290743420881048
# 4 order: dodatkowe również mogą pojawiać się aktywności | Prob: 0.21142199019624303
# 5 order: również dodatkowe aktywności mogą pojawiać się | Prob: 0.21115301787372465
# True order: mogą się pojawiać również dodatkowe aktywności
# position of true order: 121
# Points for sentence: 0.008264462809917356
#
#
# ------------Sentence 9--------------------
# 1 order: aktywności te będą premiowane | Prob: 0.1925737527799345
# 2 order: te będą premiowane aktywności | Prob: 0.18093837057799736
# 3 order: te aktywności będą premiowane | Prob: 0.1306658744283735
# 4 order: aktywności będą premiowane te | Prob: 0.127443130539146
# 5 order: aktywności te premiowane będą | Prob: 0.04436998397723941
# True order: te aktywności będą premiowane
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 10--------------------
# 1 order: przykłąd quizy zdalnej na platformie na | Prob: 0.6780080404496484
# 2 order: przykłąd quizy zdalnej na platformie na | Prob: 0.6780080404496484
# 3 order: na przykłąd quizy zdalnej na platformie | Prob: 0.672176487792608
# 4 order: na przykłąd quizy zdalnej na platformie | Prob: 0.672176487792608
# 5 order: przykłąd quizy zdalnej na na platformie | Prob: 0.6669748322041994
# True order: na przykłąd quizy na platformie zdalnej
# position of true order: 78
# Points for sentence: 0.01282051282051282
#
#
# ------------Sentence 11--------------------
# 1 order: też miniprojekty rozważamy na temat wykładu | Prob: 0.06019205258543268
# 2 order: miniprojekty rozważamy na temat wykładu też | Prob: 0.0600431138251262
# 3 order: wykładu miniprojekty rozważamy na temat też | Prob: 0.05910228740368932
# 4 order: wykładu też miniprojekty rozważamy na temat | Prob: 0.059048632699867556
# 5 order: też wykładu miniprojekty rozważamy na temat | Prob: 0.05887143077909609
# True order: rozważamy też miniprojekty na temat wykładu
# position of true order: 51
# Points for sentence: 0.0196078431372549
#
#
# ------------Sentence 12--------------------
# 1 order: je zapowiadamy tygodniowym wyprzedzeniem z co najmniej | Prob: 0.8264565701817475
# 2 order: zapowiadamy tygodniowym wyprzedzeniem z co najmniej je | Prob: 0.8263850749074864
# 3 order: zapowiadamy tygodniowym wyprzedzeniem je z co najmniej | Prob: 0.8234136656510569
# 4 order: z co najmniej je zapowiadamy tygodniowym wyprzedzeniem | Prob: 0.8222811014244059
# 5 order: je z co najmniej zapowiadamy tygodniowym wyprzedzeniem | Prob: 0.816095269032988
# True order: zapowiadamy je z co najmniej tygodniowym wyprzedzeniem
# position of true order: 7
# Points for sentence: 0.14285714285714285
#
#
# ------------Sentence 13--------------------
# 1 order: zajęcia przeznaczone są na konkretne zadania | Prob: 0.3013021717950274
# 2 order: na konkretne zadania zajęcia przeznaczone są | Prob: 0.25005250319534045
# 3 order: zajęcia przeznaczone są konkretne na zadania | Prob: 0.22444388310015453
# 4 order: zajęcia przeznaczone są na zadania konkretne | Prob: 0.2129111086211296
# 5 order: zajęcia są przeznaczone na konkretne zadania | Prob: 0.20939374399667118
# True order: zadania są przeznaczone na konkretne zajęcia
# position of true order: 75
# Points for sentence: 0.013333333333333334
#
#
# ------------Sentence 14--------------------
# 1 order: ćwiczenia zaczynają się w sali seminaryjnej | Prob: 0.2735775316295045
# 2 order: sali zaczynają się w seminaryjnej ćwiczenia | Prob: 0.2594157775257197
# 3 order: ćwiczenia sali zaczynają się w seminaryjnej | Prob: 0.25740724059805536
# 4 order: sali zaczynają się w ćwiczenia seminaryjnej | Prob: 0.24937599761938214
# 5 order: seminaryjnej sali zaczynają się w ćwiczenia | Prob: 0.24493525711801148
# True order: ćwiczenia zaczynają się w sali seminaryjnej
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 15--------------------
# 1 order: trybie tylko w tak stacjonarnym jest | Prob: 0.19267889284470954
# 2 order: jest trybie tylko w tak stacjonarnym | Prob: 0.18862344377595608
# 3 order: tylko tak jest w trybie stacjonarnym | Prob: 0.1577259061515484
# 4 order: trybie jest tylko w tak stacjonarnym | Prob: 0.15573460457059674
# 5 order: jest tylko w tak stacjonarnym trybie | Prob: 0.15511761544265434
# True order: jest tak tylko w trybie stacjonarnym
# position of true order: 30
# Points for sentence: 0.03333333333333333
#
#
# ------------Sentence 16--------------------
# 1 order: pracowni pozostałe domyślnie zajęcia zaczynają się w | Prob: 0.43708269438903385
# 2 order: zajęcia zaczynają się w pracowni pozostałe domyślnie | Prob: 0.43332732677822894
# 3 order: pracowni pozostałe domyślnie w zajęcia zaczynają się | Prob: 0.38324693388701186
# 4 order: zajęcia zaczynają się pracowni pozostałe domyślnie w | Prob: 0.3815705185154266
# 5 order: w pracowni pozostałe domyślnie zajęcia zaczynają się | Prob: 0.34842575636228534
# True order: pozostałe zajęcia domyślnie zaczynają się w pracowni
# position of true order: 163
# Points for sentence: 0.006134969325153374
#
#
# ------------Sentence 17--------------------
# 1 order: pracownia polega na indywidualnych konsutlacjach | Prob: 0.6905179383479259
# 2 order: pracownia polega na konsutlacjach indywidualnych | Prob: 0.473952010481295
# 3 order: polega na indywidualnych konsutlacjach pracownia | Prob: 0.44112110243160885
# 4 order: polega pracownia na indywidualnych konsutlacjach | Prob: 0.44071875438222946
# 5 order: pracownia na indywidualnych konsutlacjach polega | Prob: 0.4318973005872496
# True order: pracownia polega na indywidualnych konsutlacjach
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 18--------------------
# 1 order: tam rozwiązań rozmawiamy na temat | Prob: 0.03799461878626987
# 2 order: rozwiązań rozmawiamy na temat tam | Prob: 0.037860248211267995
# 3 order: tam temat rozwiązań rozmawiamy na | Prob: 0.031870607529003864
# 4 order: temat rozwiązań rozmawiamy na tam | Prob: 0.03174451943471865
# 5 order: temat tam rozwiązań rozmawiamy na | Prob: 0.03172761733819591
# True order: rozmawiamy tam na temat rozwiązań
# position of true order: 25
# Points for sentence: 0.04
#
#
# ------------Sentence 19--------------------
# 1 order: studenci zadań przedstawiają ćwiczeń pisemne rozwiązania podczas | Prob: 0.5324616594622387
# 2 order: ćwiczeń pisemne rozwiązania podczas studenci zadań przedstawiają | Prob: 0.5322892704943798
# 3 order: studenci zadań przedstawiają podczas ćwiczeń pisemne rozwiązania | Prob: 0.5319125710451621
# 4 order: ćwiczeń pisemne rozwiązania studenci zadań przedstawiają podczas | Prob: 0.5312873726499869
# 5 order: podczas studenci zadań przedstawiają ćwiczeń pisemne rozwiązania | Prob: 0.5311015225880652
# True order: podczas ćwiczeń studenci przedstawiają pisemne rozwiązania zadań
# position of true order: 692
# Points for sentence: 0.001445086705202312
#
#
# ------------Sentence 20--------------------
# 1 order: tryb zależy od zajęć sytuacji epidemiologicznej | Prob: 0.3045285494400829
# 2 order: zajęć sytuacji epidemiologicznej tryb zależy od | Prob: 0.3031527023402006
# 3 order: tryb zajęć sytuacji epidemiologicznej zależy od | Prob: 0.2774521087501732
# 4 order: zajęć sytuacji epidemiologicznej zależy od tryb | Prob: 0.27588730926839283
# 5 order: tryb zajęć sytuacji epidemiologicznej od zależy | Prob: 0.21781949053950422
# True order: tryb zajęć zależy od sytuacji epidemiologicznej
# position of true order: 67
# Points for sentence: 0.014925373134328358
#
#
# ------------Sentence 21--------------------
# 1 order: wymogów zależy od też formalnych | Prob: 0.2516100504219564
# 2 order: też wymogów formalnych zależy od | Prob: 0.20850590858737522
# 3 order: też zależy od wymogów formalnych | Prob: 0.199001469870209
# 4 order: od też formalnych wymogów zależy | Prob: 0.1885038867369817
# 5 order: zależy od też formalnych wymogów | Prob: 0.18764246891279537
# True order: zależy też od wymogów formalnych
# position of true order: 6
# Points for sentence: 0.16666666666666666
#
#
# ------------Sentence 22--------------------
# 1 order: władz również decyzji zależy od | Prob: 0.14716113709786163
# 2 order: władz od decyzji zależy również | Prob: 0.13560367149644445
# 3 order: władz również decyzji od zależy | Prob: 0.13266155644922803
# 4 order: zależy władz również decyzji od | Prob: 0.13166167163328157
# 5 order: zależy od władz również decyzji | Prob: 0.1257667311654662
# True order: zależy również od decyzji władz
# position of true order: 19
# Points for sentence: 0.05263157894736842
#
#
# ------------Sentence 23--------------------
# 1 order: się możliwości uwzględnia studentów prowadzących i | Prob: 0.3241602381861327
# 2 order: możliwości studentów prowadzących i uwzględnia się | Prob: 0.32195983913474735
# 3 order: się możliwości i uwzględnia studentów prowadzących | Prob: 0.31679790664948937
# 4 order: się możliwości studentów prowadzących i uwzględnia | Prob: 0.3086257660182315
# 5 order: się uwzględnia możliwości studentów prowadzących i | Prob: 0.30165154319876125
# True order: uwzględnia się możliwości studentów i prowadzących
# position of true order: 261
# Points for sentence: 0.0038314176245210726
#
#
# ------------Sentence 24--------------------
# 1 order: semestru może zmieniać się on w trakcie | Prob: 0.28186780744290646
# 2 order: może zmieniać się on w trakcie semestru | Prob: 0.28068382196939196
# 3 order: semestru on może zmieniać się w trakcie | Prob: 0.2664767020474332
# 4 order: on może zmieniać się w trakcie semestru | Prob: 0.2656249639972364
# 5 order: on semestru może zmieniać się w trakcie | Prob: 0.2650434631081046
# True order: może się on zmieniać w trakcie semestru
# position of true order: 1073
# Points for sentence: 0.0009319664492078285
#
#
# ------------Sentence 25--------------------
# 1 order: prowadzącemu studenci dostarczają przed ćwiczeniami deklaracje | Prob: 0.24498928374844808
# 2 order: deklaracje prowadzącemu studenci dostarczają przed ćwiczeniami | Prob: 0.24456283168197301
# 3 order: deklaracje studenci dostarczają przed ćwiczeniami prowadzącemu | Prob: 0.19891035249744837
# 4 order: prowadzącemu deklaracje studenci dostarczają przed ćwiczeniami | Prob: 0.19840962915564508
# 5 order: prowadzącemu studenci dostarczają deklaracje przed ćwiczeniami | Prob: 0.1894079986870345
# True order: przed ćwiczeniami studenci dostarczają prowadzącemu deklaracje
# position of true order: 176
# Points for sentence: 0.005681818181818182
#
#
# ------------Sentence 26--------------------
# 1 order: numery zadań ona zawiera | Prob: 0.0075569139403382345
# 2 order: zadań ona zawiera numery | Prob: 0.007435114607674778
# 3 order: zadań zawiera ona numery | Prob: 0.0019134211612376604
# 4 order: zadań numery zawiera ona | Prob: 0.001843797205612605
# 5 order: numery zadań zawiera ona | Prob: 0.0017429087905320578
# True order: zawiera ona numery zadań
# position of true order: 10
# Points for sentence: 0.1
#
#
# ------------Sentence 27--------------------
# 1 order: przy studenci pokazują rozwiązania tablicy | Prob: 0.08334175812868935
# 2 order: tablicy przy studenci pokazują rozwiązania | Prob: 0.08305906281589234
# 3 order: przy studenci pokazują tablicy rozwiązania | Prob: 0.07714393019788011
# 4 order: rozwiązania tablicy przy studenci pokazują | Prob: 0.07061325113801702
# 5 order: tablicy rozwiązania przy studenci pokazują | Prob: 0.06943213141219023
# True order: studenci pokazują rozwiązania przy tablicy
# position of true order: 14
# Points for sentence: 0.07142857142857142
#
#
# ------------Sentence 28--------------------
# 1 order: jeżeli student nie jest źle , umie | Prob: 0.3721211075926091
# 2 order: umie jeżeli student nie jest źle , | Prob: 0.37172288631307804
# 3 order: jest źle , jeżeli student nie umie | Prob: 0.3384697725201158
# 4 order: umie jest źle , jeżeli student nie | Prob: 0.3364356725298514
# 5 order: jeżeli student nie umie jest źle , | Prob: 0.3344396706792422
# True order: jest źle , jeżeli student nie umie
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 29--------------------
# 1 order: dodatkowo mu się coś odejmuje | Prob: 0.27124914542424544
# 2 order: dodatkowo mu się odejmuje coś | Prob: 0.2632407925032716
# 3 order: odejmuje dodatkowo mu się coś | Prob: 0.26323057162380137
# 4 order: coś dodatkowo mu się odejmuje | Prob: 0.26288044250247217
# 5 order: coś odejmuje dodatkowo mu się | Prob: 0.2612423776324718
# True order: dodatkowo coś mu się odejmuje
# position of true order: 9
# Points for sentence: 0.1111111111111111
#
#
# ------------Sentence 30--------------------
# 1 order: zajęć można oddawać podczas zadania na pracowni | Prob: 0.23124205049463645
# 2 order: pracowni zajęć można oddawać podczas zadania na | Prob: 0.23108544567151643
# 3 order: zajęć pracowni podczas zadania można oddawać na | Prob: 0.229892847755171
# 4 order: pracowni podczas zadania można oddawać na zajęć | Prob: 0.22964972283489757
# 5 order: zajęć można oddawać na pracowni podczas zadania | Prob: 0.2265636577334743
# True order: zadania można oddawać podczas zajęć na pracowni
# position of true order: 342
# Points for sentence: 0.0029239766081871343
#
#
# ------------Sentence 31--------------------
# 1 order: zadania należy rozwiązywać samodzielnie | Prob: 0.0966627471923665
# 2 order: samodzielnie należy rozwiązywać zadania | Prob: 0.07945064178389423
# 3 order: należy rozwiązywać samodzielnie zadania | Prob: 0.06969577219995926
# 4 order: zadania samodzielnie należy rozwiązywać | Prob: 0.06769085998867548
# 5 order: zadania należy samodzielnie rozwiązywać | Prob: 0.06556417757558594
# True order: zadania należy rozwiązywać samodzielnie
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 32--------------------
# 1 order: prowadzący poprawność ocenia rozwiązania | Prob: 0.12915728352975706
# 2 order: prowadzący poprawność rozwiązania ocenia | Prob: 0.12915728352975706
# 3 order: rozwiązania prowadzący poprawność ocenia | Prob: 0.11191678210703279
# 4 order: ocenia prowadzący poprawność rozwiązania | Prob: 0.11191678210703279
# 5 order: prowadzący ocenia poprawność rozwiązania | Prob: 0.09418033813745282
# True order: prowadzący ocenia poprawność rozwiązania
# position of true order: 5
# Points for sentence: 0.2
#
#
# ------------Sentence 33--------------------
# 1 order: czasem mogą pojawić się informacje o regułach | Prob: 0.409206794301195
# 2 order: mogą pojawić się informacje o regułach czasem | Prob: 0.3921423416618169
# 3 order: czasem informacje o regułach mogą pojawić się | Prob: 0.36801899178373093
# 4 order: czasem pojawić się informacje o regułach mogą | Prob: 0.3458911536618783
# 5 order: mogą czasem pojawić się informacje o regułach | Prob: 0.34576847131212635
# True order: czasem mogą pojawić się informacje o regułach
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 34--------------------
# 1 order: termin podany jest na każdej liście | Prob: 0.19498904105916037
# 2 order: każdej termin podany jest na liście | Prob: 0.18160390222211878
# 3 order: termin podany jest na liście każdej | Prob: 0.1802346599219047
# 4 order: liście termin podany jest na każdej | Prob: 0.16011356877905877
# 5 order: każdej liście termin podany jest na | Prob: 0.16003750635197211
# True order: na każdej liście podany jest termin
# position of true order: 44
# Points for sentence: 0.022727272727272728
#
#
# ------------Sentence 35--------------------
# 1 order: dostajemy za poprawne rozwiązanie dużo punktów | Prob: 0.20825600738039943
# 2 order: dostajemy dużo za poprawne rozwiązanie punktów | Prob: 0.2070832304132879
# 3 order: dużo dostajemy za poprawne rozwiązanie punktów | Prob: 0.2063071192035362
# 4 order: za poprawne rozwiązanie dużo punktów dostajemy | Prob: 0.20571703155881474
# 5 order: dostajemy za poprawne rozwiązanie punktów dużo | Prob: 0.20450981229202456
# True order: za poprawne rozwiązanie dostajemy dużo punktów
# position of true order: 14
# Points for sentence: 0.07142857142857142
#
#
# ------------Sentence 36--------------------
# 1 order: spóźnione zadania będą sprawdzane nie | Prob: 0.21088660833138806
# 2 order: zadania będą sprawdzane nie spóźnione | Prob: 0.2095022930129559
# 3 order: zadania będą sprawdzane spóźnione nie | Prob: 0.19195232708462864
# 4 order: nie spóźnione zadania będą sprawdzane | Prob: 0.17788148795370495
# 5 order: spóźnione nie zadania będą sprawdzane | Prob: 0.17769016478943733
# True order: spóźnione zadania nie będą sprawdzane
# position of true order: 12
# Points for sentence: 0.08333333333333333
#
#
# ------------Sentence 37--------------------
# 1 order: pierwsza lista ma dłuższy termin | Prob: 0.008803635575337221
# 2 order: dłuższy termin ma pierwsza lista | Prob: 0.007048412254659979
# 3 order: lista dłuższy termin ma pierwsza | Prob: 0.00694407017572291
# 4 order: termin pierwsza lista ma dłuższy | Prob: 0.00636125762124546
# 5 order: lista ma dłuższy termin pierwsza | Prob: 0.005100382869563375
# True order: pierwsza lista ma dłuższy termin
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 38--------------------
# 1 order: semestru musi być zmodyfikowana pod koniec zasada | Prob: 0.4179917651121344
# 2 order: zasada semestru musi być zmodyfikowana pod koniec | Prob: 0.4063868075223513
# 3 order: semestru zmodyfikowana musi być pod koniec zasada | Prob: 0.3998297155554384
# 4 order: zmodyfikowana musi być pod koniec zasada semestru | Prob: 0.39977802519405314
# 5 order: semestru zasada zmodyfikowana musi być pod koniec | Prob: 0.389028755444845
# True order: zasada musi być zmodyfikowana pod koniec semestru
# position of true order: 151
# Points for sentence: 0.006622516556291391
#
#
# ------------Sentence 39--------------------
# 1 order: studenta choroby przypadku w obowiązują inne zasady | Prob: 0.12523091681516874
# 2 order: choroby przypadku w obowiązują inne zasady studenta | Prob: 0.12519346718288482
# 3 order: studenta obowiązują inne zasady choroby przypadku w | Prob: 0.11505192378182622
# 4 order: choroby przypadku w studenta obowiązują inne zasady | Prob: 0.1147527100081018
# 5 order: obowiązują inne zasady choroby przypadku w studenta | Prob: 0.10953999194438686
# True order: w przypadku choroby studenta obowiązują inne zasady
# position of true order: 734
# Points for sentence: 0.0013623978201634877
#
#
# ------------Sentence 40--------------------
# 1 order: kwarantanny studenta w obowiązują inne zasady przypadku | Prob: 0.14338659389132033
# 2 order: przypadku kwarantanny studenta w obowiązują inne zasady | Prob: 0.14255140600146604
# 3 order: kwarantanny studenta w przypadku obowiązują inne zasady | Prob: 0.13880716497797724
# 4 order: obowiązują inne zasady kwarantanny studenta w przypadku | Prob: 0.13829391056584206
# 5 order: przypadku obowiązują inne zasady kwarantanny studenta w | Prob: 0.1274060803518203
# True order: w przypadku kwarantanny studenta obowiązują inne zasady
# position of true order: 1036
# Points for sentence: 0.0009652509652509653
#
#
# ------------Sentence 41--------------------
# 1 order: przypadku studenta izolacji w obowiązują inne zasady | Prob: 0.12570661085350326
# 2 order: obowiązują inne zasady studenta w przypadku izolacji | Prob: 0.12439028864675795
# 3 order: studenta izolacji w obowiązują inne zasady przypadku | Prob: 0.12386793779367455
# 4 order: obowiązują inne zasady studenta izolacji w przypadku | Prob: 0.11834215297365455
# 5 order: studenta izolacji w przypadku obowiązują inne zasady | Prob: 0.11667476450867136
# True order: w przypadku izolacji studenta obowiązują inne zasady
# position of true order: 271
# Points for sentence: 0.0036900369003690036
#
#
# ------------Sentence 42--------------------
# 1 order: bez straty punktowej możliwe jest oddawanie zadań zaległych | Prob: 1.134410668823111
# 2 order: punktowej możliwe jest oddawanie zadań zaległych bez straty | Prob: 1.1261968719204443
# 3 order: straty bez punktowej możliwe jest oddawanie zadań zaległych | Prob: 1.1250206834058578
# 4 order: punktowej możliwe jest oddawanie zadań zaległych straty bez | Prob: 1.1175750481731692
# 5 order: straty punktowej możliwe jest oddawanie zadań zaległych bez | Prob: 1.1170524128827795
# True order: możliwe jest oddawanie zaległych zadań bez straty punktowej
# position of true order: 1879
# Points for sentence: 0.0005321979776476849
#
#
# ------------Sentence 43--------------------
# 1 order: ocenę zgodnie wystawia się tabelką z | Prob: 0.20663549118879565
# 2 order: zgodnie wystawia się tabelką z ocenę | Prob: 0.2061461817398561
# 3 order: tabelką ocenę zgodnie wystawia się z | Prob: 0.20006301929938974
# 4 order: z tabelką ocenę zgodnie wystawia się | Prob: 0.19392383247057948
# 5 order: tabelką wystawia z ocenę się zgodnie | Prob: 0.1870917895552966
# True order: ocenę wystawia się zgodnie z tabelką
# position of true order: 50
# Points for sentence: 0.02
#
#
# ------------Sentence 44--------------------
# 1 order: daje 50 punktów ocenę dostateczną | Prob: 0.27585435487912735
# 2 order: punktów ocenę dostateczną daje 50 | Prob: 0.2543084932046233
# 3 order: 50 punktów ocenę dostateczną daje | Prob: 0.254279562093224
# 4 order: 50 daje punktów ocenę dostateczną | Prob: 0.25413801868956326
# 5 order: punktów ocenę dostateczną 50 daje | Prob: 0.2533409634611043
# True order: 50 punktów daje ocenę dostateczną
# position of true order: 29
# Points for sentence: 0.034482758620689655
#
#
# ------------Sentence 45--------------------
# 1 order: daje 120 punktów ocenę bardzo dobrą | Prob: 0.5763765973826279
# 2 order: ocenę bardzo dobrą daje 120 punktów | Prob: 0.5759416940979155
# 3 order: daje ocenę bardzo dobrą 120 punktów | Prob: 0.42080504707908495
# 4 order: ocenę bardzo dobrą 120 punktów daje | Prob: 0.4205124125892783
# 5 order: 120 ocenę bardzo dobrą daje punktów | Prob: 0.41732821527717867
# True order: 120 punktów daje ocenę bardzo dobrą
# position of true order: 13
# Points for sentence: 0.07692307692307693
#
#
# ------------Sentence 46--------------------
# 1 order: powyższa tabelka przeskalowana zostanie | Prob: 0.032284850604153786
# 2 order: tabelka przeskalowana zostanie powyższa | Prob: 0.026125105075640517
# 3 order: powyższa tabelka zostanie przeskalowana | Prob: 0.019985172554184253
# 4 order: tabelka powyższa przeskalowana zostanie | Prob: 0.019488902806766108
# 5 order: przeskalowana powyższa tabelka zostanie | Prob: 0.017485972042107233
# True order: powyższa tabelka zostanie przeskalowana
# position of true order: 3
# Points for sentence: 0.3333333333333333
#
#
# ------------Sentence 47--------------------
# 1 order: przeskalowana może też zostać z powodów innych | Prob: 0.4338786289399561
# 2 order: może też zostać z powodów innych przeskalowana | Prob: 0.43196466817451634
# 3 order: też przeskalowana może zostać z powodów innych | Prob: 0.4300280964550645
# 4 order: przeskalowana może zostać z powodów innych też | Prob: 0.42994307601839654
# 5 order: przeskalowana może zostać z innych też powodów | Prob: 0.42653152666140104
# True order: może też zostać przeskalowana z innych powodów
# position of true order: 1001
# Points for sentence: 0.000999000999000999
#
#
# ------------Sentence 48--------------------
# 1 order: podamy coś w pierwszym tygodniu zajęć | Prob: 0.1843283062616973
# 2 order: zajęć podamy coś w pierwszym tygodniu | Prob: 0.18431035499685303
# 3 order: coś zajęć podamy w pierwszym tygodniu | Prob: 0.17207590145789076
# 4 order: zajęć podamy w pierwszym tygodniu coś | Prob: 0.1717939826206609
# 5 order: zajęć coś podamy w pierwszym tygodniu | Prob: 0.16742200726371936
# True order: w pierwszym tygodniu zajęć coś podamy
# position of true order: 21
# Points for sentence: 0.047619047619047616
#
#
# ------------Sentence 49--------------------
# 1 order: egzaminu zasady umożliwiające dodatkowe zwolnienie z | Prob: 0.12551215813938704
# 2 order: zasady umożliwiające dodatkowe zwolnienie z egzaminu | Prob: 0.12358155809868798
# 3 order: egzaminu umożliwiające dodatkowe zwolnienie z zasady | Prob: 0.1221568539289
# 4 order: zasady egzaminu umożliwiające dodatkowe zwolnienie z | Prob: 0.12194108320560568
# 5 order: umożliwiające dodatkowe zwolnienie z egzaminu zasady | Prob: 0.12124114476775465
# True order: dodatkowe zasady umożliwiające zwolnienie z egzaminu
# position of true order: 34
# Points for sentence: 0.029411764705882353
#
#
# ------------Sentence 50--------------------
# 1 order: dotyczą dużą liczbą punktów z osób | Prob: 0.16169558521374958
# 2 order: osób dotyczą dużą liczbą punktów z | Prob: 0.1614707702030949
# 3 order: dotyczą dużą liczbą punktów osób z | Prob: 0.15574979013540605
# 4 order: osób dotyczą z dużą liczbą punktów | Prob: 0.14034758755559873
# 5 order: z dotyczą dużą liczbą punktów osób | Prob: 0.13486821435552154
# True order: dotyczą osób z dużą liczbą punktów
# position of true order: 8
# Points for sentence: 0.125
#
#
# ------------Sentence 51--------------------
# 1 order: też specjalne zadanie można rozwiązać | Prob: 0.1987329139815625
# 2 order: rozwiązać można też specjalne zadanie | Prob: 0.18901928302864512
# 3 order: rozwiązać też specjalne zadanie można | Prob: 0.18175866760609488
# 4 order: można rozwiązać też specjalne zadanie | Prob: 0.1814696288981869
# 5 order: też specjalne zadanie rozwiązać można | Prob: 0.18091424624351032
# True order: można rozwiązać też zadanie specjalne
# position of true order: 28
# Points for sentence: 0.03571428571428571
#
#
# ------------Sentence 52--------------------
# 1 order: forma egzaminu zależy od wielu czynników | Prob: 0.15460495007039018
# 2 order: egzaminu zależy od wielu czynników forma | Prob: 0.15429012718072008
# 3 order: egzaminu forma zależy od wielu czynników | Prob: 0.12702278416247256
# 4 order: forma zależy od wielu czynników egzaminu | Prob: 0.1267941503121408
# 5 order: egzaminu forma od wielu czynników zależy | Prob: 0.11956463747105824
# True order: forma egzaminu zależy od wielu czynników
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 53--------------------
# 1 order: należy się spodziewać wariantów różnych | Prob: 0.2871979077703919
# 2 order: należy wariantów różnych spodziewać się | Prob: 0.2860821911878629
# 3 order: należy wariantów różnych się spodziewać | Prob: 0.23641016005001037
# 4 order: należy spodziewać się wariantów różnych | Prob: 0.23542093959650956
# 5 order: spodziewać należy wariantów różnych się | Prob: 0.2347769364501213
# True order: należy się spodziewać różnych wariantów
# position of true order: 13
# Points for sentence: 0.07692307692307693
#
#
# ------------Sentence 54--------------------
# 1 order: nie wykluczamy indywidualnego egzaminu ustnego | Prob: 0.15242746713979277
# 2 order: nie wykluczamy ustnego egzaminu indywidualnego | Prob: 0.15242746713979277
# 3 order: indywidualnego egzaminu ustnego wykluczamy nie | Prob: 0.15121043267723083
# 4 order: ustnego egzaminu indywidualnego wykluczamy nie | Prob: 0.15121043267723083
# 5 order: ustnego egzaminu indywidualnego nie wykluczamy | Prob: 0.1459548898114988
# True order: nie wykluczamy indywidualnego egzaminu ustnego
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 55--------------------
# 1 order: tutaj też są jaś i małgosia | Prob: 1.1714098740102485
# 2 order: też tutaj są jaś i małgosia | Prob: 1.1647221721933627
# 3 order: są jaś i małgosia też tutaj | Prob: 1.1636849473506696
# 4 order: tutaj są jaś i małgosia też | Prob: 1.1634025057542432
# 5 order: są jaś i małgosia tutaj też | Prob: 1.163287712426966
# True order: jaś i małgosia też są tutaj
# position of true order: 42
# Points for sentence: 0.023809523809523808
#
#
# ------------Sentence 56--------------------
# 1 order: puchatek przybędą nie z prosiaczkiem | Prob: 0.09718154845905547
# 2 order: przybędą puchatek nie z prosiaczkiem | Prob: 0.07628148750123526
# 3 order: przybędą nie z prosiaczkiem puchatek | Prob: 0.07332897794860008
# 4 order: puchatek nie z prosiaczkiem przybędą | Prob: 0.06956246966059373
# 5 order: puchatek z prosiaczkiem przybędą nie | Prob: 0.06001575815851838
# True order: puchatek z prosiaczkiem nie przybędą
# position of true order: 15
# Points for sentence: 0.06666666666666667
#
#
# ------------Sentence 57--------------------
# 1 order: był chory i odpoczywał kotek raz | Prob: 0.09686166985143355
# 2 order: był chory i kotek raz odpoczywał | Prob: 0.09623588144789286
# 3 order: kotek odpoczywał raz był chory i | Prob: 0.0958274793294489
# 4 order: odpoczywał był chory i kotek raz | Prob: 0.0956459627730688
# 5 order: był chory i kotek odpoczywał raz | Prob: 0.09379736084857328
# True order: raz kotek był chory i odpoczywał
# position of true order: 9
# Points for sentence: 0.1111111111111111
#
#
# ------------Sentence 58--------------------
# 1 order: leżał chory w kotek i łóżeczku raz był | Prob: 0.1972436931776769
# 2 order: łóżeczku leżał chory w kotek i raz był | Prob: 0.19518083739894193
# 3 order: leżał chory w kotek i raz był łóżeczku | Prob: 0.19515641404631368
# 4 order: był leżał chory w kotek i łóżeczku raz | Prob: 0.19474056538393714
# 5 order: łóżeczku raz był leżał chory w kotek i | Prob: 0.19444634715097303
# True order: raz kotek był chory i leżał w łóżeczku
# position of true order: 895
# Points for sentence: 0.0011173184357541898
#
#
# ------------Sentence 59--------------------
# 1 order: definicja trudna równoważności jest nie relacji | Prob: 0.5336011739466631
# 2 order: trudna równoważności jest nie relacji definicja | Prob: 0.5327522294649
# 3 order: trudna równoważności jest nie definicja relacji | Prob: 0.5325983711850029
# 4 order: relacji trudna równoważności jest nie definicja | Prob: 0.5219068545783967
# 5 order: definicja relacji trudna równoważności jest nie | Prob: 0.5203921799532212
# True order: definicja relacji równoważności nie jest trudna
# position of true order: 310
# Points for sentence: 0.0032258064516129032
#
#
# ------------Sentence 60--------------------
# 1 order: hipoteza continuum jest niezależna od aksjomatów | Prob: 0.32989964958240975
# 2 order: aksjomatów hipoteza continuum jest niezależna od | Prob: 0.32433360329430416
# 3 order: continuum jest niezależna od aksjomatów hipoteza | Prob: 0.2300678484059518
# 4 order: aksjomatów continuum jest niezależna od hipoteza | Prob: 0.22844016288432387
# 5 order: hipoteza aksjomatów continuum jest niezależna od | Prob: 0.228429416113809
# True order: hipoteza continuum jest niezależna od aksjomatów
# position of true order: 1
# Points for sentence: 1.0
#
#
# ------------Sentence 61--------------------
# 1 order: daje wiele radości teoria mnogości | Prob: 0.14273805089651823
# 2 order: daje wiele mnogości teoria radości | Prob: 0.14273805089651823
# 3 order: teoria daje wiele radości mnogości | Prob: 0.13523981909365262
# 4 order: teoria daje wiele mnogości radości | Prob: 0.13523981909365262
# 5 order: radości teoria daje wiele mnogości | Prob: 0.13507444837144061
# True order: teoria mnogości daje wiele radości
# position of true order: 8
# Points for sentence: 0.125
#
#
# ------------Sentence 62--------------------
# 1 order: szczególnie trudne jest nie programowanie | Prob: 0.4250431862152186
# 2 order: nie trudne jest szczególnie programowanie | Prob: 0.4250431862152186
# 3 order: nie trudne jest programowanie szczególnie | Prob: 0.4250431862152186
# 4 order: programowanie trudne jest szczególnie nie | Prob: 0.4250431862152186
# 5 order: programowanie trudne jest nie szczególnie | Prob: 0.4250431862152186
# True order: programowanie nie jest szczególnie trudne
# position of true order: 83
# Points for sentence: 0.012048192771084338
#
#
# ------------Sentence 63--------------------
# 1 order: rachunek przydaje się prawdopodobieństwa w życiu | Prob: 0.3918268050177666
# 2 order: życiu rachunek przydaje się prawdopodobieństwa w | Prob: 0.38547991185096836
# 3 order: rachunek przydaje się życiu prawdopodobieństwa w | Prob: 0.3720254191611235
# 4 order: rachunek przydaje się w życiu prawdopodobieństwa | Prob: 0.3684966697531326
# 5 order: życiu prawdopodobieństwa w rachunek przydaje się | Prob: 0.36743375798065714
# True order: rachunek prawdopodobieństwa przydaje się w życiu
# position of true order: 40
# Points for sentence: 0.025
#
#
# ------------Sentence 64--------------------
# 1 order: smoka zanim rycerze osaczyli księżniczkę strawił | Prob: 0.6257755647311936
# 2 order: smoka zanim rycerze osaczyli strawił księżniczkę | Prob: 0.6257321744027597
# 3 order: księżniczkę smoka zanim rycerze osaczyli strawił | Prob: 0.6257255471788206
# 4 order: strawił smoka zanim rycerze osaczyli księżniczkę | Prob: 0.6257192773750343
# 5 order: strawił księżniczkę smoka zanim rycerze osaczyli | Prob: 0.6257131253509741
# True order: rycerze osaczyli smoka zanim strawił księżniczkę
# position of true order: 639
# Points for sentence: 0.001564945226917058
#
#
# ------------Sentence 65--------------------
# 1 order: przestać już należy chyba wymyślać zdania | Prob: 0.0672670152161381
# 2 order: już należy chyba wymyślać zdania przestać | Prob: 0.06712768400055023
# 3 order: należy chyba wymyślać zdania już przestać | Prob: 0.06444482771413315
# 4 order: już przestać należy chyba wymyślać zdania | Prob: 0.0643843685799747
# 5 order: należy chyba wymyślać zdania przestać już | Prob: 0.06423442487259166
# True order: chyba należy już przestać wymyślać zdania
# position of true order: 189
# Points for sentence: 0.005291005291005291
#
#
# All points: 13.507704480002788
